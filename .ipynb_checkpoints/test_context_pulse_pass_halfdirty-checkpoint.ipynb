# %% [markdown]
# ### A few initial libraries ###

# %%
import numpy as np
import qiskit
from qiskit import *
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, Aer, execute, transpile

from qiskit.transpiler import PassManager

from qiskit.converters import circuit_to_dag
from qiskit.visualization import dag_drawer, plot_histogram
from qiskit.compiler import assemble
from qiskit.tools.monitor import job_monitor

from qiskit import IBMQ
from qiskit.test.mock import FakeManhattan
from qiskit.test.mock import FakeBogota
from qiskit.test.mock import FakeMumbai
from qiskit.test.mock import FakeTokyo
# The pulse simulator
from qiskit.providers.aer import PulseSimulator

# Object for representing physical models
from qiskit.providers.aer.pulse import PulseSystemModel



from gate_variants.toffoli_variants import CCX_Variant_Gate 
from orientation_map import orientation_map_gen
from trios_bench.cnx_halfdirty import generate_cnx_halfdirty
from trios_bench.cnx_dirty import generate_dirty_multicontrol
from trios_bench.cuccaro_adder import generate_cuccaro_adder
# Out:
# /Users/revilooliver/Documents/quantum_computing/anaconda/anaconda3/envs/qiskit-terra/lib/python3.7/site-packages/qiskit/aqua/__init__.py:86: DeprecationWarning: The package qiskit.aqua is deprecated. It was moved/refactored to qiskit-terra For more information see <https://github.com/Qiskit/qiskit-aqua/blob/main/README.md#migration-guide>
#   warn_package('aqua', 'qiskit-terra')

# %%
qiskit.__qiskit_version__
# Out:
# {'qiskit-terra': '0.18.3', 'qiskit-aer': '0.9.1', 'qiskit-ignis': '0.6.0', 'qiskit-ibmq-provider': '0.18.1', 'qiskit-aqua': '0.9.5', 'qiskit': '0.32.1', 'qiskit-nature': None, 'qiskit-finance': None, 'qiskit-optimization': None, 'qiskit-machine-learning': None}

# %% [markdown]
# ### Load device and the device configuration object ###

# %%
IBMQ.load_account()

provider = IBMQ.get_provider('ibm-q-ornl')
# device = FakeMumbai()

# backend_prop = device.properties()

# %%
from qiskit_superstaq.superstaq_provider import SuperstaQProvider

# %%
superstaq_provider = SuperstaQProvider(api_key="ya29.A0ARrdaM-BWPjpkjhKgbVSRwWROaVE3g6mKCew2all4yXuPNLIwc6l65K10DiAMa-w8he0mR-i0Tb_jE6-GqqWlscj9Zq58rC2oSSzRVaLdZJMoy2bWqIXVhK3Tehp5N4zd8uHhyp01G9KC90Xmu3BKALiGiLP-w")

# %%
from level3_context import _parse_transpile_args, level_3_context_pass_manager
from level3_context_pulse import level_3_pass_manager, level_3_orign_pulse_pass_manager, level_3_context_pulse_pass_manager, level_3_pulse_pass_manager

# %%
qc = QuantumCircuit(5, 5)
# qc.cx(0,3)
# qc.cx(1,2)
# qc.h(2)
# qc.ccx(0,1,2)
# qc.x(1)
# qc.cx(1,2)
# qc.cx(0,1)
# qc.z(0)
# qc.ccx(0,1,2)
# qc.x(1)
# qc.cx(1,2)
qc.rx(np.pi/3, 0)
qc.cx(0,1)
qc.cx(1,2)
qc.cx(0,1)
#

# %%
qc =  generate_cnx_halfdirty(5)

# %%
qc.draw()
# Out:
#
# q_0: ───────■─────────■──
#             │         │
# q_1: ───────■─────────■──
#             │         │
# q_2: ──■────┼────■────┼──
#      ┌─┴─┐  │  ┌─┴─┐  │
# q_3: ┤ X ├──┼──┤ X ├──┼──
#      └─┬─┘┌─┴─┐└─┬─┘┌─┴─┐
# q_4: ──■──┤ X ├──■──┤ X ├
#           └───┘     └───┘

# %%
qc.count_ops()
# Out:
# OrderedDict([('ccx', 4)])

# %%
backend = provider.get_backend('ibmq_jakarta')

# %%
backend_prop = backend.properties()

# %%
orientation_map = orientation_map_gen(backend)

# %%
coupling_map = [[0, 1], [1, 0], [1, 2], [1, 3], [2, 1], [3, 1], [3, 5], [4, 5], [5, 3], [5, 4], [5, 6], [6, 5]]

# %%
transpile_args = _parse_transpile_args([qc], backend = None, coupling_map = coupling_map, basis_gates = ['cx', 'rz', 'sx', 'x', 'acecr_pm'], seed_transpiler = 0, orientation_map = orientation_map)

# %%
pass_manager_config = transpile_args[0]['pass_manager_config']

# %%
print(pass_manager_config.orientation_map)
# Out:
# {(0, 1): 'f', (1, 0): 'b', (1, 2): 'b', (1, 3): 'f', (2, 1): 'f', (3, 1): 'b', (3, 5): 'f', (4, 5): 'b', (5, 3): 'b', (5, 4): 'f', (5, 6): 'b', (6, 5): 'f'}

# %%
pm_context = level_3_context_pass_manager(pass_manager_config)
# Out:
# layout_method:  dense
# routing method:  basic

# %%
pm_orign = level_3_pass_manager(pass_manager_config)
# Out:
# layout_method:  dense
# routing method:  basic

# %%
pm_orign_pulse = level_3_orign_pulse_pass_manager(pass_manager_config)
# Out:
# layout_method:  dense
# routing method:  basic

# %%
pm_context_pulse = level_3_context_pulse_pass_manager(pass_manager_config)
# Out:
# layout_method:  dense
# routing method:  basic

# %%
qc_context_pulse = pm_context_pulse.run(qc)
# Out:
# ccx
# ccx
# ccx
# ccx
# No solution found:  nonexistent solution
# Layout({
# 5: Qubit(QuantumRegister(5, 'q'), 0),
# 3: Qubit(QuantumRegister(5, 'q'), 1),
# 2: Qubit(QuantumRegister(5, 'q'), 2),
# 1: Qubit(QuantumRegister(5, 'q'), 3),
# 0: Qubit(QuantumRegister(5, 'q'), 4)
# })
# The physical qubits for the toffoli are:  0 2 1
# The required toffoli will be decomposed using an 8 cnot decomposition - two in center
# ccx
# three intersection conditions False True False
# three qargs Qubit(QuantumRegister(7, 'q'), 0) Qubit(QuantumRegister(7, 'q'), 2) Qubit(QuantumRegister(7, 'q'), 1)
# calculated tags ['00', '00', 'l2', 'p'] ['00', '00', 'l2', 'p']
# swap
# successor swap two intersection conditions:TrueTrue
# initialized variant_tag: ('00', '02', 'l2', 's')
# The physical qubits for the toffoli are:  5 3 1
# The required toffoli will be decomposed using an 8 cnot decomposition - one in center
# ccx
# three intersection conditions True True False
# three qargs Qubit(QuantumRegister(7, 'q'), 5) Qubit(QuantumRegister(7, 'q'), 3) Qubit(QuantumRegister(7, 'q'), 1)
# calculated tags ['00', '01', 'l1', 's'] ['01', '00', 'l1', 'p']
# initialized variant_tag: ('01', '00', 'l1', 'p')
# initialized variant_tag: ('00', '01', 'l1', 's')
# The physical qubits for the toffoli are:  1 2 0
# The required toffoli will be decomposed using an 8 cnot decomposition - zero in center
# ccx_variant
# None
# None
# predecessor swap two intersection conditions:FalseTrue
# initialized variant_tag: ('00', '00', 'l0', 'p')
# look for variant_rules ('00', '02', 'l2', 's')
# final tag, one match ('21', '02', 'l2', 's')
# look for variant_rules ('00', '01', 'l1', 's')
# final tag, one match ('12', '01', 'l1', 's')
# look for variant_rules ('00', '00', 'l0', 'p')
# didn't find match tag
# l0 ['00', '00', 'l0', 'p']
# look for variant_rules ('01', '00', 'l1', 'p')
# final tag, one match ('01', '12', 'l1', 'p')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 0), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# ('00', '11', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# ('11', '00', 'f')
# ('00', '11', 'b')
# ('11', '00', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 5), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'b')
# ('11', '00', 'b')
# ('00', '11', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 5), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'b')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'b')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 2), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# ('00', '11', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 2), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# ('00', '11', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 5), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'b')
# ('11', '00', 'b')
# ('00', '11', 'b')
# ('00', '11', 'b')

# %%
qc_context_pulse.draw()
# Out:
# global phase: π
#                                                               ┌───────────┐»
#       q_4 -> 0 ───────────────────────────────────────────────┤0          ├»
#                                 ┌───────────┐┌─────────┐┌────┐│  Acecr_pm │»
#       q_3 -> 1 ─────────────────┤1          ├┤ Rz(π/2) ├┤ √X ├┤1          ├»
#                ┌─────────┐┌────┐│  Acecr_pm │├─────────┤├────┤└┬─────────┬┘»
#       q_2 -> 2 ┤ Rz(π/2) ├┤ √X ├┤0          ├┤ Rz(π/2) ├┤ √X ├─┤ Rz(π/4) ├─»
#                ├─────────┤├────┤└┬─────────┬┘└─────────┘└────┘ └─────────┘ »
#       q_1 -> 3 ┤ Rz(π/2) ├┤ √X ├─┤ Rz(π/2) ├───────────────────────────────»
#                └─────────┘└────┘ └─────────┘                               »
# ancilla_0 -> 4 ────────────────────────────────────────────────────────────»
#                ┌─────────┐┌────┐ ┌─────────┐                               »
#       q_0 -> 5 ┤ Rz(π/2) ├┤ √X ├─┤ Rz(π/2) ├───────────────────────────────»
#                └─────────┘└────┘ └─────────┘                               »
# ancilla_1 -> 6 ────────────────────────────────────────────────────────────»
#                                                                            »
# «                                                                         »
# «      q_4 -> 0 ──────────────────────────────────────────────────────────»
# «               ┌─────────┐┌────┐┌───────────┐┌─────────┐┌────┐┌─────────┐»
# «      q_3 -> 1 ┤ Rz(π/2) ├┤ √X ├┤1          ├┤ Rz(π/2) ├┤ √X ├┤ Rz(π/4) ├»
# «               └──┬────┬─┘└────┘│  Acecr_pm │├─────────┤├────┤├─────────┤»
# «      q_2 -> 2 ───┤ √X ├────────┤0          ├┤ Rz(π/2) ├┤ √X ├┤ Rz(π/4) ├»
# «                  └────┘        └───────────┘└─────────┘└────┘└─────────┘»
# «      q_1 -> 3 ──────────────────────────────────────────────────────────»
# «                                                                         »
# «ancilla_0 -> 4 ──────────────────────────────────────────────────────────»
# «                                                                         »
# «      q_0 -> 5 ──────────────────────────────────────────────────────────»
# «                                                                         »
# «ancilla_1 -> 6 ──────────────────────────────────────────────────────────»
# «                                                                         »
# «                     ┌───────────┐   ┌───┐   ┌─────────┐           »
# «      q_4 -> 0 ──────┤0          ├───┤ X ├───┤ Rz(π/2) ├───────────»
# «               ┌────┐│  Acecr_pm │┌──┴───┴──┐└──┬────┬─┘┌─────────┐»
# «      q_3 -> 1 ┤ √X ├┤1          ├┤ Rz(π/2) ├───┤ √X ├──┤ Rz(π/2) ├»
# «               ├────┤└───────────┘└─────────┘   └────┘  └─────────┘»
# «      q_2 -> 2 ┤ √X ├──────────────────────────────────────────────»
# «               └────┘                                              »
# «      q_1 -> 3 ────────────────────────────────────────────────────»
# «                                                                   »
# «ancilla_0 -> 4 ────────────────────────────────────────────────────»
# «                                                                   »
# «      q_0 -> 5 ────────────────────────────────────────────────────»
# «                                                                   »
# «ancilla_1 -> 6 ────────────────────────────────────────────────────»
# «                                                                   »
# «                                                   ┌───────────┐┌────────────┐»
# «      q_4 -> 0 ────────────────────────────────────┤0          ├┤ Rz(3.1306) ├»
# «               ┌───────────┐   ┌───┐   ┌──────────┐│  Acecr_pm │└┬─────────┬─┘»
# «      q_3 -> 1 ┤1          ├───┤ X ├───┤ Rz(-π/2) ├┤1          ├─┤ Rz(π/2) ├──»
# «               │  Acecr_pm │┌──┴───┴──┐└──┬────┬──┘└┬──────────┤ └──┬────┬─┘  »
# «      q_2 -> 2 ┤0          ├┤ Rz(π/2) ├───┤ √X ├────┤ Rz(-π/4) ├────┤ √X ├────»
# «               └───────────┘└─────────┘   └────┘    └──────────┘    └────┘    »
# «      q_1 -> 3 ───────────────────────────────────────────────────────────────»
# «                                                                              »
# «ancilla_0 -> 4 ───────────────────────────────────────────────────────────────»
# «                                                                              »
# «      q_0 -> 5 ───────────────────────────────────────────────────────────────»
# «                                                                              »
# «ancilla_1 -> 6 ───────────────────────────────────────────────────────────────»
# «                                                                              »
# «               ┌────┐ ┌────────┐                                   »
# «      q_4 -> 0 ┤ √X ├─┤ Rz(-π) ├───────────────────────────────────»
# «               ├────┤┌┴────────┤┌───────────┐   ┌────┐  ┌─────────┐»
# «      q_3 -> 1 ┤ √X ├┤ Rz(π/2) ├┤1          ├───┤ √X ├──┤ Rz(π/2) ├»
# «               └────┘└─────────┘│  Acecr_pm │┌──┴────┴─┐└──┬────┬─┘»
# «      q_2 -> 2 ─────────────────┤0          ├┤ Rz(π/2) ├───┤ √X ├──»
# «                                └───────────┘└─────────┘   └────┘  »
# «      q_1 -> 3 ────────────────────────────────────────────────────»
# «                                                                   »
# «ancilla_0 -> 4 ────────────────────────────────────────────────────»
# «                                                                   »
# «      q_0 -> 5 ────────────────────────────────────────────────────»
# «                                                                   »
# «ancilla_1 -> 6 ────────────────────────────────────────────────────»
# «                                                                   »
# «               ┌───────────┐┌─────────┐┌────┐┌───────────┐  ┌────┐  »
# «      q_4 -> 0 ┤0          ├┤ Rz(π/2) ├┤ √X ├┤0          ├──┤ √X ├──»
# «               │  Acecr_pm │├─────────┤├────┤│  Acecr_pm │┌─┴────┴─┐»
# «      q_3 -> 1 ┤1          ├┤ Rz(π/2) ├┤ √X ├┤1          ├┤ Rz(-π) ├»
# «               └─┬────────┬┘└─────────┘└────┘└───────────┘└────────┘»
# «      q_2 -> 2 ──┤ Rz(-π) ├─────────────────────────────────────────»
# «                 └────────┘                                         »
# «      q_1 -> 3 ─────────────────────────────────────────────────────»
# «                                                                    »
# «ancilla_0 -> 4 ─────────────────────────────────────────────────────»
# «                                                                    »
# «      q_0 -> 5 ─────────────────────────────────────────────────────»
# «                                                                    »
# «ancilla_1 -> 6 ─────────────────────────────────────────────────────»
# «                                                                    »
# «               ┌───────────┐    ┌────┐                                  »
# «      q_4 -> 0 ┤ Rz(-3π/4) ├────┤ √X ├──────────────────────────────────»
# «               └───┬────┬──┘┌───┴────┴───┐┌───────────┐┌─────────┐┌────┐»
# «      q_3 -> 1 ────┤ √X ├───┤ Rz(2.3672) ├┤0          ├┤ Rz(π/2) ├┤ √X ├»
# «                   └────┘   └────────────┘│           │└─────────┘└────┘»
# «      q_2 -> 2 ───────────────────────────┤  Acecr_pm ├─────────────────»
# «                                          │           │ ┌────────┐┌────┐»
# «      q_1 -> 3 ───────────────────────────┤1          ├─┤ Rz(-π) ├┤ √X ├»
# «                                          └───────────┘ └────────┘└────┘»
# «ancilla_0 -> 4 ─────────────────────────────────────────────────────────»
# «                                                                        »
# «      q_0 -> 5 ─────────────────────────────────────────────────────────»
# «                                                                        »
# «ancilla_1 -> 6 ─────────────────────────────────────────────────────────»
# «                                                                        »
# «                                                                          »
# «      q_4 -> 0 ───────────────────────────────────────────────────────────»
# «               ┌─────────┐    ┌────┐        ┌───────────┐┌─────────┐┌────┐»
# «      q_3 -> 1 ┤ Rz(π/4) ├────┤ √X ├────────┤0          ├┤ Rz(π/2) ├┤ √X ├»
# «               └─────────┘    └────┘        │           │└─────────┘└────┘»
# «      q_2 -> 2 ─────────────────────────────┤  Acecr_pm ├─────────────────»
# «               ┌─────────┐┌───────────┐┌───┐│           │┌─────────┐┌────┐»
# «      q_1 -> 3 ┤ Rz(π/2) ├┤0          ├┤ X ├┤1          ├┤ Rz(π/2) ├┤ √X ├»
# «               └─────────┘│           │└───┘└───────────┘└─────────┘└────┘»
# «ancilla_0 -> 4 ───────────┤  Acecr_pm ├───────────────────────────────────»
# «                          │           │                                   »
# «      q_0 -> 5 ───────────┤1          ├───────────────────────────────────»
# «                          └───────────┘                                   »
# «ancilla_1 -> 6 ───────────────────────────────────────────────────────────»
# «                                                                          »
# «                                                                    »
# «      q_4 -> 0 ─────────────────────────────────────────────────────»
# «               ┌─────────┐ ┌────┐                                   »
# «      q_3 -> 1 ┤ Rz(π/4) ├─┤ √X ├───────────────────────────────────»
# «               └─────────┘ └────┘                                   »
# «      q_2 -> 2 ─────────────────────────────────────────────────────»
# «               ┌──────────┐┌────┐┌─────────┐┌───────────┐┌─────────┐»
# «      q_1 -> 3 ┤ Rz(-π/4) ├┤ √X ├┤ Rz(π/2) ├┤0          ├┤ Rz(π/2) ├»
# «               └──────────┘└────┘└─────────┘│           │└─────────┘»
# «ancilla_0 -> 4 ─────────────────────────────┤  Acecr_pm ├───────────»
# «                                            │           │           »
# «      q_0 -> 5 ─────────────────────────────┤1          ├───────────»
# «                                            └───────────┘           »
# «ancilla_1 -> 6 ─────────────────────────────────────────────────────»
# «                                                                    »
# «                                                                           »
# «      q_4 -> 0 ────────────────────────────────────────────────────────────»
# «               ┌───────────┐┌─────────┐┌────┐┌──────────┐    ┌────┐        »
# «      q_3 -> 1 ┤0          ├┤ Rz(π/2) ├┤ √X ├┤ Rz(-π/4) ├────┤ √X ├────────»
# «               │           │└─────────┘└────┘└──────────┘    └────┘        »
# «      q_2 -> 2 ┤  Acecr_pm ├───────────────────────────────────────────────»
# «               │           │ ┌────────┐┌────┐┌─────────┐ ┌───────────┐┌───┐»
# «      q_1 -> 3 ┤1          ├─┤ Rz(-π) ├┤ √X ├┤ Rz(π/2) ├─┤0          ├┤ X ├»
# «               └───────────┘ └────────┘└────┘└─────────┘ │           │└───┘»
# «ancilla_0 -> 4 ──────────────────────────────────────────┤  Acecr_pm ├─────»
# «                                                         │           │     »
# «      q_0 -> 5 ──────────────────────────────────────────┤1          ├─────»
# «                                                         └───────────┘     »
# «ancilla_1 -> 6 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «                                                          ┌───────────┐»
# «      q_4 -> 0 ───────────────────────────────────────────┤0          ├»
# «               ┌───────────┐┌─────────┐┌────┐┌───────────┐│  Acecr_pm │»
# «      q_3 -> 1 ┤0          ├┤ Rz(π/2) ├┤ √X ├┤ Rz(-3π/4) ├┤1          ├»
# «               │           │└─────────┘└────┘└───────────┘└───────────┘»
# «      q_2 -> 2 ┤  Acecr_pm ├───────────────────────────────────────────»
# «               │           │                                           »
# «      q_1 -> 3 ┤1          ├───────────────────────────────────────────»
# «               └───────────┘                                           »
# «ancilla_0 -> 4 ────────────────────────────────────────────────────────»
# «                                                                       »
# «      q_0 -> 5 ────────────────────────────────────────────────────────»
# «                                                                       »
# «ancilla_1 -> 6 ────────────────────────────────────────────────────────»
# «                                                                       »
# «               ┌─────────┐┌────┐ ┌─────────┐    ┌────┐        ┌───────────┐»
# «      q_4 -> 0 ┤ Rz(π/2) ├┤ √X ├─┤ Rz(π/4) ├────┤ √X ├────────┤0          ├»
# «               ├─────────┤├────┤┌┴─────────┴┐┌──┴────┴─┐┌────┐│  Acecr_pm │»
# «      q_3 -> 1 ┤ Rz(π/2) ├┤ √X ├┤1          ├┤ Rz(π/2) ├┤ √X ├┤1          ├»
# «               └─────────┘└────┘│  Acecr_pm │└─────────┘└────┘└───────────┘»
# «      q_2 -> 2 ─────────────────┤0          ├──────────────────────────────»
# «                                └───────────┘                              »
# «      q_1 -> 3 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_0 -> 4 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «      q_0 -> 5 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_1 -> 6 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «               ┌─────────┐┌────┐┌─────────┐┌────┐                        »
# «      q_4 -> 0 ┤ Rz(π/2) ├┤ √X ├┤ Rz(π/4) ├┤ √X ├────────────────────────»
# «               ├─────────┤├────┤├─────────┤├────┤┌───────────┐┌─────────┐»
# «      q_3 -> 1 ┤ Rz(π/2) ├┤ √X ├┤ Rz(π/4) ├┤ √X ├┤1          ├┤ Rz(π/2) ├»
# «               └─────────┘└────┘└─────────┘└────┘│  Acecr_pm │└─────────┘»
# «      q_2 -> 2 ──────────────────────────────────┤0          ├───────────»
# «                                                 └───────────┘           »
# «      q_1 -> 3 ──────────────────────────────────────────────────────────»
# «                                                                         »
# «ancilla_0 -> 4 ──────────────────────────────────────────────────────────»
# «                                                                         »
# «      q_0 -> 5 ──────────────────────────────────────────────────────────»
# «                                                                         »
# «ancilla_1 -> 6 ──────────────────────────────────────────────────────────»
# «                                                                         »
# «                                ┌───────────┐┌─────────┐┌────┐ ┌──────────┐»
# «      q_4 -> 0 ─────────────────┤0          ├┤ Rz(π/2) ├┤ √X ├─┤ Rz(-π/4) ├»
# «               ┌────┐┌─────────┐│  Acecr_pm │├─────────┤├────┤┌┴──────────┤»
# «      q_3 -> 1 ┤ √X ├┤ Rz(π/2) ├┤1          ├┤ Rz(π/2) ├┤ √X ├┤1          ├»
# «               └────┘└─────────┘└───────────┘└─────────┘└────┘│  Acecr_pm │»
# «      q_2 -> 2 ───────────────────────────────────────────────┤0          ├»
# «                                                              └───────────┘»
# «      q_1 -> 3 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_0 -> 4 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «      q_0 -> 5 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_1 -> 6 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «                  ┌────┐        ┌───────────┐┌─────────┐   ┌────┐   »
# «      q_4 -> 0 ───┤ √X ├────────┤0          ├┤ Rz(π/2) ├───┤ √X ├───»
# «               ┌──┴────┴─┐┌────┐│  Acecr_pm │└──┬───┬──┘┌──┴────┴──┐»
# «      q_3 -> 1 ┤ Rz(π/2) ├┤ √X ├┤1          ├───┤ X ├───┤ Rz(-π/2) ├»
# «               └─────────┘└────┘└───────────┘   └───┘   └──────────┘»
# «      q_2 -> 2 ─────────────────────────────────────────────────────»
# «                                                                    »
# «      q_1 -> 3 ─────────────────────────────────────────────────────»
# «                                                                    »
# «ancilla_0 -> 4 ─────────────────────────────────────────────────────»
# «                                                                    »
# «      q_0 -> 5 ─────────────────────────────────────────────────────»
# «                                                                    »
# «ancilla_1 -> 6 ─────────────────────────────────────────────────────»
# «                                                                    »
# «                ┌──────────┐    ┌────┐   ┌─────────┐                  »
# «      q_4 -> 0 ─┤ Rz(-π/4) ├────┤ √X ├───┤ Rz(π/2) ├──────────────────»
# «               ┌┴──────────┤┌───┴────┴──┐└──┬────┬─┘┌──────────┐┌────┐»
# «      q_3 -> 1 ┤1          ├┤ Rz(-3π/4) ├───┤ √X ├──┤ Rz(-π/4) ├┤ √X ├»
# «               │  Acecr_pm │└───────────┘   └────┘  └──────────┘└────┘»
# «      q_2 -> 2 ┤0          ├──────────────────────────────────────────»
# «               └───────────┘                                          »
# «      q_1 -> 3 ───────────────────────────────────────────────────────»
# «                                                                      »
# «ancilla_0 -> 4 ───────────────────────────────────────────────────────»
# «                                                                      »
# «      q_0 -> 5 ───────────────────────────────────────────────────────»
# «                                                                      »
# «ancilla_1 -> 6 ───────────────────────────────────────────────────────»
# «                                                                      »
# «                                                                      »
# «      q_4 -> 0 ───────────────────────────────────────────────────────»
# «               ┌──────────┐┌───────────┐┌────┐ ┌──────────┐   ┌────┐  »
# «      q_3 -> 1 ┤ Rz(-π/2) ├┤0          ├┤ √X ├─┤ Rz(3π/4) ├───┤ √X ├──»
# «               └──────────┘│           │└────┘ └──────────┘   └────┘  »
# «      q_2 -> 2 ────────────┤  Acecr_pm ├──────────────────────────────»
# «                           │           │┌───┐ ┌───────────┐┌─────────┐»
# «      q_1 -> 3 ────────────┤1          ├┤ X ├─┤0          ├┤ Rz(π/2) ├»
# «                           └───────────┘└───┘ │           │└─────────┘»
# «ancilla_0 -> 4 ───────────────────────────────┤  Acecr_pm ├───────────»
# «                                              │           │           »
# «      q_0 -> 5 ───────────────────────────────┤1          ├───────────»
# «                                              └───────────┘           »
# «ancilla_1 -> 6 ───────────────────────────────────────────────────────»
# «                                                                      »
# «                                                                   »
# «      q_4 -> 0 ────────────────────────────────────────────────────»
# «               ┌────────┐┌───────────┐┌─────────┐┌────┐┌──────────┐»
# «      q_3 -> 1 ┤ Rz(-π) ├┤0          ├┤ Rz(π/2) ├┤ √X ├┤ Rz(-π/4) ├»
# «               └────────┘│           │└─────────┘└────┘└──────────┘»
# «      q_2 -> 2 ──────────┤  Acecr_pm ├─────────────────────────────»
# «                         │           │ ┌────────┐┌────┐┌─────────┐ »
# «      q_1 -> 3 ──────────┤1          ├─┤ Rz(-π) ├┤ √X ├┤ Rz(π/2) ├─»
# «                         └───────────┘ └────────┘└────┘└─────────┘ »
# «ancilla_0 -> 4 ────────────────────────────────────────────────────»
# «                                                                   »
# «      q_0 -> 5 ────────────────────────────────────────────────────»
# «                                                                   »
# «ancilla_1 -> 6 ────────────────────────────────────────────────────»
# «                                                                   »
# «                                                                          »
# «      q_4 -> 0 ───────────────────────────────────────────────────────────»
# «                   ┌────┐                                                 »
# «      q_3 -> 1 ────┤ √X ├─────────────────────────────────────────────────»
# «                   └────┘                                                 »
# «      q_2 -> 2 ───────────────────────────────────────────────────────────»
# «               ┌───────────┐┌─────────┐┌────┐┌──────────┐┌────┐┌─────────┐»
# «      q_1 -> 3 ┤0          ├┤ Rz(π/2) ├┤ √X ├┤ Rz(-π/4) ├┤ √X ├┤ Rz(π/2) ├»
# «               │           │└─────────┘└────┘└──────────┘└────┘└─────────┘»
# «ancilla_0 -> 4 ┤  Acecr_pm ├──────────────────────────────────────────────»
# «               │           │                                              »
# «      q_0 -> 5 ┤1          ├──────────────────────────────────────────────»
# «               └───────────┘                                              »
# «ancilla_1 -> 6 ───────────────────────────────────────────────────────────»
# «                                                                          »
# «                                                                      »
# «      q_4 -> 0 ───────────────────────────────────────────────────────»
# «               ┌───────────┐┌─────────┐    ┌────┐   ┌──────────┐┌────┐»
# «      q_3 -> 1 ┤0          ├┤ Rz(π/2) ├────┤ √X ├───┤ Rz(-π/4) ├┤ √X ├»
# «               │           │└─────────┘    └────┘   └──────────┘└────┘»
# «      q_2 -> 2 ┤  Acecr_pm ├──────────────────────────────────────────»
# «               │           │   ┌────┐  ┌───────────┐┌─────────┐       »
# «      q_1 -> 3 ┤1          ├───┤ √X ├──┤0          ├┤ Rz(π/2) ├───────»
# «               └───────────┘   └────┘  │           │└─────────┘       »
# «ancilla_0 -> 4 ────────────────────────┤  Acecr_pm ├──────────────────»
# «                                       │           │┌─────────┐ ┌────┐»
# «      q_0 -> 5 ────────────────────────┤1          ├┤ Rz(π/2) ├─┤ √X ├»
# «                                       └───────────┘└─────────┘ └────┘»
# «ancilla_1 -> 6 ───────────────────────────────────────────────────────»
# «                                                                      »
# «
# «      q_4 -> 0 ──────────────────────────────
# «               ┌───────────┐   ┌───┐
# «      q_3 -> 1 ┤0          ├───┤ X ├─────────
# «               │           │   └───┘
# «      q_2 -> 2 ┤  Acecr_pm ├─────────────────
# «               │           │┌─────────┐┌────┐
# «      q_1 -> 3 ┤1          ├┤ Rz(π/2) ├┤ √X ├
# «               └───────────┘└─────────┘└────┘
# «ancilla_0 -> 4 ──────────────────────────────
# «                ┌─────────┐
# «      q_0 -> 5 ─┤ Rz(π/2) ├──────────────────
# «                └─────────┘
# «ancilla_1 -> 6 ──────────────────────────────
# «

# %%
qc_context_pulse.count_ops()
# Out:
# OrderedDict([('rz', 84), ('sx', 63), ('acecr_pm', 31), ('x', 7)])

# %%
qc_orign_pulse = pm_orign_pulse.run(qc)
# Out:
# ccx
# ccx
# ccx
# ccx
# No solution found:  nonexistent solution
# Layout({
# 5: Qubit(QuantumRegister(5, 'q'), 0),
# 3: Qubit(QuantumRegister(5, 'q'), 1),
# 2: Qubit(QuantumRegister(5, 'q'), 2),
# 1: Qubit(QuantumRegister(5, 'q'), 3),
# 0: Qubit(QuantumRegister(5, 'q'), 4)
# })
# The physical qubits for the toffoli are:  0 2 1
# The required toffoli will be decomposed using an 8 cnot decomposition - two in center
# The physical qubits for the toffoli are:  5 3 1
# The required toffoli will be decomposed using an 8 cnot decomposition - one in center
# The physical qubits for the toffoli are:  1 2 0
# The required toffoli will be decomposed using an 8 cnot decomposition - zero in center
# The physical qubits for the toffoli are:  5 3 1
# The required toffoli will be decomposed using an 8 cnot decomposition - one in center
# ('11', '00', 'f')
# ('00', '11', 'b')
# ('11', '00', 'f')
# ('00', '11', 'b')
# ('11', '00', 'f')
# ('00', '11', 'b')
# ('11', '00', 'f')
# ('00', '11', 'b')
# ('11', '00', 'f')
# ('00', '11', 'b')
# ('11', '00', 'f')
# ('00', '11', 'b')
# ('00', '11', 'b')
# ('00', '11', 'b')
# ('00', '11', 'b')
# ('00', '11', 'b')
# ('00', '11', 'b')
# ('00', '11', 'b')
# ('00', '11', 'b')
# ('11', '00', 'f')
# ('00', '11', 'b')
# ('11', '00', 'f')
# ('00', '11', 'b')
# ('11', '00', 'f')
# ('00', '11', 'b')
# ('11', '00', 'f')
# ('00', '11', 'b')
# ('00', '11', 'b')
# ('00', '11', 'b')
# ('00', '11', 'b')
# ('00', '11', 'b')
# ('00', '11', 'b')
# ('00', '11', 'b')
# ('00', '11', 'b')
# ('00', '11', 'b')

# %%
qc_orign_pulse.count_ops()
# Out:
# OrderedDict([('rz', 111), ('sx', 69), ('acecr_pm', 35), ('x', 23)])

# %%
qc_orign_pulse.draw()
# Out:
# global phase: 5π/4
#                   ┌───┐    ┌─────────┐                         ┌───────────┐»
#       q_4 -> 0 ───┤ X ├────┤ Rz(π/4) ├─────────────────────────┤0          ├»
#                ┌──┴───┴──┐ └──┬────┬─┘┌──────────┐    ┌────┐   │  Acecr_pm │»
#       q_3 -> 1 ┤ Rz(π/2) ├────┤ √X ├──┤ Rz(3π/4) ├────┤ √X ├───┤1          ├»
#                ├─────────┴┐   ├────┤  └──────────┘    └────┘   └───────────┘»
#       q_2 -> 2 ┤ Rz(3π/4) ├───┤ √X ├────────────────────────────────────────»
#                ├──────────┤   ├────┤              ┌───────────┐    ┌───┐    »
#       q_1 -> 3 ┤ Rz(3π/4) ├───┤ √X ├──────────────┤0          ├────┤ X ├────»
#                └──────────┘   └────┘              │           │    └───┘    »
# ancilla_0 -> 4 ───────────────────────────────────┤  Acecr_pm ├─────────────»
#                 ┌────────┐    ┌────┐  ┌─────────┐ │           │  ┌────────┐ »
#       q_0 -> 5 ─┤ Rz(-π) ├────┤ √X ├──┤ Rz(π/2) ├─┤1          ├──┤ Rz(-π) ├─»
#                 └────────┘    └────┘  └─────────┘ └───────────┘  └────────┘ »
# ancilla_1 -> 6 ─────────────────────────────────────────────────────────────»
#                                                                             »
# «                  ┌───┐   ┌─────────┐                                   »
# «      q_4 -> 0 ───┤ X ├───┤ Rz(π/2) ├───────────────────────────────────»
# «               ┌──┴───┴──┐└──┬────┬─┘┌─────────┐┌───────────┐   ┌───┐   »
# «      q_3 -> 1 ┤ Rz(π/2) ├───┤ √X ├──┤ Rz(π/2) ├┤1          ├───┤ X ├───»
# «               └─────────┘   └────┘  └─────────┘│  Acecr_pm │┌──┴───┴──┐»
# «      q_2 -> 2 ─────────────────────────────────┤0          ├┤ Rz(π/2) ├»
# «                                                └───────────┘└─────────┘»
# «      q_1 -> 3 ─────────────────────────────────────────────────────────»
# «                                                                        »
# «ancilla_0 -> 4 ─────────────────────────────────────────────────────────»
# «                  ┌────┐   ┌────────┐                                   »
# «      q_0 -> 5 ───┤ √X ├───┤ Rz(-π) ├───────────────────────────────────»
# «                  └────┘   └────────┘                                   »
# «ancilla_1 -> 6 ─────────────────────────────────────────────────────────»
# «                                                                        »
# «                           ┌───────────┐   ┌───┐   ┌─────────┐           »
# «      q_4 -> 0 ────────────┤0          ├───┤ X ├───┤ Rz(π/2) ├───────────»
# «               ┌──────────┐│  Acecr_pm │┌──┴───┴──┐└──┬────┬─┘┌─────────┐»
# «      q_3 -> 1 ┤ Rz(-π/2) ├┤1          ├┤ Rz(π/2) ├───┤ √X ├──┤ Rz(π/2) ├»
# «               └──┬────┬──┘└┬─────────┬┘└──┬────┬─┘   └────┘  └─────────┘»
# «      q_2 -> 2 ───┤ √X ├────┤ Rz(π/4) ├────┤ √X ├────────────────────────»
# «                  └────┘    └─────────┘    └────┘                        »
# «      q_1 -> 3 ──────────────────────────────────────────────────────────»
# «                                                                         »
# «ancilla_0 -> 4 ──────────────────────────────────────────────────────────»
# «                                                                         »
# «      q_0 -> 5 ──────────────────────────────────────────────────────────»
# «                                                                         »
# «ancilla_1 -> 6 ──────────────────────────────────────────────────────────»
# «                                                                         »
# «                                                   ┌───────────┐   ┌───┐   »
# «      q_4 -> 0 ────────────────────────────────────┤0          ├───┤ X ├───»
# «               ┌───────────┐   ┌───┐   ┌──────────┐│  Acecr_pm │┌──┴───┴──┐»
# «      q_3 -> 1 ┤1          ├───┤ X ├───┤ Rz(-π/2) ├┤1          ├┤ Rz(π/4) ├»
# «               │  Acecr_pm │┌──┴───┴──┐└──┬────┬──┘└┬──────────┤└──┬────┬─┘»
# «      q_2 -> 2 ┤0          ├┤ Rz(π/2) ├───┤ √X ├────┤ Rz(-π/4) ├───┤ √X ├──»
# «               └───────────┘└─────────┘   └────┘    └──────────┘   └────┘  »
# «      q_1 -> 3 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_0 -> 4 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «      q_0 -> 5 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_1 -> 6 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «               ┌─────────┐                                               »
# «      q_4 -> 0 ┤ Rz(π/2) ├───────────────────────────────────────────────»
# «               └──┬────┬─┘┌─────────┐┌───────────┐   ┌───┐   ┌──────────┐»
# «      q_3 -> 1 ───┤ √X ├──┤ Rz(π/2) ├┤1          ├───┤ X ├───┤ Rz(-π/2) ├»
# «                  └────┘  └─────────┘│  Acecr_pm │┌──┴───┴──┐└──┬────┬──┘»
# «      q_2 -> 2 ──────────────────────┤0          ├┤ Rz(π/2) ├───┤ √X ├───»
# «                                     └───────────┘└─────────┘   └────┘   »
# «      q_1 -> 3 ──────────────────────────────────────────────────────────»
# «                                                                         »
# «ancilla_0 -> 4 ──────────────────────────────────────────────────────────»
# «                                                                         »
# «      q_0 -> 5 ──────────────────────────────────────────────────────────»
# «                                                                         »
# «ancilla_1 -> 6 ──────────────────────────────────────────────────────────»
# «                                                                         »
# «               ┌───────────┐   ┌───┐   ┌─────────┐                        »
# «      q_4 -> 0 ┤0          ├───┤ X ├───┤ Rz(π/2) ├────────────────────────»
# «               │  Acecr_pm │┌──┴───┴──┐└──┬────┬─┘┌─────────┐┌───────────┐»
# «      q_3 -> 1 ┤1          ├┤ Rz(π/2) ├───┤ √X ├──┤ Rz(π/2) ├┤1          ├»
# «               └┬──────────┤└──┬────┬─┘   └────┘  └─────────┘│  Acecr_pm │»
# «      q_2 -> 2 ─┤ Rz(-π/4) ├───┤ √X ├────────────────────────┤0          ├»
# «                └──────────┘   └────┘                        └───────────┘»
# «      q_1 -> 3 ───────────────────────────────────────────────────────────»
# «                                                                          »
# «ancilla_0 -> 4 ───────────────────────────────────────────────────────────»
# «                                                                          »
# «      q_0 -> 5 ───────────────────────────────────────────────────────────»
# «                                                                          »
# «ancilla_1 -> 6 ───────────────────────────────────────────────────────────»
# «                                                                          »
# «               ┌───────────┐┌─────────┐   ┌────┐              ┌───────────┐»
# «      q_4 -> 0 ┤0          ├┤ Rz(π/2) ├───┤ √X ├──────────────┤0          ├»
# «               │  Acecr_pm │├─────────┤   ├────┤   ┌─────────┐│  Acecr_pm │»
# «      q_3 -> 1 ┤1          ├┤ Rz(π/2) ├───┤ √X ├───┤ Rz(π/2) ├┤1          ├»
# «               └┬──────────┤└──┬────┬─┘┌──┴────┴──┐└─────────┘└───────────┘»
# «      q_2 -> 2 ─┤ Rz(-π/2) ├───┤ √X ├──┤ Rz(-π/4) ├────────────────────────»
# «                └──────────┘   └────┘  └──────────┘                        »
# «      q_1 -> 3 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_0 -> 4 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «      q_0 -> 5 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_1 -> 6 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «               ┌──────────┐   ┌────┐   ┌───────────┐┌─────────┐┌────┐»
# «      q_4 -> 0 ┤ Rz(-π/2) ├───┤ √X ├───┤0          ├┤ Rz(π/2) ├┤ √X ├»
# «               └──┬───┬───┘┌──┴────┴──┐│  Acecr_pm │├─────────┤├────┤»
# «      q_3 -> 1 ───┤ X ├────┤ Rz(-π/2) ├┤1          ├┤ Rz(π/2) ├┤ √X ├»
# «                  └───┘    └──────────┘└───────────┘└─────────┘└────┘»
# «      q_2 -> 2 ──────────────────────────────────────────────────────»
# «                                                                     »
# «      q_1 -> 3 ──────────────────────────────────────────────────────»
# «                                                                     »
# «ancilla_0 -> 4 ──────────────────────────────────────────────────────»
# «                                                                     »
# «      q_0 -> 5 ──────────────────────────────────────────────────────»
# «                                                                     »
# «ancilla_1 -> 6 ──────────────────────────────────────────────────────»
# «                                                                     »
# «               ┌───────────┐┌────┐                                         »
# «      q_4 -> 0 ┤ Rz(-3π/4) ├┤ √X ├─────────────────────────────────────────»
# «               ├───────────┤├────┤┌───────────┐┌─────────┐┌────┐┌─────────┐»
# «      q_3 -> 1 ┤ Rz(-3π/4) ├┤ √X ├┤0          ├┤ Rz(π/2) ├┤ √X ├┤ Rz(π/4) ├»
# «               └───────────┘└────┘│           │└─────────┘└────┘└─────────┘»
# «      q_2 -> 2 ───────────────────┤  Acecr_pm ├────────────────────────────»
# «                                  │           │ ┌────────┐┌────┐┌─────────┐»
# «      q_1 -> 3 ───────────────────┤1          ├─┤ Rz(-π) ├┤ √X ├┤ Rz(π/2) ├»
# «                                  └───────────┘ └────────┘└────┘└─────────┘»
# «ancilla_0 -> 4 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «      q_0 -> 5 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_1 -> 6 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «                                                                    »
# «      q_4 -> 0 ─────────────────────────────────────────────────────»
# «                   ┌────┐             ┌───────────┐┌─────────┐┌────┐»
# «      q_3 -> 1 ────┤ √X ├─────────────┤0          ├┤ Rz(π/2) ├┤ √X ├»
# «                   └────┘             │           │└─────────┘└────┘»
# «      q_2 -> 2 ───────────────────────┤  Acecr_pm ├─────────────────»
# «               ┌───────────┐  ┌───┐   │           │ ┌────────┐┌────┐»
# «      q_1 -> 3 ┤0          ├──┤ X ├───┤1          ├─┤ Rz(-π) ├┤ √X ├»
# «               │           │  └───┘   └───────────┘ └────────┘└────┘»
# «ancilla_0 -> 4 ┤  Acecr_pm ├────────────────────────────────────────»
# «               │           │┌────────┐    ┌────┐    ┌────────┐      »
# «      q_0 -> 5 ┤1          ├┤ Rz(-π) ├────┤ √X ├────┤ Rz(-π) ├──────»
# «               └───────────┘└────────┘    └────┘    └────────┘      »
# «ancilla_1 -> 6 ─────────────────────────────────────────────────────»
# «                                                                    »
# «                                                                           »
# «      q_4 -> 0 ────────────────────────────────────────────────────────────»
# «               ┌──────────┐    ┌────┐                                      »
# «      q_3 -> 1 ┤ Rz(-π/4) ├────┤ √X ├──────────────────────────────────────»
# «               └──────────┘    └────┘                                      »
# «      q_2 -> 2 ────────────────────────────────────────────────────────────»
# «               ┌─────────┐ ┌───────────┐┌─────────┐┌────┐┌──────────┐┌────┐»
# «      q_1 -> 3 ┤ Rz(π/2) ├─┤0          ├┤ Rz(π/2) ├┤ √X ├┤ Rz(-π/4) ├┤ √X ├»
# «               └─────────┘ │           │└─────────┘└────┘└──────────┘└────┘»
# «ancilla_0 -> 4 ────────────┤  Acecr_pm ├───────────────────────────────────»
# «                           │           │ ┌────────┐┌────┐ ┌────────┐       »
# «      q_0 -> 5 ────────────┤1          ├─┤ Rz(-π) ├┤ √X ├─┤ Rz(-π) ├───────»
# «                           └───────────┘ └────────┘└────┘ └────────┘       »
# «ancilla_1 -> 6 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «                                                                    »
# «      q_4 -> 0 ─────────────────────────────────────────────────────»
# «                          ┌───────────┐┌─────────┐┌────┐┌──────────┐»
# «      q_3 -> 1 ───────────┤0          ├┤ Rz(π/2) ├┤ √X ├┤ Rz(-π/4) ├»
# «                          │           │└─────────┘└────┘└──────────┘»
# «      q_2 -> 2 ───────────┤  Acecr_pm ├─────────────────────────────»
# «               ┌─────────┐│           │ ┌────────┐┌────┐┌─────────┐ »
# «      q_1 -> 3 ┤ Rz(π/2) ├┤1          ├─┤ Rz(-π) ├┤ √X ├┤ Rz(π/2) ├─»
# «               └─────────┘└───────────┘ └────────┘└────┘└─────────┘ »
# «ancilla_0 -> 4 ─────────────────────────────────────────────────────»
# «                                                                    »
# «      q_0 -> 5 ─────────────────────────────────────────────────────»
# «                                                                    »
# «ancilla_1 -> 6 ─────────────────────────────────────────────────────»
# «                                                                    »
# «                                                                     »
# «      q_4 -> 0 ──────────────────────────────────────────────────────»
# «                   ┌────┐             ┌───────────┐┌──────────┐┌────┐»
# «      q_3 -> 1 ────┤ √X ├─────────────┤0          ├┤ Rz(3π/4) ├┤ √X ├»
# «                   └────┘             │           │└──────────┘└────┘»
# «      q_2 -> 2 ───────────────────────┤  Acecr_pm ├──────────────────»
# «               ┌───────────┐  ┌───┐   │           │┌─────────┐ ┌────┐»
# «      q_1 -> 3 ┤0          ├──┤ X ├───┤1          ├┤ Rz(π/2) ├─┤ √X ├»
# «               │           │  └───┘   └───────────┘└─────────┘ └────┘»
# «ancilla_0 -> 4 ┤  Acecr_pm ├─────────────────────────────────────────»
# «               │           │┌────────┐    ┌────┐    ┌────────┐       »
# «      q_0 -> 5 ┤1          ├┤ Rz(-π) ├────┤ √X ├────┤ Rz(-π) ├───────»
# «               └───────────┘└────────┘    └────┘    └────────┘       »
# «ancilla_1 -> 6 ──────────────────────────────────────────────────────»
# «                                                                     »
# «                                                                           »
# «      q_4 -> 0 ────────────────────────────────────────────────────────────»
# «                ┌────────┐ ┌───────────┐ ┌─────────┐    ┌────┐  ┌─────────┐»
# «      q_3 -> 1 ─┤ Rz(-π) ├─┤1          ├─┤ Rz(π/2) ├────┤ √X ├──┤ Rz(π/2) ├»
# «                └────────┘ │  Acecr_pm │ └──┬───┬──┘ ┌──┴────┴─┐└─────────┘»
# «      q_2 -> 2 ────────────┤0          ├────┤ X ├────┤ Rz(π/2) ├───────────»
# «               ┌──────────┐└───┬────┬──┘┌───┴───┴───┐└──┬───┬──┘           »
# «      q_1 -> 3 ┤ Rz(3π/4) ├────┤ √X ├───┤0          ├───┤ X ├──────────────»
# «               └──────────┘    └────┘   │           │   └───┘              »
# «ancilla_0 -> 4 ─────────────────────────┤  Acecr_pm ├──────────────────────»
# «                                        │           │ ┌────────┐   ┌────┐  »
# «      q_0 -> 5 ─────────────────────────┤1          ├─┤ Rz(-π) ├───┤ √X ├──»
# «                                        └───────────┘ └────────┘   └────┘  »
# «ancilla_1 -> 6 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «               ┌───────────┐┌─────────┐   ┌────┐    ┌─────────┐    ┌────┐  »
# «      q_4 -> 0 ┤0          ├┤ Rz(π/2) ├───┤ √X ├────┤ Rz(π/4) ├────┤ √X ├──»
# «               │  Acecr_pm │└──┬───┬──┘┌──┴────┴──┐┌┴─────────┴┐┌──┴────┴─┐»
# «      q_3 -> 1 ┤1          ├───┤ X ├───┤ Rz(-π/2) ├┤1          ├┤ Rz(π/2) ├»
# «               └───────────┘   └───┘   └──────────┘│  Acecr_pm │└──┬───┬──┘»
# «      q_2 -> 2 ────────────────────────────────────┤0          ├───┤ X ├───»
# «                                                   └───────────┘   └───┘   »
# «      q_1 -> 3 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_0 -> 4 ────────────────────────────────────────────────────────────»
# «                 ┌────────┐                                                »
# «      q_0 -> 5 ──┤ Rz(-π) ├────────────────────────────────────────────────»
# «                 └────────┘                                                »
# «ancilla_1 -> 6 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «                                     ┌───────────┐┌─────────┐   ┌────┐   »
# «      q_4 -> 0 ──────────────────────┤0          ├┤ Rz(π/2) ├───┤ √X ├───»
# «                  ┌────┐  ┌─────────┐│  Acecr_pm │└──┬───┬──┘┌──┴────┴──┐»
# «      q_3 -> 1 ───┤ √X ├──┤ Rz(π/2) ├┤1          ├───┤ X ├───┤ Rz(-π/2) ├»
# «               ┌──┴────┴─┐└─────────┘└───────────┘   └───┘   └──────────┘»
# «      q_2 -> 2 ┤ Rz(π/2) ├───────────────────────────────────────────────»
# «               └─────────┘                                               »
# «      q_1 -> 3 ──────────────────────────────────────────────────────────»
# «                                                                         »
# «ancilla_0 -> 4 ──────────────────────────────────────────────────────────»
# «                                                                         »
# «      q_0 -> 5 ──────────────────────────────────────────────────────────»
# «                                                                         »
# «ancilla_1 -> 6 ──────────────────────────────────────────────────────────»
# «                                                                         »
# «                ┌──────────┐   ┌────┐                        ┌───────────┐»
# «      q_4 -> 0 ─┤ Rz(-π/4) ├───┤ √X ├────────────────────────┤0          ├»
# «               ┌┴──────────┤┌──┴────┴─┐   ┌────┐  ┌─────────┐│  Acecr_pm │»
# «      q_3 -> 1 ┤1          ├┤ Rz(π/4) ├───┤ √X ├──┤ Rz(π/2) ├┤1          ├»
# «               │  Acecr_pm │└──┬───┬──┘┌──┴────┴─┐└─────────┘└───────────┘»
# «      q_2 -> 2 ┤0          ├───┤ X ├───┤ Rz(π/2) ├────────────────────────»
# «               └───────────┘   └───┘   └─────────┘                        »
# «      q_1 -> 3 ───────────────────────────────────────────────────────────»
# «                                                                          »
# «ancilla_0 -> 4 ───────────────────────────────────────────────────────────»
# «                                                                          »
# «      q_0 -> 5 ───────────────────────────────────────────────────────────»
# «                                                                          »
# «ancilla_1 -> 6 ───────────────────────────────────────────────────────────»
# «                                                                          »
# «               ┌─────────┐   ┌────┐    ┌──────────┐   ┌────┐        »
# «      q_4 -> 0 ┤ Rz(π/2) ├───┤ √X ├────┤ Rz(-π/4) ├───┤ √X ├────────»
# «               └──┬───┬──┘┌──┴────┴──┐┌┴──────────┤┌──┴────┴─┐┌────┐»
# «      q_3 -> 1 ───┤ X ├───┤ Rz(-π/2) ├┤1          ├┤ Rz(π/2) ├┤ √X ├»
# «                  └───┘   └──────────┘│  Acecr_pm │└─────────┘└────┘»
# «      q_2 -> 2 ───────────────────────┤0          ├─────────────────»
# «                                      └───────────┘                 »
# «      q_1 -> 3 ─────────────────────────────────────────────────────»
# «                                                                    »
# «ancilla_0 -> 4 ─────────────────────────────────────────────────────»
# «                                                                    »
# «      q_0 -> 5 ─────────────────────────────────────────────────────»
# «                                                                    »
# «ancilla_1 -> 6 ─────────────────────────────────────────────────────»
# «                                                                    »
# «                          ┌───────────┐┌───┐                            »
# «      q_4 -> 0 ───────────┤0          ├┤ X ├────────────────────────────»
# «               ┌─────────┐│  Acecr_pm │├───┴┐┌─────────┐┌────┐┌────────┐»
# «      q_3 -> 1 ┤ Rz(π/2) ├┤1          ├┤ √X ├┤ Rz(π/4) ├┤ √X ├┤ Rz(-π) ├»
# «               └─────────┘└───────────┘└────┘└─────────┘└────┘└────────┘»
# «      q_2 -> 2 ─────────────────────────────────────────────────────────»
# «                                                                        »
# «      q_1 -> 3 ─────────────────────────────────────────────────────────»
# «                                                                        »
# «ancilla_0 -> 4 ─────────────────────────────────────────────────────────»
# «                                                                        »
# «      q_0 -> 5 ─────────────────────────────────────────────────────────»
# «                                                                        »
# «ancilla_1 -> 6 ─────────────────────────────────────────────────────────»
# «                                                                        »
# «                                                                     »
# «      q_4 -> 0 ──────────────────────────────────────────────────────»
# «               ┌───────────┐┌─────────┐┌────┐┌─────────┐    ┌────┐   »
# «      q_3 -> 1 ┤0          ├┤ Rz(π/2) ├┤ √X ├┤ Rz(π/4) ├────┤ √X ├───»
# «               │           │└─────────┘└────┘└─────────┘    └────┘   »
# «      q_2 -> 2 ┤  Acecr_pm ├─────────────────────────────────────────»
# «               │           │ ┌────────┐┌────┐┌─────────┐┌───────────┐»
# «      q_1 -> 3 ┤1          ├─┤ Rz(-π) ├┤ √X ├┤ Rz(π/2) ├┤0          ├»
# «               └───────────┘ └────────┘└────┘└─────────┘│           │»
# «ancilla_0 -> 4 ─────────────────────────────────────────┤  Acecr_pm ├»
# «                                                        │           │»
# «      q_0 -> 5 ─────────────────────────────────────────┤1          ├»
# «                                                        └───────────┘»
# «ancilla_1 -> 6 ──────────────────────────────────────────────────────»
# «                                                                     »
# «                                                                   »
# «      q_4 -> 0 ────────────────────────────────────────────────────»
# «                         ┌───────────┐┌─────────┐┌────┐┌──────────┐»
# «      q_3 -> 1 ──────────┤0          ├┤ Rz(π/2) ├┤ √X ├┤ Rz(-π/4) ├»
# «                         │           │└─────────┘└────┘└──────────┘»
# «      q_2 -> 2 ──────────┤  Acecr_pm ├─────────────────────────────»
# «                 ┌───┐   │           │ ┌────────┐┌────┐┌─────────┐ »
# «      q_1 -> 3 ──┤ X ├───┤1          ├─┤ Rz(-π) ├┤ √X ├┤ Rz(π/2) ├─»
# «                 └───┘   └───────────┘ └────────┘└────┘└─────────┘ »
# «ancilla_0 -> 4 ────────────────────────────────────────────────────»
# «               ┌────────┐    ┌────┐    ┌────────┐                  »
# «      q_0 -> 5 ┤ Rz(-π) ├────┤ √X ├────┤ Rz(-π) ├──────────────────»
# «               └────────┘    └────┘    └────────┘                  »
# «ancilla_1 -> 6 ────────────────────────────────────────────────────»
# «                                                                   »
# «                                                                          »
# «      q_4 -> 0 ───────────────────────────────────────────────────────────»
# «                   ┌────┐                                                 »
# «      q_3 -> 1 ────┤ √X ├─────────────────────────────────────────────────»
# «                   └────┘                                                 »
# «      q_2 -> 2 ───────────────────────────────────────────────────────────»
# «               ┌───────────┐┌─────────┐┌────┐┌──────────┐┌────┐┌─────────┐»
# «      q_1 -> 3 ┤0          ├┤ Rz(π/2) ├┤ √X ├┤ Rz(-π/4) ├┤ √X ├┤ Rz(π/2) ├»
# «               │           │└─────────┘└────┘└──────────┘└────┘└─────────┘»
# «ancilla_0 -> 4 ┤  Acecr_pm ├──────────────────────────────────────────────»
# «               │           │ ┌────────┐┌────┐ ┌────────┐                  »
# «      q_0 -> 5 ┤1          ├─┤ Rz(-π) ├┤ √X ├─┤ Rz(-π) ├──────────────────»
# «               └───────────┘ └────────┘└────┘ └────────┘                  »
# «ancilla_1 -> 6 ───────────────────────────────────────────────────────────»
# «                                                                          »
# «                                                                      »
# «      q_4 -> 0 ───────────────────────────────────────────────────────»
# «               ┌───────────┐┌─────────┐┌────┐┌──────────┐    ┌────┐   »
# «      q_3 -> 1 ┤0          ├┤ Rz(π/2) ├┤ √X ├┤ Rz(-π/4) ├────┤ √X ├───»
# «               │           │└─────────┘└────┘└──────────┘    └────┘   »
# «      q_2 -> 2 ┤  Acecr_pm ├──────────────────────────────────────────»
# «               │           │ ┌────────┐┌────┐┌─────────┐ ┌───────────┐»
# «      q_1 -> 3 ┤1          ├─┤ Rz(-π) ├┤ √X ├┤ Rz(π/2) ├─┤0          ├»
# «               └───────────┘ └────────┘└────┘└─────────┘ │           │»
# «ancilla_0 -> 4 ──────────────────────────────────────────┤  Acecr_pm ├»
# «                                                         │           │»
# «      q_0 -> 5 ──────────────────────────────────────────┤1          ├»
# «                                                         └───────────┘»
# «ancilla_1 -> 6 ───────────────────────────────────────────────────────»
# «                                                                      »
# «
# «      q_4 -> 0 ─────────────────────────────────────────
# «                          ┌───────────┐   ┌───┐
# «      q_3 -> 1 ───────────┤0          ├───┤ X ├─────────
# «                          │           │   └───┘
# «      q_2 -> 2 ───────────┤  Acecr_pm ├─────────────────
# «                  ┌───┐   │           │┌─────────┐┌────┐
# «      q_1 -> 3 ───┤ X ├───┤1          ├┤ Rz(π/2) ├┤ √X ├
# «                  └───┘   └───────────┘└─────────┘└────┘
# «ancilla_0 -> 4 ─────────────────────────────────────────
# «               ┌─────────┐    ┌────┐
# «      q_0 -> 5 ┤ Rz(π/2) ├────┤ √X ├────────────────────
# «               └─────────┘    └────┘
# «ancilla_1 -> 6 ─────────────────────────────────────────
# «

# %%
qc_context = pm_context.run(qc)
# Out:
# ccx
# ccx
# ccx
# ccx
# No solution found:  nonexistent solution
# Layout({
# 5: Qubit(QuantumRegister(5, 'q'), 0),
# 3: Qubit(QuantumRegister(5, 'q'), 1),
# 2: Qubit(QuantumRegister(5, 'q'), 2),
# 1: Qubit(QuantumRegister(5, 'q'), 3),
# 0: Qubit(QuantumRegister(5, 'q'), 4)
# })
# The physical qubits for the toffoli are:  0 2 1
# The required toffoli will be decomposed using an 8 cnot decomposition - two in center
# ccx
# three intersection conditions False True False
# three qargs Qubit(QuantumRegister(7, 'q'), 0) Qubit(QuantumRegister(7, 'q'), 2) Qubit(QuantumRegister(7, 'q'), 1)
# calculated tags ['00', '00', 'l2', 'p'] ['00', '00', 'l2', 'p']
# swap
# successor swap two intersection conditions:TrueTrue
# initialized variant_tag: ('00', '02', 'l2', 's')
# The physical qubits for the toffoli are:  5 3 1
# The required toffoli will be decomposed using an 8 cnot decomposition - one in center
# ccx
# three intersection conditions True True False
# three qargs Qubit(QuantumRegister(7, 'q'), 5) Qubit(QuantumRegister(7, 'q'), 3) Qubit(QuantumRegister(7, 'q'), 1)
# calculated tags ['00', '01', 'l1', 's'] ['01', '00', 'l1', 'p']
# initialized variant_tag: ('01', '00', 'l1', 'p')
# initialized variant_tag: ('00', '01', 'l1', 's')
# The physical qubits for the toffoli are:  1 2 0
# The required toffoli will be decomposed using an 8 cnot decomposition - zero in center
# ccx_variant
# None
# None
# predecessor swap two intersection conditions:FalseTrue
# initialized variant_tag: ('00', '00', 'l0', 'p')
# look for variant_rules ('00', '02', 'l2', 's')
# final tag, one match ('21', '02', 'l2', 's')
# look for variant_rules ('00', '01', 'l1', 's')
# final tag, one match ('12', '01', 'l1', 's')
# look for variant_rules ('00', '00', 'l0', 'p')
# didn't find match tag
# l0 ['00', '00', 'l0', 'p']
# look for variant_rules ('01', '00', 'l1', 'p')
# final tag, one match ('01', '12', 'l1', 'p')

# %%
qc_context.draw(output = 'mpl')
# Out:
# /Users/revilooliver/Documents/quantum_computing/anaconda/anaconda3/envs/qiskit-terra/lib/python3.7/site-packages/sympy/core/expr.py:3951: SymPyDeprecationWarning:
#
# expr_free_symbols method has been deprecated since SymPy 1.9. See
# https://github.com/sympy/sympy/issues/21494 for more info.
#
#   deprecated_since_version="1.9").warn()

# %%
qc_context.count_ops()
# Out:
# OrderedDict([('rz', 35), ('cx', 31), ('sx', 11), ('x', 1)])

# %%
qc_orign = pm_orign.run(qc)
# Out:
# ccx
# ccx
# ccx
# ccx
# No solution found:  nonexistent solution
# Layout({
# 5: Qubit(QuantumRegister(5, 'q'), 0),
# 3: Qubit(QuantumRegister(5, 'q'), 1),
# 2: Qubit(QuantumRegister(5, 'q'), 2),
# 1: Qubit(QuantumRegister(5, 'q'), 3),
# 0: Qubit(QuantumRegister(5, 'q'), 4)
# })
# The physical qubits for the toffoli are:  0 2 1
# The required toffoli will be decomposed using an 8 cnot decomposition - two in center
# The physical qubits for the toffoli are:  5 3 1
# The required toffoli will be decomposed using an 8 cnot decomposition - one in center
# The physical qubits for the toffoli are:  1 2 0
# The required toffoli will be decomposed using an 8 cnot decomposition - zero in center
# The physical qubits for the toffoli are:  5 3 1
# The required toffoli will be decomposed using an 8 cnot decomposition - one in center

# %%
qc_orign.count_ops()
# Out:
# OrderedDict([('rz', 38), ('cx', 35), ('sx', 8)])

# %%
qc_orign.draw(output='mpl')

# %%
from qiskit_superstaq.superstaq_provider import SuperstaQProvider
import cirq

# %%
superstaq_provider = SuperstaQProvider(api_key="ya29.A0ARrdaM-BWPjpkjhKgbVSRwWROaVE3g6mKCew2all4yXuPNLIwc6l65K10DiAMa-w8he0mR-i0Tb_jE6-GqqWlscj9Zq58rC2oSSzRVaLdZJMoy2bWqIXVhK3Tehp5N4zd8uHhyp01G9KC90Xmu3BKALiGiLP-w")

# %%
orign_pulse_out = superstaq_provider.ibmq_compile(qc_orign_pulse, target="ibmq_jakarta_qpu")

# %%
context_pulse_out = superstaq_provider.ibmq_compile(qc_context_pulse, target="ibmq_jakarta_qpu")

# %%
orign_pulse_out.pulse_sequence.draw()

# %%
context_pulse_out.pulse_sequence.draw()

# %%
orign_pulse_out.circuit.draw()
# Out:
#      ┌──────────┐   ┌───┐                                     ┌───────────┐»
# q_0: ┤ Rz(7π/4) ├───┤ X ├─────────────────────────────────────┤0          ├»
#      ├──────────┤┌──┴───┴──┐┌──────────┐ ┌─────────┐ ┌───────┐│  Acecr_pm │»
# q_1: ┤ Rz(3π/2) ├┤ Rx(π/2) ├┤ Rz(5π/4) ├─┤ Rx(π/2) ├─┤ Rz(π) ├┤1          ├»
#      ├──────────┤├─────────┤└──────────┘ └─────────┘ └───────┘└───────────┘»
# q_2: ┤ Rz(3π/4) ├┤ Rx(π/2) ├───────────────────────────────────────────────»
#      ├──────────┤├─────────┤            ┌───────────┐  ┌───┐               »
# q_3: ┤ Rz(3π/4) ├┤ Rx(π/2) ├────────────┤0          ├──┤ X ├───────────────»
#      └──────────┘└─────────┘            │           │  └───┘               »
# q_4: ───────────────────────────────────┤  Acecr_pm ├──────────────────────»
#       ┌───────┐  ┌─────────┐┌─────────┐ │           │┌───────┐ ┌─────────┐ »
# q_5: ─┤ Rz(π) ├──┤ Rx(π/2) ├┤ Rz(π/2) ├─┤1          ├┤ Rz(π) ├─┤ Rx(π/2) ├─»
#       └───────┘  └─────────┘└─────────┘ └───────────┘└───────┘ └─────────┘ »
# «     ┌──────────┐   ┌───┐                                                  »
# «q_0: ┤ Rz(3π/2) ├───┤ X ├──────────────────────────────────────────────────»
# «     ├─────────┬┘┌──┴───┴──┐┌─────────┐┌───────────┐┌─────────┐    ┌───┐   »
# «q_1: ┤ Rz(π/2) ├─┤ Rx(π/2) ├┤ Rz(π/2) ├┤1          ├┤ Rz(π/2) ├────┤ X ├───»
# «     └─────────┘ └─────────┘└─────────┘│  Acecr_pm │├─────────┴┐┌──┴───┴──┐»
# «q_2: ──────────────────────────────────┤0          ├┤ Rz(3π/2) ├┤ Rx(π/2) ├»
# «                                       └───────────┘└──────────┘└─────────┘»
# «q_3: ──────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «q_4: ──────────────────────────────────────────────────────────────────────»
# «      ┌───────┐                                                            »
# «q_5: ─┤ Rz(π) ├────────────────────────────────────────────────────────────»
# «      └───────┘                                                            »
# «     ┌───────────┐┌──────────┐   ┌───┐                                      »
# «q_0: ┤0          ├┤ Rz(3π/2) ├───┤ X ├──────────────────────────────────────»
# «     │  Acecr_pm │├─────────┬┘┌──┴───┴──┐┌─────────┐┌───────────┐┌─────────┐»
# «q_1: ┤1          ├┤ Rz(π/2) ├─┤ Rx(π/2) ├┤ Rz(π/2) ├┤1          ├┤ Rz(π/2) ├»
# «     └┬──────────┤├─────────┤ └┬───────┬┘└─────────┘│  Acecr_pm │├─────────┤»
# «q_2: ─┤ Rz(7π/4) ├┤ Rx(π/2) ├──┤ Rz(π) ├────────────┤0          ├┤ Rz(π/2) ├»
# «      └──────────┘└─────────┘  └───────┘            └───────────┘└─────────┘»
# «q_3: ───────────────────────────────────────────────────────────────────────»
# «                                                                            »
# «q_4: ───────────────────────────────────────────────────────────────────────»
# «                                                                            »
# «q_5: ───────────────────────────────────────────────────────────────────────»
# «                                                                            »
# «                ┌───────────┐┌──────────┐   ┌───┐                           »
# «q_0: ───────────┤0          ├┤ Rz(3π/2) ├───┤ X ├───────────────────────────»
# «        ┌───┐   │  Acecr_pm │├─────────┬┘┌──┴───┴──┐┌─────────┐┌───────────┐»
# «q_1: ───┤ X ├───┤1          ├┤ Rz(π/4) ├─┤ Rx(π/2) ├┤ Rz(π/2) ├┤1          ├»
# «     ┌──┴───┴──┐└┬──────────┤├─────────┤ └─────────┘└─────────┘│  Acecr_pm │»
# «q_2: ┤ Rx(π/2) ├─┤ Rz(7π/4) ├┤ Rx(π/2) ├───────────────────────┤0          ├»
# «     └─────────┘ └──────────┘└─────────┘                       └───────────┘»
# «q_3: ───────────────────────────────────────────────────────────────────────»
# «                                                                            »
# «q_4: ───────────────────────────────────────────────────────────────────────»
# «                                                                            »
# «q_5: ───────────────────────────────────────────────────────────────────────»
# «                                                                            »
# «                           ┌───────────┐┌──────────┐   ┌───┐              »
# «q_0: ──────────────────────┤0          ├┤ Rz(3π/2) ├───┤ X ├──────────────»
# «     ┌─────────┐   ┌───┐   │  Acecr_pm │├─────────┬┘┌──┴───┴──┐┌─────────┐»
# «q_1: ┤ Rz(π/2) ├───┤ X ├───┤1          ├┤ Rz(π/2) ├─┤ Rx(π/2) ├┤ Rz(π/2) ├»
# «     ├─────────┤┌──┴───┴──┐└┬──────────┤├─────────┤ └─────────┘└─────────┘»
# «q_2: ┤ Rz(π/2) ├┤ Rx(π/2) ├─┤ Rz(7π/4) ├┤ Rx(π/2) ├───────────────────────»
# «     └─────────┘└─────────┘ └──────────┘└─────────┘                       »
# «q_3: ─────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_4: ─────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_5: ─────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «                  ┌───────────┐┌─────────┐┌─────────┐            ┌───────────┐»
# «q_0: ─────────────┤0          ├┤ Rz(π/2) ├┤ Rx(π/2) ├────────────┤0          ├»
# «     ┌───────────┐│  Acecr_pm │├─────────┤├─────────┤ ┌─────────┐│  Acecr_pm │»
# «q_1: ┤1          ├┤1          ├┤ Rz(π/2) ├┤ Rx(π/2) ├─┤ Rz(π/2) ├┤1          ├»
# «     │  Acecr_pm │└┬──────────┤├─────────┤├─────────┴┐└─────────┘└───────────┘»
# «q_2: ┤0          ├─┤ Rz(3π/2) ├┤ Rx(π/2) ├┤ Rz(7π/4) ├────────────────────────»
# «     └───────────┘ └──────────┘└─────────┘└──────────┘                        »
# «q_3: ─────────────────────────────────────────────────────────────────────────»
# «                                                                              »
# «q_4: ─────────────────────────────────────────────────────────────────────────»
# «                                                                              »
# «q_5: ─────────────────────────────────────────────────────────────────────────»
# «                                                                              »
# «     ┌──────────┐┌─────────┐┌───────────┐┌─────────┐┌─────────┐┌──────────┐»
# «q_0: ┤ Rz(3π/2) ├┤ Rx(π/2) ├┤0          ├┤ Rz(π/2) ├┤ Rx(π/2) ├┤ Rz(5π/4) ├»
# «     ├─────────┬┘└──┬───┬──┘│  Acecr_pm │├─────────┤├─────────┤├──────────┤»
# «q_1: ┤ Rz(π/2) ├────┤ X ├───┤1          ├┤ Rz(π/2) ├┤ Rx(π/2) ├┤ Rz(5π/4) ├»
# «     └─────────┘    └───┘   └───────────┘└─────────┘└─────────┘└──────────┘»
# «q_2: ──────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «q_3: ──────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «q_4: ──────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «q_5: ──────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «     ┌─────────┐                                                             »
# «q_0: ┤ Rx(π/2) ├─────────────────────────────────────────────────────────────»
# «     ├─────────┤┌───────────┐┌──────────┐┌─────────┐┌──────────┐ ┌─────────┐ »
# «q_1: ┤ Rx(π/2) ├┤0          ├┤ Rz(3π/2) ├┤ Rx(π/2) ├┤ Rz(7π/4) ├─┤ Rx(π/2) ├─»
# «     └─────────┘│           │└──────────┘└─────────┘└──────────┘ └─────────┘ »
# «q_2: ───────────┤  Acecr_pm ├────────────────────────────────────────────────»
# «                │           │ ┌───────┐  ┌─────────┐┌─────────┐ ┌───────────┐»
# «q_3: ───────────┤1          ├─┤ Rz(π) ├──┤ Rx(π/2) ├┤ Rz(π/2) ├─┤0          ├»
# «                └───────────┘ └───────┘  └─────────┘└─────────┘ │           │»
# «q_4: ───────────────────────────────────────────────────────────┤  Acecr_pm ├»
# «                                                                │           │»
# «q_5: ───────────────────────────────────────────────────────────┤1          ├»
# «                                                                └───────────┘»
# «                                                                          »
# «q_0: ─────────────────────────────────────────────────────────────────────»
# «     ┌───────┐┌───────────┐┌─────────┐┌─────────┐┌──────────┐ ┌─────────┐ »
# «q_1: ┤ Rz(π) ├┤0          ├┤ Rz(π/2) ├┤ Rx(π/2) ├┤ Rz(7π/4) ├─┤ Rx(π/2) ├─»
# «     └───────┘│           │└─────────┘└─────────┘└──────────┘ └─────────┘ »
# «q_2: ─────────┤  Acecr_pm ├───────────────────────────────────────────────»
# «       ┌───┐  │           │ ┌───────┐ ┌─────────┐┌─────────┐ ┌───────────┐»
# «q_3: ──┤ X ├──┤1          ├─┤ Rz(π) ├─┤ Rx(π/2) ├┤ Rz(π/2) ├─┤0          ├»
# «       └───┘  └───────────┘ └───────┘ └─────────┘└─────────┘ │           │»
# «q_4: ────────────────────────────────────────────────────────┤  Acecr_pm ├»
# «     ┌───────┐ ┌─────────┐  ┌───────┐                        │           │»
# «q_5: ┤ Rz(π) ├─┤ Rx(π/2) ├──┤ Rz(π) ├────────────────────────┤1          ├»
# «     └───────┘ └─────────┘  └───────┘                        └───────────┘»
# «                                                                          »
# «q_0: ─────────────────────────────────────────────────────────────────────»
# «                                                             ┌───────────┐»
# «q_1: ────────────────────────────────────────────────────────┤0          ├»
# «                                                             │           │»
# «q_2: ────────────────────────────────────────────────────────┤  Acecr_pm ├»
# «     ┌─────────┐┌─────────┐┌──────────┐┌─────────┐┌─────────┐│           │»
# «q_3: ┤ Rz(π/2) ├┤ Rx(π/2) ├┤ Rz(7π/4) ├┤ Rx(π/2) ├┤ Rz(π/2) ├┤1          ├»
# «     └─────────┘└─────────┘└──────────┘└─────────┘└─────────┘└───────────┘»
# «q_4: ─────────────────────────────────────────────────────────────────────»
# «      ┌───────┐ ┌─────────┐ ┌───────┐                                     »
# «q_5: ─┤ Rz(π) ├─┤ Rx(π/2) ├─┤ Rz(π) ├─────────────────────────────────────»
# «      └───────┘ └─────────┘ └───────┘                                     »
# «                                                                          »
# «q_0: ─────────────────────────────────────────────────────────────────────»
# «     ┌─────────┐┌─────────┐┌──────────┐ ┌─────────┐          ┌───────────┐»
# «q_1: ┤ Rz(π/2) ├┤ Rx(π/2) ├┤ Rz(7π/4) ├─┤ Rx(π/2) ├──────────┤0          ├»
# «     └─────────┘└─────────┘└──────────┘ └─────────┘          │           │»
# «q_2: ────────────────────────────────────────────────────────┤  Acecr_pm ├»
# «      ┌───────┐ ┌─────────┐┌─────────┐ ┌───────────┐  ┌───┐  │           │»
# «q_3: ─┤ Rz(π) ├─┤ Rx(π/2) ├┤ Rz(π/2) ├─┤0          ├──┤ X ├──┤1          ├»
# «      └───────┘ └─────────┘└─────────┘ │           │  └───┘  └───────────┘»
# «q_4: ──────────────────────────────────┤  Acecr_pm ├──────────────────────»
# «                                       │           │┌───────┐ ┌─────────┐ »
# «q_5: ──────────────────────────────────┤1          ├┤ Rz(π) ├─┤ Rx(π/2) ├─»
# «                                       └───────────┘└───────┘ └─────────┘ »
# «                                                                              »
# «q_0: ─────────────────────────────────────────────────────────────────────────»
# «     ┌──────────┐┌─────────┐ ┌───────┐  ┌───────────┐┌─────────┐  ┌─────────┐ »
# «q_1: ┤ Rz(3π/4) ├┤ Rx(π/2) ├─┤ Rz(π) ├──┤1          ├┤ Rz(π/2) ├──┤ Rx(π/2) ├─»
# «     └──────────┘└─────────┘ └───────┘  │  Acecr_pm │├─────────┴┐ └──┬───┬──┘ »
# «q_2: ───────────────────────────────────┤0          ├┤ Rz(3π/2) ├────┤ X ├────»
# «     ┌──────────┐┌─────────┐┌──────────┐└┬─────────┬┘└┬───────┬─┘┌───┴───┴───┐»
# «q_3: ┤ Rz(3π/2) ├┤ Rx(π/2) ├┤ Rz(5π/4) ├─┤ Rx(π/2) ├──┤ Rz(π) ├──┤0          ├»
# «     └──────────┘└─────────┘└──────────┘ └─────────┘  └───────┘  │           │»
# «q_4: ────────────────────────────────────────────────────────────┤  Acecr_pm ├»
# «      ┌───────┐                                                  │           │»
# «q_5: ─┤ Rz(π) ├──────────────────────────────────────────────────┤1          ├»
# «      └───────┘                                                  └───────────┘»
# «                ┌───────────┐┌──────────┐┌─────────┐ ┌──────────┐┌─────────┐ »
# «q_0: ───────────┤0          ├┤ Rz(3π/2) ├┤ Rx(π/2) ├─┤ Rz(7π/4) ├┤ Rx(π/2) ├─»
# «     ┌─────────┐│  Acecr_pm │├─────────┬┘└──┬───┬──┘┌┴──────────┤├─────────┤ »
# «q_1: ┤ Rz(π/2) ├┤1          ├┤ Rz(π/2) ├────┤ X ├───┤1          ├┤ Rz(π/2) ├─»
# «     └─────────┘└───────────┘└─────────┘    └───┘   │  Acecr_pm │├─────────┴┐»
# «q_2: ───────────────────────────────────────────────┤0          ├┤ Rz(3π/2) ├»
# «        ┌───┐                                       └───────────┘└──────────┘»
# «q_3: ───┤ X ├────────────────────────────────────────────────────────────────»
# «        └───┘                                                                »
# «q_4: ────────────────────────────────────────────────────────────────────────»
# «      ┌───────┐  ┌─────────┐  ┌───────┐                                      »
# «q_5: ─┤ Rz(π) ├──┤ Rx(π/2) ├──┤ Rz(π) ├──────────────────────────────────────»
# «      └───────┘  └─────────┘  └───────┘                                      »
# «      ┌───────┐            ┌───────────┐┌─────────┐┌─────────┐ ┌──────────┐»
# «q_0: ─┤ Rz(π) ├────────────┤0          ├┤ Rz(π/2) ├┤ Rx(π/2) ├─┤ Rz(7π/4) ├»
# «     ┌┴───────┴┐┌─────────┐│  Acecr_pm │├─────────┤└──┬───┬──┘┌┴──────────┤»
# «q_1: ┤ Rx(π/2) ├┤ Rz(π/2) ├┤1          ├┤ Rz(π/2) ├───┤ X ├───┤1          ├»
# «     └──┬───┬──┘└─────────┘└───────────┘└─────────┘   └───┘   │  Acecr_pm │»
# «q_2: ───┤ X ├─────────────────────────────────────────────────┤0          ├»
# «        └───┘                                                 └───────────┘»
# «q_3: ──────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «q_4: ──────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «q_5: ──────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «     ┌─────────┐                       ┌───────────┐┌─────────┐┌─────────┐»
# «q_0: ┤ Rx(π/2) ├───────────────────────┤0          ├┤ Rz(π/2) ├┤ Rx(π/2) ├»
# «     ├─────────┤ ┌─────────┐┌─────────┐│  Acecr_pm │├─────────┤└──┬───┬──┘»
# «q_1: ┤ Rz(π/4) ├─┤ Rx(π/2) ├┤ Rz(π/2) ├┤1          ├┤ Rz(π/2) ├───┤ X ├───»
# «     ├─────────┴┐└──┬───┬──┘└─────────┘└───────────┘└─────────┘   └───┘   »
# «q_2: ┤ Rz(3π/2) ├───┤ X ├─────────────────────────────────────────────────»
# «     └──────────┘   └───┘                                                 »
# «q_3: ─────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_4: ─────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_5: ─────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «      ┌──────────┐┌─────────┐                      ┌───────────┐  ┌───┐  »
# «q_0: ─┤ Rz(7π/4) ├┤ Rx(π/2) ├──────────────────────┤0          ├──┤ X ├──»
# «     ┌┴──────────┤├─────────┤┌─────────┐┌─────────┐│  Acecr_pm │┌─┴───┴─┐»
# «q_1: ┤1          ├┤ Rz(π/2) ├┤ Rx(π/2) ├┤ Rz(π/2) ├┤1          ├┤ Rz(π) ├»
# «     │  Acecr_pm │└─────────┘└─────────┘└─────────┘└───────────┘└───────┘»
# «q_2: ┤0          ├───────────────────────────────────────────────────────»
# «     └───────────┘                                                       »
# «q_3: ────────────────────────────────────────────────────────────────────»
# «                                                                         »
# «q_4: ────────────────────────────────────────────────────────────────────»
# «                                                                         »
# «q_5: ────────────────────────────────────────────────────────────────────»
# «                                                                         »
# «                                                                           »
# «q_0: ──────────────────────────────────────────────────────────────────────»
# «     ┌─────────┐┌──────────┐┌─────────┐┌───────────┐┌──────────┐┌─────────┐»
# «q_1: ┤ Rx(π/2) ├┤ Rz(7π/4) ├┤ Rx(π/2) ├┤0          ├┤ Rz(3π/2) ├┤ Rx(π/2) ├»
# «     └─────────┘└──────────┘└─────────┘│           │└──────────┘└─────────┘»
# «q_2: ──────────────────────────────────┤  Acecr_pm ├───────────────────────»
# «                                       │           │ ┌───────┐  ┌─────────┐»
# «q_3: ──────────────────────────────────┤1          ├─┤ Rz(π) ├──┤ Rx(π/2) ├»
# «                                       └───────────┘ └───────┘  └─────────┘»
# «q_4: ──────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «q_5: ──────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «                                                                          »
# «q_0: ─────────────────────────────────────────────────────────────────────»
# «     ┌──────────┐ ┌─────────┐ ┌───────┐┌───────────┐┌─────────┐┌─────────┐»
# «q_1: ┤ Rz(7π/4) ├─┤ Rx(π/2) ├─┤ Rz(π) ├┤0          ├┤ Rz(π/2) ├┤ Rx(π/2) ├»
# «     └──────────┘ └─────────┘ └───────┘│           │└─────────┘└─────────┘»
# «q_2: ──────────────────────────────────┤  Acecr_pm ├──────────────────────»
# «     ┌─────────┐ ┌───────────┐  ┌───┐  │           │ ┌───────┐ ┌─────────┐»
# «q_3: ┤ Rz(π/2) ├─┤0          ├──┤ X ├──┤1          ├─┤ Rz(π) ├─┤ Rx(π/2) ├»
# «     └─────────┘ │           │  └───┘  └───────────┘ └───────┘ └─────────┘»
# «q_4: ────────────┤  Acecr_pm ├────────────────────────────────────────────»
# «                 │           │┌───────┐ ┌─────────┐  ┌───────┐            »
# «q_5: ────────────┤1          ├┤ Rz(π) ├─┤ Rx(π/2) ├──┤ Rz(π) ├────────────»
# «                 └───────────┘└───────┘ └─────────┘  └───────┘            »
# «                                                                           »
# «q_0: ──────────────────────────────────────────────────────────────────────»
# «     ┌──────────┐ ┌─────────┐                                              »
# «q_1: ┤ Rz(7π/4) ├─┤ Rx(π/2) ├──────────────────────────────────────────────»
# «     └──────────┘ └─────────┘                                              »
# «q_2: ──────────────────────────────────────────────────────────────────────»
# «     ┌─────────┐ ┌───────────┐┌─────────┐┌─────────┐┌──────────┐┌─────────┐»
# «q_3: ┤ Rz(π/2) ├─┤0          ├┤ Rz(π/2) ├┤ Rx(π/2) ├┤ Rz(7π/4) ├┤ Rx(π/2) ├»
# «     └─────────┘ │           │└─────────┘└─────────┘└──────────┘└─────────┘»
# «q_4: ────────────┤  Acecr_pm ├─────────────────────────────────────────────»
# «                 │           │ ┌───────┐ ┌─────────┐ ┌───────┐             »
# «q_5: ────────────┤1          ├─┤ Rz(π) ├─┤ Rx(π/2) ├─┤ Rz(π) ├─────────────»
# «                 └───────────┘ └───────┘ └─────────┘ └───────┘             »
# «                                                                            »
# «q_0: ───────────────────────────────────────────────────────────────────────»
# «                ┌───────────┐┌─────────┐┌─────────┐┌──────────┐ ┌─────────┐ »
# «q_1: ───────────┤0          ├┤ Rz(π/2) ├┤ Rx(π/2) ├┤ Rz(7π/4) ├─┤ Rx(π/2) ├─»
# «                │           │└─────────┘└─────────┘└──────────┘ └─────────┘ »
# «q_2: ───────────┤  Acecr_pm ├───────────────────────────────────────────────»
# «     ┌─────────┐│           │ ┌───────┐ ┌─────────┐┌─────────┐ ┌───────────┐»
# «q_3: ┤ Rz(π/2) ├┤1          ├─┤ Rz(π) ├─┤ Rx(π/2) ├┤ Rz(π/2) ├─┤0          ├»
# «     └─────────┘└───────────┘ └───────┘ └─────────┘└─────────┘ │           │»
# «q_4: ──────────────────────────────────────────────────────────┤  Acecr_pm ├»
# «                                                               │           │»
# «q_5: ──────────────────────────────────────────────────────────┤1          ├»
# «                                                               └───────────┘»
# «
# «q_0: ──────────────────────────────────────────────
# «                ┌───────────┐   ┌───┐
# «q_1: ───────────┤0          ├───┤ X ├──────────────
# «                │           │   └───┘
# «q_2: ───────────┤  Acecr_pm ├──────────────────────
# «        ┌───┐   │           │┌─────────┐┌─────────┐
# «q_3: ───┤ X ├───┤1          ├┤ Rz(π/2) ├┤ Rx(π/2) ├
# «        └───┘   └───────────┘└─────────┘└─────────┘
# «q_4: ──────────────────────────────────────────────
# «     ┌─────────┐ ┌─────────┐
# «q_5: ┤ Rz(π/2) ├─┤ Rx(π/2) ├───────────────────────
# «     └─────────┘ └─────────┘

# %%
context_pulse_out.circuit.draw()
# Out:
#                                                                ┌───────────┐»
# q_0: ──────────────────────────────────────────────────────────┤0          ├»
#                            ┌───────────┐┌─────────┐ ┌─────────┐│  Acecr_pm │»
# q_1: ──────────────────────┤1          ├┤ Rz(π/2) ├─┤ Rx(π/2) ├┤1          ├»
#      ┌─────────┐┌─────────┐│  Acecr_pm │├─────────┴┐├─────────┤└┬──────────┤»
# q_2: ┤ Rz(π/2) ├┤ Rx(π/2) ├┤0          ├┤ Rz(3π/2) ├┤ Rx(π/2) ├─┤ Rz(7π/4) ├»
#      ├─────────┤├─────────┤└┬─────────┬┘└──────────┘└─────────┘ └──────────┘»
# q_3: ┤ Rz(π/2) ├┤ Rx(π/2) ├─┤ Rz(π/2) ├─────────────────────────────────────»
#      └─────────┘└─────────┘ └─────────┘                                     »
# q_4: ───────────────────────────────────────────────────────────────────────»
#      ┌─────────┐┌─────────┐ ┌─────────┐                                     »
# q_5: ┤ Rz(π/2) ├┤ Rx(π/2) ├─┤ Rz(π/2) ├─────────────────────────────────────»
#      └─────────┘└─────────┘ └─────────┘                                     »
# «                                                                           »
# «q_0: ──────────────────────────────────────────────────────────────────────»
# «     ┌─────────┐┌─────────┐┌───────────┐┌──────────┐┌─────────┐┌──────────┐»
# «q_1: ┤ Rz(π/2) ├┤ Rx(π/2) ├┤1          ├┤ Rz(3π/2) ├┤ Rx(π/2) ├┤ Rz(7π/4) ├»
# «     ├─────────┤└┬───────┬┘│  Acecr_pm │├──────────┤├─────────┤├──────────┤»
# «q_2: ┤ Rx(π/2) ├─┤ Rz(π) ├─┤0          ├┤ Rz(3π/2) ├┤ Rx(π/2) ├┤ Rz(7π/4) ├»
# «     └─────────┘ └───────┘ └───────────┘└──────────┘└─────────┘└──────────┘»
# «q_3: ──────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «q_4: ──────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «q_5: ──────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «                         ┌───────────┐┌──────────┐   ┌───┐              »
# «q_0: ────────────────────┤0          ├┤ Rz(3π/2) ├───┤ X ├──────────────»
# «     ┌─────────┐┌───────┐│  Acecr_pm │├─────────┬┘┌──┴───┴──┐┌─────────┐»
# «q_1: ┤ Rx(π/2) ├┤ Rz(π) ├┤1          ├┤ Rz(π/2) ├─┤ Rx(π/2) ├┤ Rz(π/2) ├»
# «     ├─────────┤├───────┤└───────────┘└─────────┘ └─────────┘└─────────┘»
# «q_2: ┤ Rx(π/2) ├┤ Rz(π) ├───────────────────────────────────────────────»
# «     └─────────┘└───────┘                                               »
# «q_3: ───────────────────────────────────────────────────────────────────»
# «                                                                        »
# «q_4: ───────────────────────────────────────────────────────────────────»
# «                                                                        »
# «q_5: ───────────────────────────────────────────────────────────────────»
# «                                                                        »
# «                                        ┌───────────┐┌────────────┐┌─────────┐»
# «q_0: ───────────────────────────────────┤0          ├┤ Rz(3.1306) ├┤ Rx(π/2) ├»
# «     ┌───────────┐┌─────────┐   ┌───┐   │  Acecr_pm │└┬─────────┬─┘├─────────┤»
# «q_1: ┤1          ├┤ Rz(π/2) ├───┤ X ├───┤1          ├─┤ Rz(π/2) ├──┤ Rx(π/2) ├»
# «     │  Acecr_pm │├─────────┤┌──┴───┴──┐└┬──────────┤ ├─────────┤  └─────────┘»
# «q_2: ┤0          ├┤ Rz(π/2) ├┤ Rx(π/2) ├─┤ Rz(7π/4) ├─┤ Rx(π/2) ├─────────────»
# «     └───────────┘└─────────┘└─────────┘ └──────────┘ └─────────┘             »
# «q_3: ─────────────────────────────────────────────────────────────────────────»
# «                                                                              »
# «q_4: ─────────────────────────────────────────────────────────────────────────»
# «                                                                              »
# «q_5: ─────────────────────────────────────────────────────────────────────────»
# «                                                                              »
# «      ┌───────┐                                    ┌───────────┐┌─────────┐»
# «q_0: ─┤ Rz(π) ├────────────────────────────────────┤0          ├┤ Rz(π/2) ├»
# «     ┌┴───────┴┐┌───────────┐┌─────────┐┌─────────┐│  Acecr_pm │├─────────┤»
# «q_1: ┤ Rz(π/2) ├┤1          ├┤ Rx(π/2) ├┤ Rz(π/2) ├┤1          ├┤ Rz(π/2) ├»
# «     └─────────┘│  Acecr_pm │├─────────┤├─────────┤└─┬───────┬─┘└─────────┘»
# «q_2: ───────────┤0          ├┤ Rz(π/2) ├┤ Rx(π/2) ├──┤ Rz(π) ├─────────────»
# «                └───────────┘└─────────┘└─────────┘  └───────┘             »
# «q_3: ──────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «q_4: ──────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «q_5: ──────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «     ┌─────────┐┌───────────┐┌─────────┐┌──────────┐ ┌─────────┐  »
# «q_0: ┤ Rx(π/2) ├┤0          ├┤ Rx(π/2) ├┤ Rz(5π/4) ├─┤ Rx(π/2) ├──»
# «     ├─────────┤│  Acecr_pm │└┬───────┬┘├─────────┬┘┌┴─────────┴─┐»
# «q_1: ┤ Rx(π/2) ├┤1          ├─┤ Rz(π) ├─┤ Rx(π/2) ├─┤ Rz(2.3672) ├»
# «     └─────────┘└───────────┘ └───────┘ └─────────┘ └────────────┘»
# «q_2: ─────────────────────────────────────────────────────────────»
# «                                                                  »
# «q_3: ─────────────────────────────────────────────────────────────»
# «                                                                  »
# «q_4: ─────────────────────────────────────────────────────────────»
# «                                                                  »
# «q_5: ─────────────────────────────────────────────────────────────»
# «                                                                  »
# «                                                                           »
# «q_0: ──────────────────────────────────────────────────────────────────────»
# «     ┌───────────┐┌──────────┐┌─────────┐┌──────────┐ ┌─────────┐ ┌───────┐»
# «q_1: ┤0          ├┤ Rz(3π/2) ├┤ Rx(π/2) ├┤ Rz(7π/4) ├─┤ Rx(π/2) ├─┤ Rz(π) ├»
# «     │           │└──────────┘└─────────┘└──────────┘ └─────────┘ └───────┘»
# «q_2: ┤  Acecr_pm ├─────────────────────────────────────────────────────────»
# «     │           │ ┌───────┐  ┌─────────┐┌─────────┐ ┌───────────┐  ┌───┐  »
# «q_3: ┤1          ├─┤ Rz(π) ├──┤ Rx(π/2) ├┤ Rz(π/2) ├─┤0          ├──┤ X ├──»
# «     └───────────┘ └───────┘  └─────────┘└─────────┘ │           │  └───┘  »
# «q_4: ────────────────────────────────────────────────┤  Acecr_pm ├─────────»
# «                                                     │           │         »
# «q_5: ────────────────────────────────────────────────┤1          ├─────────»
# «                                                     └───────────┘         »
# «                                                                           »
# «q_0: ──────────────────────────────────────────────────────────────────────»
# «     ┌───────────┐┌──────────┐┌─────────┐┌──────────┐┌─────────┐ ┌───────┐ »
# «q_1: ┤0          ├┤ Rz(3π/2) ├┤ Rx(π/2) ├┤ Rz(7π/4) ├┤ Rx(π/2) ├─┤ Rz(π) ├─»
# «     │           │└──────────┘└─────────┘└──────────┘└─────────┘ └───────┘ »
# «q_2: ┤  Acecr_pm ├─────────────────────────────────────────────────────────»
# «     │           │┌─────────┐ ┌─────────┐┌──────────┐┌─────────┐┌─────────┐»
# «q_3: ┤1          ├┤ Rz(π/2) ├─┤ Rx(π/2) ├┤ Rz(7π/4) ├┤ Rx(π/2) ├┤ Rz(π/2) ├»
# «     └───────────┘└─────────┘ └─────────┘└──────────┘└─────────┘└─────────┘»
# «q_4: ──────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «q_5: ──────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «                                                                            »
# «q_0: ───────────────────────────────────────────────────────────────────────»
# «                             ┌───────────┐┌─────────┐┌─────────┐┌──────────┐»
# «q_1: ────────────────────────┤0          ├┤ Rz(π/2) ├┤ Rx(π/2) ├┤ Rz(7π/4) ├»
# «                             │           │└─────────┘└─────────┘└──────────┘»
# «q_2: ────────────────────────┤  Acecr_pm ├──────────────────────────────────»
# «     ┌───────────┐┌─────────┐│           │ ┌───────┐ ┌─────────┐┌─────────┐ »
# «q_3: ┤0          ├┤ Rz(π/2) ├┤1          ├─┤ Rz(π) ├─┤ Rx(π/2) ├┤ Rz(π/2) ├─»
# «     │           │└─────────┘└───────────┘ └───────┘ └─────────┘└─────────┘ »
# «q_4: ┤  Acecr_pm ├──────────────────────────────────────────────────────────»
# «     │           │                                                          »
# «q_5: ┤1          ├──────────────────────────────────────────────────────────»
# «     └───────────┘                                                          »
# «                                                                      »
# «q_0: ─────────────────────────────────────────────────────────────────»
# «      ┌─────────┐      ┌───────────┐┌─────────┐┌─────────┐┌──────────┐»
# «q_1: ─┤ Rx(π/2) ├──────┤0          ├┤ Rz(π/2) ├┤ Rx(π/2) ├┤ Rz(5π/4) ├»
# «      └─────────┘      │           │└─────────┘└─────────┘└──────────┘»
# «q_2: ──────────────────┤  Acecr_pm ├──────────────────────────────────»
# «     ┌───────────┐┌───┐│           │                                  »
# «q_3: ┤0          ├┤ X ├┤1          ├──────────────────────────────────»
# «     │           │└───┘└───────────┘                                  »
# «q_4: ┤  Acecr_pm ├────────────────────────────────────────────────────»
# «     │           │                                                    »
# «q_5: ┤1          ├────────────────────────────────────────────────────»
# «     └───────────┘                                                    »
# «     ┌───────────┐┌──────────┐┌─────────┐ ┌──────────┐┌─────────┐ ┌───────┐ »
# «q_0: ┤0          ├┤ Rz(3π/2) ├┤ Rx(π/2) ├─┤ Rz(7π/4) ├┤ Rx(π/2) ├─┤ Rz(π) ├─»
# «     │  Acecr_pm │├─────────┬┘├─────────┤┌┴──────────┤├─────────┤┌┴───────┴┐»
# «q_1: ┤1          ├┤ Rz(π/2) ├─┤ Rx(π/2) ├┤1          ├┤ Rz(π/2) ├┤ Rx(π/2) ├»
# «     └───────────┘└─────────┘ └─────────┘│  Acecr_pm │└─────────┘└─────────┘»
# «q_2: ────────────────────────────────────┤0          ├──────────────────────»
# «                                         └───────────┘                      »
# «q_3: ───────────────────────────────────────────────────────────────────────»
# «                                                                            »
# «q_4: ───────────────────────────────────────────────────────────────────────»
# «                                                                            »
# «q_5: ───────────────────────────────────────────────────────────────────────»
# «                                                                            »
# «     ┌───────────┐┌──────────┐┌─────────┐┌──────────┐┌─────────┐┌───────┐»
# «q_0: ┤0          ├┤ Rz(3π/2) ├┤ Rx(π/2) ├┤ Rz(7π/4) ├┤ Rx(π/2) ├┤ Rz(π) ├»
# «     │  Acecr_pm │├──────────┤├─────────┤├──────────┤├─────────┤├───────┤»
# «q_1: ┤1          ├┤ Rz(3π/2) ├┤ Rx(π/2) ├┤ Rz(7π/4) ├┤ Rx(π/2) ├┤ Rz(π) ├»
# «     └───────────┘└──────────┘└─────────┘└──────────┘└─────────┘└───────┘»
# «q_2: ────────────────────────────────────────────────────────────────────»
# «                                                                         »
# «q_3: ────────────────────────────────────────────────────────────────────»
# «                                                                         »
# «q_4: ────────────────────────────────────────────────────────────────────»
# «                                                                         »
# «q_5: ────────────────────────────────────────────────────────────────────»
# «                                                                         »
# «                                                   ┌───────────┐┌─────────┐»
# «q_0: ──────────────────────────────────────────────┤0          ├┤ Rz(π/2) ├»
# «     ┌───────────┐┌─────────┐┌─────────┐┌─────────┐│  Acecr_pm │├─────────┤»
# «q_1: ┤1          ├┤ Rz(π/2) ├┤ Rx(π/2) ├┤ Rz(π/2) ├┤1          ├┤ Rz(π/2) ├»
# «     │  Acecr_pm │└─────────┘└─────────┘└─────────┘└───────────┘└─────────┘»
# «q_2: ┤0          ├─────────────────────────────────────────────────────────»
# «     └───────────┘                                                         »
# «q_3: ──────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «q_4: ──────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «q_5: ──────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «     ┌─────────┐ ┌──────────┐┌─────────┐           ┌───────────┐┌─────────┐»
# «q_0: ┤ Rx(π/2) ├─┤ Rz(7π/4) ├┤ Rx(π/2) ├───────────┤0          ├┤ Rz(π/2) ├»
# «     ├─────────┤┌┴──────────┤├─────────┤┌─────────┐│  Acecr_pm │├─────────┤»
# «q_1: ┤ Rx(π/2) ├┤1          ├┤ Rz(π/2) ├┤ Rx(π/2) ├┤1          ├┤ Rz(π/2) ├»
# «     └─────────┘│  Acecr_pm │└─────────┘└─────────┘└───────────┘└─────────┘»
# «q_2: ───────────┤0          ├──────────────────────────────────────────────»
# «                └───────────┘                                              »
# «q_3: ──────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «q_4: ──────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «q_5: ──────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «     ┌─────────┐ ┌──────────┐┌─────────┐ ┌─────────┐                       »
# «q_0: ┤ Rx(π/2) ├─┤ Rz(7π/4) ├┤ Rx(π/2) ├─┤ Rz(π/2) ├───────────────────────»
# «     └──┬───┬──┘┌┴──────────┤├─────────┴┐├─────────┤┌──────────┐┌─────────┐»
# «q_1: ───┤ X ├───┤1          ├┤ Rz(5π/4) ├┤ Rx(π/2) ├┤ Rz(7π/4) ├┤ Rx(π/2) ├»
# «        └───┘   │  Acecr_pm │└──────────┘└─────────┘└──────────┘└─────────┘»
# «q_2: ───────────┤0          ├──────────────────────────────────────────────»
# «                └───────────┘                                              »
# «q_3: ──────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «q_4: ──────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «q_5: ──────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «                                                                           »
# «q_0: ──────────────────────────────────────────────────────────────────────»
# «     ┌──────────┐┌───────────┐┌───────┐ ┌─────────┐ ┌──────────┐┌─────────┐»
# «q_1: ┤ Rz(3π/2) ├┤0          ├┤ Rz(π) ├─┤ Rx(π/2) ├─┤ Rz(5π/4) ├┤ Rx(π/2) ├»
# «     └──────────┘│           │└───────┘ └─────────┘ └──────────┘└─────────┘»
# «q_2: ────────────┤  Acecr_pm ├─────────────────────────────────────────────»
# «                 │           │  ┌───┐  ┌───────────┐┌─────────┐            »
# «q_3: ────────────┤1          ├──┤ X ├──┤0          ├┤ Rz(π/2) ├────────────»
# «                 └───────────┘  └───┘  │           │└─────────┘            »
# «q_4: ──────────────────────────────────┤  Acecr_pm ├───────────────────────»
# «                                       │           │                       »
# «q_5: ──────────────────────────────────┤1          ├───────────────────────»
# «                                       └───────────┘                       »
# «                                                                            »
# «q_0: ───────────────────────────────────────────────────────────────────────»
# «     ┌───────────┐┌─────────┐┌─────────┐┌──────────┐ ┌─────────┐            »
# «q_1: ┤0          ├┤ Rz(π/2) ├┤ Rx(π/2) ├┤ Rz(7π/4) ├─┤ Rx(π/2) ├────────────»
# «     │           │└─────────┘└─────────┘└──────────┘ └─────────┘            »
# «q_2: ┤  Acecr_pm ├──────────────────────────────────────────────────────────»
# «     │           │ ┌───────┐ ┌─────────┐┌─────────┐ ┌───────────┐┌─────────┐»
# «q_3: ┤1          ├─┤ Rz(π) ├─┤ Rx(π/2) ├┤ Rz(π/2) ├─┤0          ├┤ Rz(π/2) ├»
# «     └───────────┘ └───────┘ └─────────┘└─────────┘ │           │└─────────┘»
# «q_4: ───────────────────────────────────────────────┤  Acecr_pm ├───────────»
# «                                                    │           │           »
# «q_5: ───────────────────────────────────────────────┤1          ├───────────»
# «                                                    └───────────┘           »
# «                                                                          »
# «q_0: ─────────────────────────────────────────────────────────────────────»
# «                                                  ┌───────────┐┌─────────┐»
# «q_1: ─────────────────────────────────────────────┤0          ├┤ Rz(π/2) ├»
# «                                                  │           │└─────────┘»
# «q_2: ─────────────────────────────────────────────┤  Acecr_pm ├───────────»
# «     ┌─────────┐┌──────────┐┌─────────┐┌─────────┐│           │┌─────────┐»
# «q_3: ┤ Rx(π/2) ├┤ Rz(7π/4) ├┤ Rx(π/2) ├┤ Rz(π/2) ├┤1          ├┤ Rx(π/2) ├»
# «     └─────────┘└──────────┘└─────────┘└─────────┘└───────────┘└─────────┘»
# «q_4: ─────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_5: ─────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «
# «q_0: ───────────────────────────────────────────────────────────────────────
# «      ┌─────────┐ ┌──────────┐┌─────────┐┌───────────┐   ┌───┐
# «q_1: ─┤ Rx(π/2) ├─┤ Rz(7π/4) ├┤ Rx(π/2) ├┤0          ├───┤ X ├──────────────
# «      └─────────┘ └──────────┘└─────────┘│           │   └───┘
# «q_2: ────────────────────────────────────┤  Acecr_pm ├──────────────────────
# «     ┌───────────┐┌─────────┐            │           │┌─────────┐┌─────────┐
# «q_3: ┤0          ├┤ Rz(π/2) ├────────────┤1          ├┤ Rz(π/2) ├┤ Rx(π/2) ├
# «     │           │└─────────┘            └───────────┘└─────────┘└─────────┘
# «q_4: ┤  Acecr_pm ├──────────────────────────────────────────────────────────
# «     │           │┌─────────┐ ┌─────────┐ ┌─────────┐
# «q_5: ┤1          ├┤ Rz(π/2) ├─┤ Rx(π/2) ├─┤ Rz(π/2) ├───────────────────────
# «     └───────────┘└─────────┘ └─────────┘ └─────────┘

# %%
armonk_model = PulseSystemModel.from_backend(armonk_backend)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-6a1ec5957ef9> in <module>
# ----> 1 armonk_model = PulseSystemModel.from_backend(armonk_backend)
#
# NameError: name 'PulseSystemModel' is not defined
