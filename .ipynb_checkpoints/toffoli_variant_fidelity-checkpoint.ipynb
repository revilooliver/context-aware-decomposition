# %%
import qiskit

def cnx_halfdirty(circuit, controls, target, ancilla):
    if len(controls) == 2:
        circuit.toffoli(controls[0], controls[1], target)
    elif len(controls) == 1:
        circuit.cx(controls[0], target)
    else:
        bits = []
        bits.append(controls[0])
        
        for i in range(1, len(controls) - 1):
            bits.append(controls[i])
            bits.append(ancilla[i-1])
        bits.append(controls[-1])
        bits.append(target)
        
        for i in range(len(bits) - 1, 0, -2):
            circuit.toffoli(bits[i-2], bits[i-1], bits[i])
        
        for i in range(4, len(bits) - 2, 2):
            circuit.toffoli(bits[i-2], bits[i-1], bits[i])
            
        for i in range(len(bits) - 1, 0, -2):
            circuit.toffoli(bits[i-2], bits[i-1], bits[i])
            
        for i in range(4, len(bits) - 2, 2):
            circuit.toffoli(bits[i-2], bits[i-1], bits[i])

def generate_cnx_halfdirty(n):
    c = qiskit.circuit.QuantumCircuit(n)
    
    qs = range(n)
    
    assert (n + 3) % 2 == 0
    
    reg_len = int((n + 3)  / 2)
    cnx_halfdirty(c, qs[:reg_len -1], qs[reg_len -1], qs[reg_len:])
    return c

# %%
circuit = generate_cnx_halfdirty(5)

# %%
circuit.draw()
# Out:
#
# q_0: ───────■─────────■──
#             │         │
# q_1: ───────■─────────■──
#             │         │
# q_2: ──■────┼────■────┼──
#      ┌─┴─┐  │  ┌─┴─┐  │
# q_3: ┤ X ├──┼──┤ X ├──┼──
#      └─┬─┘┌─┴─┐└─┬─┘┌─┴─┐
# q_4: ──■──┤ X ├──■──┤ X ├
#           └───┘     └───┘

# %%
from qiskit.compiler import transpile

# %%
trans_orign = transpile(circuit, optimization_level=3)

# %%
trans_orign.draw(output = 'mpl')

# %%
trans_orign.count_ops()
# Out:
# OrderedDict([('cx', 24), ('t', 16), ('tdg', 12), ('h', 6)])

# %%
from gate_variants.toffoli_variants import CCX_01_12_Gate, CCX_02_01_Gate, CCX_02_01_h_Gate, CCX_01_02_Gate

# %%
c = qiskit.circuit.QuantumCircuit(5)

c.append(CCX_01_02_Gate(),[2,4,3])
c.ccx(0,1,4)
c.append(CCX_02_01_h_Gate(), [2,4,3])
c.append(CCX_01_12_Gate(), [0,1,4])

# %%
c.draw(output = "mpl")

# %%
trans_qc = transpile(c, optimization_level=3)
trans_qc.draw(output='mpl')

# %%
trans_qc.count_ops()
# Out:
# OrderedDict([('cx', 16), ('t', 10), ('tdg', 8), ('h', 6), ('unitary', 2)])

# %%
trans_orign.count_ops()
# Out:
# OrderedDict([('cx', 24), ('t', 16), ('tdg', 12), ('h', 6)])

# %%
16/24
# Out:
# 0.6666666666666666
