# %% [markdown]
# ### A few initial libraries ###

# %%
import numpy as np
import qiskit
from qiskit import *
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, Aer, execute, transpile

from qiskit.transpiler import PassManager

from qiskit.converters import circuit_to_dag
from qiskit.visualization import dag_drawer, plot_histogram
from qiskit.compiler import assemble
from qiskit.tools.monitor import job_monitor

from qiskit import IBMQ
from qiskit.test.mock import FakeManhattan
from qiskit.test.mock import FakeBogota
from qiskit.test.mock import FakeMumbai
from qiskit.test.mock import FakeTokyo
from gate_variants.cx_variants import CX_Variant_Gate 
from orientation_map import orientation_map_gen
from trios_bench.incrementer_borrowedbit import generate_incrementer

# %%
qiskit.__qiskit_version__
# Out:
# {'qiskit-terra': '0.18.3', 'qiskit-aer': '0.9.1', 'qiskit-ignis': '0.6.0', 'qiskit-ibmq-provider': '0.18.1', 'qiskit-aqua': '0.9.5', 'qiskit': '0.32.1', 'qiskit-nature': None, 'qiskit-finance': None, 'qiskit-optimization': None, 'qiskit-machine-learning': None}

# %% [markdown]
# ### Load device and the device configuration object ###

# %%
IBMQ.load_account()

provider = IBMQ.get_provider('ibm-q-ornl')
# device = FakeMumbai()

# backend_prop = device.properties()
# Out:
# ibmqfactory.load_account:WARNING:2022-04-06 18:44:02,805: Credentials are already in use. The existing account in the session will be replaced.

# %%
from qiskit_superstaq.superstaq_provider import SuperstaQProvider

# %%
superstaq_provider = SuperstaQProvider(api_key="ya29.A0ARrdaM-BWPjpkjhKgbVSRwWROaVE3g6mKCew2all4yXuPNLIwc6l65K10DiAMa-w8he0mR-i0Tb_jE6-GqqWlscj9Zq58rC2oSSzRVaLdZJMoy2bWqIXVhK3Tehp5N4zd8uHhyp01G9KC90Xmu3BKALiGiLP-w")

# %%
from level3_context import _parse_transpile_args
from level3_context_pulse import level_3_pass_manager, level_3_context_pulse_pass_manager, level_3_pulse_pass_manager

# %%
t5 = generate_incrementer(6)

# %%
t5.draw()
# Out:
#                          ┌───┐                                             »
# q_0: ──■─────────■────■──┤ X ├──■───────────────────────────────────────■──»
#        │  ┌───┐  │    │  └─┬─┘┌─┴─┐     ┌───┐               ┌───┐     ┌─┴─┐»
# q_1: ──┼──┤ X ├──┼────┼────■──┤ X ├──■──┤ X ├──■─────────■──┤ X ├─────┤ X ├»
#        │  ├───┤  │    │    │  └─┬─┘  │  └─┬─┘┌─┴─┐     ┌─┴─┐└─┬─┘     └─┬─┘»
# q_2: ──┼──┤ X ├──┼────┼────┼────┼────┼────■──┤ X ├──■──┤ X ├──■────■────┼──»
#        │  └───┘┌─┴─┐  │    │    │  ┌─┴─┐  │  └─┬─┘  │  └─┬─┘  │  ┌─┴─┐  │  »
# q_3: ──┼───────┤ X ├──┼────┼────┼──┤ X ├──■────■────┼────■────■──┤ X ├──┼──»
#        │  ┌───┐└───┘  │    │    │  └───┘          ┌─┴─┐          └───┘  │  »
# q_4: ──┼──┤ X ├───────┼────┼────┼─────────────────┤ X ├─────────────────┼──»
#      ┌─┴─┐└───┘     ┌─┴─┐  │    │                 └───┘                 │  »
# q_5: ┤ X ├──────────┤ X ├──■────■───────────────────────────────────────■──»
#      └───┘          └───┘                                                  »
# «     ┌───┐                    ┌───┐                                        »
# «q_0: ┤ X ├─────────────────■──┤ X ├──■─────────────────────────────────────»
# «     └─┬─┘          ┌───┐  │  └─┬─┘┌─┴─┐     ┌───┐               ┌───┐     »
# «q_1: ──■─────────■──┤ X ├──┼────■──┤ X ├──■──┤ X ├──■─────────■──┤ X ├─────»
# «       │  ┌───┐  │  └───┘  │    │  └─┬─┘  │  └─┬─┘┌─┴─┐     ┌─┴─┐└─┬─┘     »
# «q_2: ──┼──┤ X ├──┼─────────┼────┼────┼────┼────■──┤ X ├──■──┤ X ├──■────■──»
# «       │  └───┘  │         │    │    │  ┌─┴─┐  │  └─┬─┘  │  └─┬─┘  │  ┌─┴─┐»
# «q_3: ──┼─────────┼─────────┼────┼────┼──┤ X ├──■────■────┼────■────■──┤ X ├»
# «       │         │         │    │    │  └───┘          ┌─┴─┐          └───┘»
# «q_4: ──┼─────────┼─────────┼────┼────┼─────────────────┤ X ├───────────────»
# «       │       ┌─┴─┐     ┌─┴─┐  │    │                 └───┘               »
# «q_5: ──■───────┤ X ├─────┤ X ├──■────■─────────────────────────────────────»
# «               └───┘     └───┘                                             »
# «          ┌───┐                                                            »
# «q_0: ──■──┤ X ├───────■────■───────────────────■─────────■─────────────────»
# «     ┌─┴─┐└─┬─┘       │    │                   │         │  ┌───┐          »
# «q_1: ┤ X ├──■────■────┼────┼───────────────────■─────────■──┤ X ├──────────»
# «     └─┬─┘  │    │    │    │                   │         │  ├───┤          »
# «q_2: ──┼────┼────┼────┼────┼──────────────■────┼────■────┼──┤ X ├──────────»
# «       │    │    │    │  ┌─┴─┐┌───┐       │  ┌─┴─┐  │  ┌─┴─┐├───┤┌───┐     »
# «q_3: ──┼────┼────┼────┼──┤ X ├┤ X ├───────■──┤ X ├──■──┤ X ├┤ X ├┤ X ├─────»
# «       │    │    │    │  └───┘└─┬─┘┌───┐  │  └───┘  │  └───┘└─┬─┘├───┤┌───┐»
# «q_4: ──┼────┼────┼────┼─────────┼──┤ X ├──┼─────────┼─────────┼──┤ X ├┤ X ├»
# «       │    │  ┌─┴─┐┌─┴─┐┌───┐  │  └─┬─┘┌─┴─┐     ┌─┴─┐       │  └─┬─┘└───┘»
# «q_5: ──■────■──┤ X ├┤ X ├┤ X ├──■────■──┤ X ├─────┤ X ├───────■────■───────»
# «               └───┘└───┘└───┘          └───┘     └───┘                    »
# «                    ┌───┐                                             ┌───┐»
# «q_0: ──■────■────■──┤ X ├──■───────────────────────────────────────■──┤ X ├»
# «       │    │    │  └─┬─┘┌─┴─┐     ┌───┐               ┌───┐     ┌─┴─┐└─┬─┘»
# «q_1: ──┼────┼────┼────■──┤ X ├──■──┤ X ├──■─────────■──┤ X ├─────┤ X ├──■──»
# «       │    │    │    │  └─┬─┘  │  └─┬─┘┌─┴─┐     ┌─┴─┐└─┬─┘     └─┬─┘  │  »
# «q_2: ──┼────┼────┼────┼────┼────┼────■──┤ X ├──■──┤ X ├──■────■────┼────┼──»
# «       │  ┌─┴─┐  │    │    │  ┌─┴─┐  │  └─┬─┘  │  └─┬─┘  │  ┌─┴─┐  │    │  »
# «q_3: ──┼──┤ X ├──┼────┼────┼──┤ X ├──■────■────┼────■────■──┤ X ├──┼────┼──»
# «       │  ├───┤  │    │    │  └───┘          ┌─┴─┐          └───┘  │    │  »
# «q_4: ──┼──┤ X ├──┼────┼────┼─────────────────┤ X ├─────────────────┼────┼──»
# «     ┌─┴─┐└───┘┌─┴─┐  │    │                 └───┘                 │    │  »
# «q_5: ┤ X ├─────┤ X ├──■────■───────────────────────────────────────■────■──»
# «     └───┘     └───┘                                                       »
# «                         ┌───┐                                             »
# «q_0: ─────────────────■──┤ X ├──■───────────────────────────────────────■──»
# «               ┌───┐  │  └─┬─┘┌─┴─┐     ┌───┐               ┌───┐     ┌─┴─┐»
# «q_1: ───────■──┤ X ├──┼────■──┤ X ├──■──┤ X ├──■─────────■──┤ X ├─────┤ X ├»
# «     ┌───┐  │  └───┘  │    │  └─┬─┘  │  └─┬─┘┌─┴─┐     ┌─┴─┐└─┬─┘     └─┬─┘»
# «q_2: ┤ X ├──┼─────────┼────┼────┼────┼────■──┤ X ├──■──┤ X ├──■────■────┼──»
# «     └───┘  │         │    │    │  ┌─┴─┐  │  └─┬─┘  │  └─┬─┘  │  ┌─┴─┐  │  »
# «q_3: ───────┼─────────┼────┼────┼──┤ X ├──■────■────┼────■────■──┤ X ├──┼──»
# «            │         │    │    │  └───┘          ┌─┴─┐┌───┐     └───┘  │  »
# «q_4: ───────┼─────────┼────┼────┼─────────────────┤ X ├┤ X ├────────────┼──»
# «          ┌─┴─┐     ┌─┴─┐  │    │                 └───┘└───┘            │  »
# «q_5: ─────┤ X ├─────┤ X ├──■────■───────────────────────────────────────■──»
# «          └───┘     └───┘                                                  »
# «     ┌───┐                                                       ┌───┐     »
# «q_0: ┤ X ├───────■────■────────────────────────■─────────■───────┤ X ├─────»
# «     └─┬─┘       │    │                        │         │       └─┬─┘┌───┐»
# «q_1: ──■────■────┼────┼────────────────────────■─────────■─────────┼──┤ X ├»
# «       │    │    │    │                        │         │  ┌───┐  │  └─┬─┘»
# «q_2: ──┼────┼────┼────┼───────────────────■────┼────■────┼──┤ X ├──┼────┼──»
# «       │    │    │  ┌─┴─┐┌───┐┌───┐       │  ┌─┴─┐  │  ┌─┴─┐├───┤  │    │  »
# «q_3: ──┼────┼────┼──┤ X ├┤ X ├┤ X ├───────■──┤ X ├──■──┤ X ├┤ X ├──■────■──»
# «       │    │    │  └───┘└───┘└─┬─┘┌───┐  │  └───┘  │  └───┘└─┬─┘┌───┐┌───┐»
# «q_4: ──┼────┼────┼──────────────┼──┤ X ├──┼─────────┼─────────┼──┤ X ├┤ X ├»
# «       │  ┌─┴─┐┌─┴─┐┌───┐       │  └─┬─┘┌─┴─┐     ┌─┴─┐       │  └─┬─┘├───┤»
# «q_5: ──■──┤ X ├┤ X ├┤ X ├───────■────■──┤ X ├─────┤ X ├───────■────■──┤ X ├»
# «          └───┘└───┘└───┘               └───┘     └───┘               └───┘»
# «     ┌───┐                                                       ┌───┐┌───┐»
# «q_0: ┤ X ├──■────■───────────────────────────────────────■────■──┤ X ├┤ X ├»
# «     └─┬─┘  │    │  ┌───┐                         ┌───┐  │    │  └─┬─┘└─┬─┘»
# «q_1: ──┼────┼────┼──┤ X ├──■────■─────────■────■──┤ X ├──┼────┼────┼────┼──»
# «       │    │    │  └─┬─┘  │    │  ┌───┐  │    │  └─┬─┘  │    │    │    │  »
# «q_2: ──┼────┼────┼────┼────┼────┼──┤ X ├──┼────┼────┼────┼────┼────┼────┼──»
# «       │  ┌─┴─┐  │    │    │    │  └─┬─┘  │    │    │    │  ┌─┴─┐  │    │  »
# «q_3: ──■──┤ X ├──■────┼────┼────┼────┼────┼────┼────┼────■──┤ X ├──┼────■──»
# «          └─┬─┘┌─┴─┐  │  ┌─┴─┐  │    │    │  ┌─┴─┐  │  ┌─┴─┐└─┬─┘  │  ┌───┐»
# «q_4: ───────■──┤ X ├──■──┤ X ├──■────┼────■──┤ X ├──┼──┤ X ├──■────■──┤ X ├»
# «               └───┘     └─┬─┘┌─┴─┐  │  ┌─┴─┐└─┬─┘  │  ├───┤          └───┘»
# «q_5: ──────────────────────■──┤ X ├──■──┤ X ├──■────■──┤ X ├───────────────»
# «                              └───┘     └───┘          └───┘               »
# «                                                            ┌───┐┌───┐
# «q_0: ──■────■───────────────────────────────────────■────■──┤ X ├┤ X ├─────
# «       │    │  ┌───┐                         ┌───┐  │    │  └─┬─┘└─┬─┘┌───┐
# «q_1: ──┼────┼──┤ X ├──■────■─────────■────■──┤ X ├──┼────┼────┼────┼──┤ X ├
# «       │    │  └─┬─┘  │    │  ┌───┐  │    │  └─┬─┘  │    │    │    │  └─┬─┘
# «q_2: ──┼────┼────┼────┼────┼──┤ X ├──┼────┼────┼────┼────┼────┼────┼────┼──
# «     ┌─┴─┐  │    │    │    │  └─┬─┘  │    │    │    │  ┌─┴─┐  │    │    │
# «q_3: ┤ X ├──■────┼────┼────┼────┼────┼────┼────┼────■──┤ X ├──┼────■────■──
# «     └─┬─┘┌─┴─┐  │  ┌─┴─┐  │    │    │  ┌─┴─┐  │  ┌─┴─┐└─┬─┘  │
# «q_4: ──■──┤ X ├──■──┤ X ├──■────┼────■──┤ X ├──┼──┤ X ├──■────■────────────
# «          └───┘     └─┬─┘┌─┴─┐  │  ┌─┴─┐└─┬─┘  │  └───┘
# «q_5: ─────────────────■──┤ X ├──■──┤ X ├──■────■───────────────────────────
# «                         └───┘     └───┘

# %%
backend = provider.get_backend('ibmq_jakarta')

# %%
backend
# Out:
# <IBMQBackend('ibmq_jakarta') from IBMQ(hub='ibm-q-ornl', group='anl', project='csc430')>

# %%
backend_prop = backend.properties()

# %%
orientation_map = orientation_map_gen(backend)

# %%
transpile_args = _parse_transpile_args([t5], backend, seed_transpiler = 0, orientation_map = orientation_map)

# %%
pass_manager_config = transpile_args[0]['pass_manager_config']

# %%
print(pass_manager_config.orientation_map)
# Out:
# {(0, 1): 'f', (1, 0): 'b', (1, 2): 'b', (1, 3): 'f', (2, 1): 'f', (3, 1): 'b', (3, 5): 'f', (4, 5): 'b', (5, 3): 'b', (5, 4): 'f', (5, 6): 'b', (6, 5): 'f'}

# %%
pm_context = level_3_pulse_pass_manager(pass_manager_config)
# Out:
# layout_method:  dense
# routing method:  basic

# %%
pm_orign = level_3_pass_manager(pass_manager_config)
# Out:
# layout_method:  dense
# routing method:  basic

# %%
t_circ = pm_context.run(t5)
# Out:
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# No solution found:  nonexistent solution
# Layout({
# 4: Qubit(QuantumRegister(6, 'q'), 0),
# 5: Qubit(QuantumRegister(6, 'q'), 1),
# 3: Qubit(QuantumRegister(6, 'q'), 2),
# 2: Qubit(QuantumRegister(6, 'q'), 3),
# 1: Qubit(QuantumRegister(6, 'q'), 4),
# 0: Qubit(QuantumRegister(6, 'q'), 5)
# })
# intersect [Qubit(QuantumRegister(7, 'q'), 4), Qubit(QuantumRegister(7, 'q'), 5)]
# ('00', '11', 'b')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 5)]
# intersect [Qubit(QuantumRegister(7, 'q'), 5), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'b')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 5)]
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'b')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1), Qubit(QuantumRegister(7, 'q'), 2)]
# ('00', '11', 'b')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 4), Qubit(QuantumRegister(7, 'q'), 5)]
# ('00', '11', 'b')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 4), Qubit(QuantumRegister(7, 'q'), 5)]
# ('00', '11', 'b')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 5)]
# intersect [Qubit(QuantumRegister(7, 'q'), 5), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'b')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'b')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'b')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 0), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 0), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 5), Qubit(QuantumRegister(7, 'q'), 4)]
# ('00', '11', 'f')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 5), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'b')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 5), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'b')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'b')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'b')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 2), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 2), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 2), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 5), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'b')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 5), Qubit(QuantumRegister(7, 'q'), 4)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 5)]
# intersect [Qubit(QuantumRegister(7, 'q'), 5), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'b')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 2), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'b')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'b')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 1), Qubit(QuantumRegister(7, 'q'), 2)]
# ('00', '11', 'b')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'b')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 0), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 5), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'b')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# intersect [Qubit(QuantumRegister(7, 'q'), 5), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'b')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 1), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'b')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# intersect [Qubit(QuantumRegister(7, 'q'), 5), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'b')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 5), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'b')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# intersect [Qubit(QuantumRegister(7, 'q'), 5), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'b')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 1), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'b')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'b')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 0), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 0), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 2), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 2), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'b')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 2), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 5)]
# ('00', '11', 'f')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 5)]
# ('00', '11', 'f')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 5)]
# ('00', '11', 'f')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'b')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 0), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 0), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'b')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'b')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'f')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# intersect [Qubit(QuantumRegister(7, 'q'), 5), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'b')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 5), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'b')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 1), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'f')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 0), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 2), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 2), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1), Qubit(QuantumRegister(7, 'q'), 2)]
# ('00', '11', 'b')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 0), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 0), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 1), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'f')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 2), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 2), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'f')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 1), Qubit(QuantumRegister(7, 'q'), 2)]
# ('00', '11', 'b')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 1), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# intersect [Qubit(QuantumRegister(7, 'q'), 5), Qubit(QuantumRegister(7, 'q'), 4)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 1), Qubit(QuantumRegister(7, 'q'), 0)]
# ('00', '11', 'b')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'b')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 2), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 2), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# intersect [Qubit(QuantumRegister(7, 'q'), 0), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 5), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'b')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 5), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'b')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 0), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 2), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 5)]
# ('00', '11', 'f')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 2), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# intersect [Qubit(QuantumRegister(7, 'q'), 5), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'b')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 5), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'b')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# intersect [Qubit(QuantumRegister(7, 'q'), 2), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 2), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 5), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'b')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 1), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'f')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 1), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'f')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 5)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 1), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'f')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 1), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'f')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 1), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 5), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'b')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# intersect [Qubit(QuantumRegister(7, 'q'), 5), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'b')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'b')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 0), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 0), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 2), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 2), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'b')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 2), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 5)]
# ('00', '11', 'f')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 5)]
# ('00', '11', 'f')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 5)]
# intersect [Qubit(QuantumRegister(7, 'q'), 5), Qubit(QuantumRegister(7, 'q'), 4)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 5)]
# ('00', '11', 'f')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'b')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 0), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 0), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'b')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'b')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# intersect [Qubit(QuantumRegister(7, 'q'), 5), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'b')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 5), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'b')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'b')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'b')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 0), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 2), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 2), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 0), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 0), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1), Qubit(QuantumRegister(7, 'q'), 0)]
# ('00', '11', 'b')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 2), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 2), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 2), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 0), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 0), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'b')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 1), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 5), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'b')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# intersect [Qubit(QuantumRegister(7, 'q'), 5), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'b')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 5)]
# ('00', '11', 'f')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 1), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# intersect [Qubit(QuantumRegister(7, 'q'), 5), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'b')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# intersect [Qubit(QuantumRegister(7, 'q'), 5), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'b')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# intersect [Qubit(QuantumRegister(7, 'q'), 2), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 2), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 0), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 0), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1), Qubit(QuantumRegister(7, 'q'), 0)]
# ('00', '11', 'b')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 2), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 0), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 5)]
# ('00', '11', 'f')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 5)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 0), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 0), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 1), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 0), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 0), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 1), Qubit(QuantumRegister(7, 'q'), 2)]
# ('00', '11', 'b')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 5)]
# ('00', '11', 'f')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 5)]
# ('00', '11', 'f')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 5)]
# ('00', '11', 'f')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'b')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'b')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 0), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 0), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 4), Qubit(QuantumRegister(7, 'q'), 5)]
# ('00', '11', 'b')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 4), Qubit(QuantumRegister(7, 'q'), 5)]
# ('00', '11', 'b')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 5)]
# intersect [Qubit(QuantumRegister(7, 'q'), 5), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'b')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 5), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'b')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'b')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'b')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 2), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 2), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 2), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 5), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'b')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 5), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'b')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 2), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'b')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'b')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 1), Qubit(QuantumRegister(7, 'q'), 2)]
# ('00', '11', 'b')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'b')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 0), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 5), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'b')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# intersect [Qubit(QuantumRegister(7, 'q'), 5), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'b')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 1), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'b')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 5), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'b')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 5), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'b')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# intersect [Qubit(QuantumRegister(7, 'q'), 5), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'b')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 1), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'b')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'b')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 0), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 0), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 2), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 2), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'b')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 2), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 5)]
# ('00', '11', 'f')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 5)]
# ('00', '11', 'f')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 5)]
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 5)]
# ('00', '11', 'f')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'b')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 0), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 0), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'b')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 3), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'b')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'f')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 3)]
# intersect [Qubit(QuantumRegister(7, 'q'), 5), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'b')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 5), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'b')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 1), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'f')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 0), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 2), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 2), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'f')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 1), Qubit(QuantumRegister(7, 'q'), 2)]
# ('00', '11', 'b')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 1)]
# intersect [Qubit(QuantumRegister(7, 'q'), 0), Qubit(QuantumRegister(7, 'q'), 1)]
# ('00', '11', 'f')
# ('11', '00', 'b')
# intersect [Qubit(QuantumRegister(7, 'q'), 1), Qubit(QuantumRegister(7, 'q'), 3)]
# ('00', '11', 'f')
# ('11', '00', 'b')

# %%
t_orign = pm_orign.run(t5)
# Out:
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# ccx
# No solution found:  nonexistent solution
# Layout({
# 4: Qubit(QuantumRegister(6, 'q'), 0),
# 5: Qubit(QuantumRegister(6, 'q'), 1),
# 3: Qubit(QuantumRegister(6, 'q'), 2),
# 2: Qubit(QuantumRegister(6, 'q'), 3),
# 1: Qubit(QuantumRegister(6, 'q'), 4),
# 0: Qubit(QuantumRegister(6, 'q'), 5)
# })

# %%
t_circ.count_ops()
# Out:
# OrderedDict([('rz', 1331),
#              ('rx', 605),
#              ('ry', 605),
#              ('acecr_pm', 430),
#              ('cx', 282),
#              ('sx', 173),
#              ('x', 22)])

# %%
t_circ.draw()
# Out:
#                ┌─────────┐                                               »
#       q_5 -> 0 ┤ Rz(π/4) ├───────────────────────────────────────────────»
#                └──┬───┬──┘┌─────────┐ ┌─────────┐                        »
#       q_4 -> 1 ───┤ X ├───┤ Rz(π/2) ├─┤ Rx(π/2) ├────────────────────────»
#                ┌──┴───┴──┐├─────────┤ └─────────┘                        »
#       q_3 -> 2 ┤ Rz(π/2) ├┤ Rx(π/2) ├────────────────────────────────────»
#                └──┬───┬──┘├─────────┤ ┌─────────┐                        »
#       q_2 -> 3 ───┤ X ├───┤ Rz(π/2) ├─┤ Rx(π/2) ├────────────────────────»
#                 ┌─┴───┴─┐ ├─────────┤┌┴─────────┴┐┌─────────┐ ┌─────────┐»
#       q_0 -> 4 ─┤ Rz(π) ├─┤ Ry(π/2) ├┤1          ├┤ Rz(π/2) ├─┤ Rx(π/2) ├»
#                ┌┴───────┴┐├─────────┤│  Acecr_pm │├─────────┴┐├─────────┤»
#       q_1 -> 5 ┤ Rz(π/2) ├┤ Rx(π/2) ├┤0          ├┤ Ry(-π/2) ├┤ Rz(π/2) ├»
#                └─────────┘└─────────┘└───────────┘└──────────┘└─────────┘»
# ancilla_0 -> 6 ──────────────────────────────────────────────────────────»
#                                                                          »
# «                                                                           »
# «      q_5 -> 0 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «      q_4 -> 1 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «      q_3 -> 2 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «      q_2 -> 3 ────────────────────────────────────────────────────────────»
# «               ┌─────────┐┌───────────┐       ┌───┐   ┌───────┐ ┌─────────┐»
# «      q_0 -> 4 ┤ Rx(π/2) ├┤1          ├──■────┤ X ├───┤ Rz(π) ├─┤ Ry(π/2) ├»
# «               └┬───────┬┘│  Acecr_pm │┌─┴─┐┌─┴───┴─┐┌┴───────┴┐└─────────┘»
# «      q_1 -> 5 ─┤ Ry(π) ├─┤0          ├┤ X ├┤ Rz(π) ├┤ Ry(π/2) ├───────────»
# «                └───────┘ └───────────┘└───┘└───────┘└─────────┘           »
# «ancilla_0 -> 6 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «                                                                           »
# «      q_5 -> 0 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «      q_4 -> 1 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «      q_3 -> 2 ────────────────────────────────────────────────────────────»
# «               ┌───────────┐┌──────────┐┌─────────┐ ┌───────┐ ┌───────────┐»
# «      q_2 -> 3 ┤0          ├┤ Ry(-π/2) ├┤ Rz(π/2) ├─┤ Ry(π) ├─┤0          ├»
# «               │           │└──────────┘└─────────┘ └───────┘ │           │»
# «      q_0 -> 4 ┤  Acecr_pm ├──────────────────────────────────┤  Acecr_pm ├»
# «               │           │┌─────────┐ ┌─────────┐┌─────────┐│           │»
# «      q_1 -> 5 ┤1          ├┤ Rz(π/2) ├─┤ Rx(π/2) ├┤ Rx(π/2) ├┤1          ├»
# «               └───────────┘└─────────┘ └─────────┘└─────────┘└───────────┘»
# «ancilla_0 -> 6 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «                                                                              »
# «      q_5 -> 0 ───────────────────────────────────────────────────────────────»
# «                                          ┌───────────┐┌──────────┐┌─────────┐»
# «      q_4 -> 1 ───────────────────────────┤0          ├┤ Ry(-π/2) ├┤ Rz(π/2) ├»
# «                                          │           │└──────────┘└─────────┘»
# «      q_3 -> 2 ───────────────────────────┤  Acecr_pm ├───────────────────────»
# «               ┌───┐ ┌───────┐ ┌─────────┐│           │┌─────────┐ ┌─────────┐»
# «      q_2 -> 3 ┤ X ├─┤ Rz(π) ├─┤ Ry(π/2) ├┤1          ├┤ Rz(π/2) ├─┤ Rx(π/2) ├»
# «               └─┬─┘ └───────┘ └─────────┘├───────────┤├─────────┤ ├─────────┤»
# «      q_0 -> 4 ──┼────────────────────────┤1          ├┤ Rz(π/2) ├─┤ Rx(π/2) ├»
# «                 │  ┌─────────┐┌─────────┐│  Acecr_pm │├─────────┴┐├─────────┤»
# «      q_1 -> 5 ──■──┤ Rz(π/2) ├┤ Rx(π/2) ├┤0          ├┤ Ry(-π/2) ├┤ Rz(π/2) ├»
# «                    └─────────┘└─────────┘└───────────┘└──────────┘└─────────┘»
# «ancilla_0 -> 6 ───────────────────────────────────────────────────────────────»
# «                                                                              »
# «                                                                          »
# «      q_5 -> 0 ───────────────────────────────────────────────────────────»
# «                ┌───────┐ ┌───────────┐   ┌───┐    ┌───────┐  ┌─────────┐ »
# «      q_4 -> 1 ─┤ Ry(π) ├─┤0          ├───┤ X ├────┤ Rz(π) ├──┤ Ry(π/2) ├─»
# «                └───────┘ │           │   └─┬─┘    └───────┘  └─────────┘ »
# «      q_3 -> 2 ───────────┤  Acecr_pm ├─────┼─────────────────────────────»
# «               ┌─────────┐│           │     │     ┌─────────┐ ┌─────────┐ »
# «      q_2 -> 3 ┤ Rx(π/2) ├┤1          ├─────■─────┤ Rz(π/2) ├─┤ Rx(π/2) ├─»
# «               ├─────────┤├───────────┤ ┌───────┐ ├─────────┤┌┴─────────┴┐»
# «      q_0 -> 4 ┤ Rx(π/2) ├┤1          ├─┤ Rz(π) ├─┤ Ry(π/2) ├┤1          ├»
# «               └┬───────┬┘│  Acecr_pm │┌┴───────┴┐├─────────┤│  Acecr_pm │»
# «      q_1 -> 5 ─┤ Ry(π) ├─┤0          ├┤ Rz(π/2) ├┤ Rx(π/2) ├┤0          ├»
# «                └───────┘ └───────────┘└─────────┘└─────────┘└───────────┘»
# «ancilla_0 -> 6 ───────────────────────────────────────────────────────────»
# «                                                                          »
# «                                                                             »
# «      q_5 -> 0 ──────────────────────────────────────────────────────────────»
# «               ┌───────────┐┌─────────┐ ┌─────────┐ ┌─────────┐     ┌────┐   »
# «      q_4 -> 1 ┤1          ├┤ Rz(π/2) ├─┤ Rx(π/2) ├─┤ Rz(π/2) ├─────┤ √X ├───»
# «               │  Acecr_pm │├─────────┴┐├─────────┤ └─────────┘     └────┘   »
# «      q_3 -> 2 ┤0          ├┤ Ry(-π/2) ├┤ Ry(π/2) ├──────────────────────────»
# «               └───────────┘└──────────┘└─────────┘             ┌───────────┐»
# «      q_2 -> 3 ─────────────────────────────────────────────────┤0          ├»
# «                ┌─────────┐ ┌─────────┐ ┌──────────┐┌──────────┐│           │»
# «      q_0 -> 4 ─┤ Rz(π/2) ├─┤ Rx(π/2) ├─┤ Rx(-π/2) ├┤ Rz(-π/2) ├┤  Acecr_pm ├»
# «                ├─────────┴┐└┬───────┬┘ ├─────────┬┘└──────────┘│           │»
# «      q_1 -> 5 ─┤ Ry(-π/2) ├─┤ Rz(π) ├──┤ Ry(π/2) ├─────────────┤1          ├»
# «                └──────────┘ └───────┘  └─────────┘             └───────────┘»
# «ancilla_0 -> 6 ──────────────────────────────────────────────────────────────»
# «                                                                             »
# «                                                                   »
# «      q_5 -> 0 ────────────────────────────────────────────────────»
# «               ┌──────────┐┌─────────┐┌─────────┐                  »
# «      q_4 -> 1 ┤ Rz(3π/4) ├┤ Rz(π/2) ├┤ Rx(π/2) ├──────────────────»
# «               └──────────┘└─────────┘└─────────┘                  »
# «      q_3 -> 2 ────────────────────────────────────────────────────»
# «               ┌──────────┐┌─────────┐ ┌───────┐ ┌───────────┐┌───┐»
# «      q_2 -> 3 ┤ Ry(-π/2) ├┤ Rz(π/2) ├─┤ Ry(π) ├─┤0          ├┤ X ├»
# «               └──────────┘└─────────┘ └───────┘ │           │└─┬─┘»
# «      q_0 -> 4 ──────────────────────────────────┤  Acecr_pm ├──┼──»
# «               ┌─────────┐ ┌─────────┐┌─────────┐│           │  │  »
# «      q_1 -> 5 ┤ Rz(π/2) ├─┤ Rx(π/2) ├┤ Rx(π/2) ├┤1          ├──■──»
# «               └─────────┘ └─────────┘└─────────┘└───────────┘     »
# «ancilla_0 -> 6 ────────────────────────────────────────────────────»
# «                                                                   »
# «                                                                              »
# «      q_5 -> 0 ───────────────────────────────────────────────────────────────»
# «                                                    ┌───────────┐ ┌──────────┐»
# «      q_4 -> 1 ─────────────────────────────────────┤0          ├─┤ Ry(-π/2) ├»
# «                                                    │           │ └──────────┘»
# «      q_3 -> 2 ─────────────────────────────────────┤  Acecr_pm ├─────────────»
# «               ┌──────────┐  ┌───────┐  ┌─────────┐ │           │ ┌─────────┐ »
# «      q_2 -> 3 ┤ Rz(3π/4) ├──┤ Rz(π) ├──┤ Ry(π/2) ├─┤1          ├─┤ Rz(π/2) ├─»
# «               └──────────┘┌─┴───────┴─┐├─────────┴┐└─┬────────┬┘┌┴─────────┴┐»
# «      q_0 -> 4 ────────────┤1          ├┤ Ry(-π/2) ├──┤ Rz(-π) ├─┤1          ├»
# «               ┌─────────┐ │  Acecr_pm │├──────────┤ ┌┴────────┴┐│  Acecr_pm │»
# «      q_1 -> 5 ┤ Ry(π/2) ├─┤0          ├┤ Rx(-π/2) ├─┤ Rz(-π/2) ├┤0          ├»
# «               └─────────┘ └───────────┘└──────────┘ └──────────┘└───────────┘»
# «ancilla_0 -> 6 ───────────────────────────────────────────────────────────────»
# «                                                                              »
# «                  ┌───┐    ┌─────────┐                                      »
# «      q_5 -> 0 ───┤ X ├────┤ Rz(π/4) ├──────────────────────────────────────»
# «                  └─┬─┘    ├─────────┤             ┌───────────┐┌──────────┐»
# «      q_4 -> 1 ─────■──────┤ Ry(π/2) ├─────────────┤0          ├┤ Rx(-π/2) ├»
# «                           └─────────┘             │           │└──────────┘»
# «      q_3 -> 2 ────────────────────────────────────┤  Acecr_pm ├────────────»
# «               ┌─────────┐ ┌──────────┐┌──────────┐│           │┌──────────┐»
# «      q_2 -> 3 ┤ Rx(π/2) ├─┤ Rx(-π/2) ├┤ Rz(-π/2) ├┤1          ├┤ Ry(-π/2) ├»
# «               ├─────────┴┐├──────────┤├──────────┤├───────────┤├──────────┤»
# «      q_0 -> 4 ┤ Rx(-π/2) ├┤ Rx(-π/2) ├┤ Rz(-π/2) ├┤1          ├┤ Ry(-π/2) ├»
# «               └┬───────┬─┘├──────────┤├─────────┬┘│  Acecr_pm │├──────────┤»
# «      q_1 -> 5 ─┤ Ry(π) ├──┤ Rz(-π/2) ├┤ Ry(π/2) ├─┤0          ├┤ Rx(-π/2) ├»
# «                └───────┘  └──────────┘└─────────┘ └───────────┘└──────────┘»
# «ancilla_0 -> 6 ─────────────────────────────────────────────────────────────»
# «                                                                            »
# «                             ┌───┐  ┌──────────┐                        »
# «      q_5 -> 0 ──────────────┤ X ├──┤ Rz(-π/4) ├────────────────────────»
# «               ┌──────────┐  └─┬─┘  ├─────────┬┘┌─────────┐┌───────────┐»
# «      q_4 -> 1 ┤ Rz(-π/2) ├────■────┤ Rz(π/2) ├─┤ Rx(π/2) ├┤0          ├»
# «               └──────────┘         └─────────┘ └─────────┘│           │»
# «      q_3 -> 2 ────────────────────────────────────────────┤  Acecr_pm ├»
# «                ┌────────┐ ┌───────┐┌─────────┐            │           │»
# «      q_2 -> 3 ─┤ Rz(-π) ├─┤ Rz(π) ├┤ Ry(π/2) ├────────────┤1          ├»
# «                ├────────┤ └───────┘└─────────┘            └───────────┘»
# «      q_0 -> 4 ─┤ Rz(-π) ├──────────────────────────────────────────────»
# «               ┌┴────────┴┐┌───────┐┌─────────┐                         »
# «      q_1 -> 5 ┤ Rz(-π/2) ├┤ Rz(π) ├┤ Ry(π/2) ├─────────────────────────»
# «               └──────────┘└───────┘└─────────┘                         »
# «ancilla_0 -> 6 ─────────────────────────────────────────────────────────»
# «                                                                        »
# «                                          ┌───┐    ┌──────────┐             »
# «      q_5 -> 0 ───────────────────────────┤ X ├────┤ Rz(-π/4) ├─────────────»
# «               ┌──────────┐┌──────────┐   └─┬─┘    ├─────────┬┘┌───────────┐»
# «      q_4 -> 1 ┤ Ry(-π/2) ├┤ Rz(-π/4) ├─────■──────┤ Ry(π/2) ├─┤0          ├»
# «               └──────────┘└──────────┘            └─────────┘ │           │»
# «      q_3 -> 2 ────────────────────────────────────────────────┤  Acecr_pm ├»
# «               ┌─────────┐ ┌─────────┐ ┌──────────┐┌──────────┐│           │»
# «      q_2 -> 3 ┤ Rz(π/2) ├─┤ Rx(π/2) ├─┤ Rx(-π/2) ├┤ Rz(-π/2) ├┤1          ├»
# «               └─────────┘ └─────────┘ └──────────┘└──────────┘└───────────┘»
# «      q_0 -> 4 ─────────────────────────────────────────────────────────────»
# «                                                                            »
# «      q_1 -> 5 ─────────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_0 -> 6 ─────────────────────────────────────────────────────────────»
# «                                                                            »
# «                                       ┌───┐ ┌─────────┐                   »
# «      q_5 -> 0 ────────────────────────┤ X ├─┤ Rz(π/4) ├───────────────────»
# «               ┌──────────┐┌──────────┐└─┬─┘ ├─────────┤ ┌────┐┌──────────┐»
# «      q_4 -> 1 ┤ Rx(-π/2) ├┤ Rz(-π/2) ├──■───┤ Rz(π/2) ├─┤ √X ├┤ Rz(3π/4) ├»
# «               └──────────┘└──────────┘      └─────────┘ └────┘└──────────┘»
# «      q_3 -> 2 ────────────────────────────────────────────────────────────»
# «               ┌──────────┐ ┌────────┐ ┌────┐┌──────────┐                  »
# «      q_2 -> 3 ┤ Ry(-π/2) ├─┤ Rz(-π) ├─┤ √X ├┤ Rz(3π/4) ├──────────────────»
# «               └──────────┘ └────────┘ └────┘└──────────┘                  »
# «      q_0 -> 4 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «      q_1 -> 5 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_0 -> 6 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «               ┌───────────┐ ┌───────┐  ┌──────────┐┌─────────┐┌───────┐»
# «      q_5 -> 0 ┤0          ├─┤ Ry(π) ├──┤ Rz(-π/2) ├┤ Rz(π/2) ├┤ Ry(π) ├»
# «               │  Acecr_pm │┌┴───────┴─┐└──────────┘├─────────┤└───────┘»
# «      q_4 -> 1 ┤1          ├┤ Rx(-π/2) ├─────■──────┤ Rx(π/2) ├─────────»
# «               └───────────┘└──────────┘     │      └─────────┘         »
# «      q_3 -> 2 ──────────────────────────────┼──────────────────────────»
# «                                           ┌─┴─┐    ┌─────────┐         »
# «      q_2 -> 3 ────────────────────────────┤ X ├────┤ Rz(π/4) ├─────────»
# «                                           └───┘    └─────────┘         »
# «      q_0 -> 4 ─────────────────────────────────────────────────────────»
# «                                                                        »
# «      q_1 -> 5 ─────────────────────────────────────────────────────────»
# «                                                                        »
# «ancilla_0 -> 6 ─────────────────────────────────────────────────────────»
# «                                                                        »
# «               ┌───────────┐     ┌───────────┐ ┌───────┐  ┌──────────┐»
# «      q_5 -> 0 ┤0          ├─────┤0          ├─┤ Ry(π) ├──┤ Rz(-π/2) ├»
# «               │  Acecr_pm │     │  Acecr_pm │┌┴───────┴─┐├──────────┤»
# «      q_4 -> 1 ┤1          ├──■──┤1          ├┤ Rx(-π/2) ├┤ Rz(-π/4) ├»
# «               └───────────┘  │  └───────────┘└──────────┘└──────────┘»
# «      q_3 -> 2 ───────────────┼───────────────────────────────────────»
# «                            ┌─┴─┐ ┌──────────┐                        »
# «      q_2 -> 3 ─────────────┤ X ├─┤ Rz(-π/4) ├────────────────────────»
# «                            └───┘ └──────────┘                        »
# «      q_0 -> 4 ───────────────────────────────────────────────────────»
# «                                                                      »
# «      q_1 -> 5 ───────────────────────────────────────────────────────»
# «                                                                      »
# «ancilla_0 -> 6 ───────────────────────────────────────────────────────»
# «                                                                      »
# «               ┌─────────┐ ┌───────┐ ┌───────────┐                       »
# «      q_5 -> 0 ┤ Rz(π/2) ├─┤ Ry(π) ├─┤0          ├───────────────────────»
# «               └─────────┘┌┴───────┴┐│  Acecr_pm │┌────┐┌──────────┐     »
# «      q_4 -> 1 ─────■─────┤ Rx(π/2) ├┤1          ├┤ √X ├┤ Rz(-π/2) ├──■──»
# «                    │     └─────────┘└───────────┘└────┘└──────────┘  │  »
# «      q_3 -> 2 ─────┼─────────────────────────────────────────────────┼──»
# «                  ┌─┴─┐      ┌───┐    ┌──────────┐                  ┌─┴─┐»
# «      q_2 -> 3 ───┤ X ├──────┤ X ├────┤ Rz(-π/4) ├──────────────────┤ X ├»
# «                  └───┘      └───┘    └──────────┘                  └───┘»
# «      q_0 -> 4 ──────────────────────────────────────────────────────────»
# «                                                                         »
# «      q_1 -> 5 ──────────────────────────────────────────────────────────»
# «                                                                         »
# «ancilla_0 -> 6 ──────────────────────────────────────────────────────────»
# «                                                                         »
# «                                                                        »
# «      q_5 -> 0 ─────────────────────────────────────────────────────────»
# «                  ┌────┐  ┌──────────┐┌────┐     ┌──────────┐   ┌────┐  »
# «      q_4 -> 1 ───┤ √X ├──┤ Rz(-π/2) ├┤ √X ├──■──┤ Rz(-π/2) ├───┤ √X ├──»
# «                  └────┘  └──────────┘└────┘  │  └──────────┘   └────┘  »
# «      q_3 -> 2 ───────────────────────────────┼─────────────────────────»
# «               ┌─────────┐                  ┌─┴─┐   ┌────┐   ┌─────────┐»
# «      q_2 -> 3 ┤ Rz(π/2) ├──────────────────┤ X ├───┤ √X ├───┤ Rz(π/2) ├»
# «               └─────────┘                  └───┘   └────┘   └─────────┘»
# «      q_0 -> 4 ─────────────────────────────────────────────────────────»
# «                                                                        »
# «      q_1 -> 5 ─────────────────────────────────────────────────────────»
# «                                                                        »
# «ancilla_0 -> 6 ─────────────────────────────────────────────────────────»
# «                                                                        »
# «                                                                             »
# «      q_5 -> 0 ──────────────────────────────────────────────────────────────»
# «               ┌──────────┐┌──────────┐ ┌──────────┐┌───────────┐┌──────────┐»
# «      q_4 -> 1 ┤ Rz(-π/2) ├┤ Rx(-π/2) ├─┤ Rz(-π/2) ├┤1          ├┤ Ry(-π/2) ├»
# «               └──────────┘└──────────┘ └──────────┘│  Acecr_pm │├──────────┤»
# «      q_3 -> 2 ─────────────────────────────────────┤0          ├┤ Rx(-π/2) ├»
# «               ┌─────────┐ ┌─────────┐ ┌───────────┐└┬──────────┤├─────────┬┘»
# «      q_2 -> 3 ┤ Rz(π/2) ├─┤ Rx(π/2) ├─┤0          ├─┤ Ry(-π/2) ├┤ Rz(π/2) ├─»
# «               └─────────┘ └─────────┘ │           │ └──────────┘└─────────┘ »
# «      q_0 -> 4 ────────────────────────┤  Acecr_pm ├─────────────────────────»
# «                                       │           │ ┌─────────┐ ┌─────────┐ »
# «      q_1 -> 5 ────────────────────────┤1          ├─┤ Rz(π/2) ├─┤ Rx(π/2) ├─»
# «                                       └───────────┘ └─────────┘ └─────────┘ »
# «ancilla_0 -> 6 ──────────────────────────────────────────────────────────────»
# «                                                                             »
# «                                                                            »
# «      q_5 -> 0 ─────────────────────────────────────────────────────────────»
# «                ┌────────┐     ┌────┐   ┌──────────┐┌─────────┐ ┌─────────┐ »
# «      q_4 -> 1 ─┤ Rz(-π) ├─────┤ √X ├───┤ Rz(3π/4) ├┤ Rz(π/2) ├─┤ Rx(π/2) ├─»
# «               ┌┴────────┴┐ ┌──┴────┴─┐ └──────────┘└─────────┘ └─────────┘ »
# «      q_3 -> 2 ┤ Rz(-π/2) ├─┤ Rz(π/4) ├─────────────────────────────────────»
# «               └┬───────┬─┘┌┴─────────┴┐┌─────────┐ ┌─────────┐┌───────────┐»
# «      q_2 -> 3 ─┤ Ry(π) ├──┤0          ├┤ Rz(π/2) ├─┤ Rx(π/2) ├┤0          ├»
# «                └───────┘  │           │└─────────┘ └─────────┘│           │»
# «      q_0 -> 4 ────────────┤  Acecr_pm ├───────────────────────┤  Acecr_pm ├»
# «               ┌─────────┐ │           │ ┌───────┐  ┌─────────┐│           │»
# «      q_1 -> 5 ┤ Rx(π/2) ├─┤1          ├─┤ Rz(π) ├──┤ Ry(π/2) ├┤1          ├»
# «               └─────────┘ └───────────┘ └───────┘  └─────────┘└───────────┘»
# «ancilla_0 -> 6 ─────────────────────────────────────────────────────────────»
# «                                                                            »
# «                                                                          »
# «      q_5 -> 0 ───────────────────────────────────────────────────────────»
# «                                                             ┌───────────┐»
# «      q_4 -> 1 ──────────────────────────────────────────────┤0          ├»
# «                                                             │           │»
# «      q_3 -> 2 ──────────────────────────────────────────────┤  Acecr_pm ├»
# «               ┌──────────┐┌──────────┐ ┌───────┐ ┌─────────┐│           │»
# «      q_2 -> 3 ┤ Ry(-π/2) ├┤ Rz(3π/4) ├─┤ Rz(π) ├─┤ Ry(π/2) ├┤1          ├»
# «               └──────────┘└──────────┘ └───────┘ └─────────┘└───────────┘»
# «      q_0 -> 4 ───────────────────────────────────────────────────────────»
# «               ┌─────────┐ ┌─────────┐ ┌─────────┐                        »
# «      q_1 -> 5 ┤ Rz(π/2) ├─┤ Rx(π/2) ├─┤ Rx(π/2) ├────────────────────────»
# «               └─────────┘ └─────────┘ └─────────┘                        »
# «ancilla_0 -> 6 ───────────────────────────────────────────────────────────»
# «                                                                          »
# «                                                                           »
# «      q_5 -> 0 ────────────────────────────────────────────────────────────»
# «               ┌──────────┐           ┌─────────┐             ┌───────────┐»
# «      q_4 -> 1 ┤ Ry(-π/2) ├─────■─────┤ Ry(π/2) ├─────────────┤0          ├»
# «               └──────────┘   ┌─┴─┐   ├─────────┤             │           │»
# «      q_3 -> 2 ───────────────┤ X ├───┤ Rz(π/4) ├─────────────┤  Acecr_pm ├»
# «               ┌─────────┐ ┌──┴───┴──┐├─────────┴┐┌──────────┐│           │»
# «      q_2 -> 3 ┤ Rz(π/2) ├─┤ Rx(π/2) ├┤ Rx(-π/2) ├┤ Rz(-π/2) ├┤1          ├»
# «               └─────────┘ └─────────┘└──────────┘└──────────┘└───────────┘»
# «      q_0 -> 4 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «      q_1 -> 5 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_0 -> 6 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «                                                                       »
# «      q_5 -> 0 ────────────────────────────────────────────────────────»
# «               ┌──────────┐┌──────────┐         ┌─────────┐ ┌─────────┐»
# «      q_4 -> 1 ┤ Rx(-π/2) ├┤ Rz(-π/2) ├────■────┤ Rz(π/2) ├─┤ Rx(π/2) ├»
# «               └──────────┘└──────────┘  ┌─┴─┐  ├─────────┴┐└─────────┘»
# «      q_3 -> 2 ──────────────────────────┤ X ├──┤ Rz(-π/4) ├───────────»
# «               ┌──────────┐ ┌────────┐ ┌─┴───┴─┐├─────────┬┘           »
# «      q_2 -> 3 ┤ Ry(-π/2) ├─┤ Rz(-π) ├─┤ Rz(π) ├┤ Ry(π/2) ├────────────»
# «               └──────────┘ └────────┘ └───────┘└─────────┘            »
# «      q_0 -> 4 ────────────────────────────────────────────────────────»
# «                                                                       »
# «      q_1 -> 5 ────────────────────────────────────────────────────────»
# «                                                                       »
# «ancilla_0 -> 6 ────────────────────────────────────────────────────────»
# «                                                                       »
# «                                                                            »
# «      q_5 -> 0 ─────────────────────────────────────────────────────────────»
# «               ┌───────────┐┌──────────┐┌──────────┐            ┌─────────┐ »
# «      q_4 -> 1 ┤0          ├┤ Ry(-π/2) ├┤ Rz(-π/4) ├─────■──────┤ Ry(π/2) ├─»
# «               │           │└──────────┘└──────────┘   ┌─┴─┐    ├─────────┴┐»
# «      q_3 -> 2 ┤  Acecr_pm ├───────────────────────────┤ X ├────┤ Rz(-π/4) ├»
# «               │           │┌─────────┐ ┌─────────┐ ┌──┴───┴───┐├──────────┤»
# «      q_2 -> 3 ┤1          ├┤ Rz(π/2) ├─┤ Rx(π/2) ├─┤ Rx(-π/2) ├┤ Rz(-π/2) ├»
# «               └───────────┘└─────────┘ └─────────┘ └──────────┘└──────────┘»
# «      q_0 -> 4 ─────────────────────────────────────────────────────────────»
# «                                                                            »
# «      q_1 -> 5 ─────────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_0 -> 6 ─────────────────────────────────────────────────────────────»
# «                                                                            »
# «                                                                            »
# «      q_5 -> 0 ─────────────────────────────────────────────────────────────»
# «               ┌───────────┐┌──────────┐┌──────────┐      ┌─────────┐ ┌────┐»
# «      q_4 -> 1 ┤0          ├┤ Rx(-π/2) ├┤ Rz(-π/2) ├──■───┤ Rz(π/2) ├─┤ √X ├»
# «               │           │└──────────┘└──────────┘┌─┴─┐ ├─────────┴┐└────┘»
# «      q_3 -> 2 ┤  Acecr_pm ├────────────────────────┤ X ├─┤ Rz(3π/4) ├──────»
# «               │           │┌──────────┐ ┌────────┐ ├───┴┐├──────────┤      »
# «      q_2 -> 3 ┤1          ├┤ Ry(-π/2) ├─┤ Rz(-π) ├─┤ √X ├┤ Rz(3π/4) ├──────»
# «               └───────────┘└──────────┘ └────────┘ └────┘└──────────┘      »
# «      q_0 -> 4 ─────────────────────────────────────────────────────────────»
# «                                                                            »
# «      q_1 -> 5 ─────────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_0 -> 6 ─────────────────────────────────────────────────────────────»
# «                                                                            »
# «                                                                     »
# «      q_5 -> 0 ──────────────────────────────────────────────────────»
# «               ┌──────────┐┌───────────┐┌──────────┐                 »
# «      q_4 -> 1 ┤ Rz(3π/4) ├┤1          ├┤ Rx(-π/2) ├──────────────■──»
# «               └──────────┘│  Acecr_pm │└┬───────┬─┘┌──────────┐  │  »
# «      q_3 -> 2 ────────────┤0          ├─┤ Ry(π) ├──┤ Rz(-π/2) ├──┼──»
# «                           └───────────┘ └───────┘  └──────────┘┌─┴─┐»
# «      q_2 -> 3 ─────────────────────────────────────────────────┤ X ├»
# «                                                                └───┘»
# «      q_0 -> 4 ──────────────────────────────────────────────────────»
# «                                                                     »
# «      q_1 -> 5 ──────────────────────────────────────────────────────»
# «                                                                     »
# «ancilla_0 -> 6 ──────────────────────────────────────────────────────»
# «                                                                     »
# «                                                                              »
# «      q_5 -> 0 ───────────────────────────────────────────────────────────────»
# «               ┌─────────┐         ┌───────────┐     ┌───────────┐┌──────────┐»
# «      q_4 -> 1 ┤ Rx(π/2) ├─────────┤1          ├──■──┤1          ├┤ Rx(-π/2) ├»
# «               ├─────────┤┌───────┐│  Acecr_pm │  │  │  Acecr_pm │└┬───────┬─┘»
# «      q_3 -> 2 ┤ Rz(π/2) ├┤ Ry(π) ├┤0          ├──┼──┤0          ├─┤ Ry(π) ├──»
# «               ├─────────┤└───────┘└───────────┘┌─┴─┐└┬──────────┤ └───────┘  »
# «      q_2 -> 3 ┤ Rz(π/4) ├──────────────────────┤ X ├─┤ Rz(-π/4) ├────────────»
# «               └─────────┘                      └───┘ └──────────┘            »
# «      q_0 -> 4 ───────────────────────────────────────────────────────────────»
# «                                                                              »
# «      q_1 -> 5 ───────────────────────────────────────────────────────────────»
# «                                                                              »
# «ancilla_0 -> 6 ───────────────────────────────────────────────────────────────»
# «                                                                              »
# «                                                                         »
# «      q_5 -> 0 ──────────────────────────────────────────────────────────»
# «               ┌──────────┐                ┌─────────┐ ┌───────────┐     »
# «      q_4 -> 1 ┤ Rz(-π/4) ├─────────────■──┤ Rx(π/2) ├─┤1          ├──■──»
# «               ├──────────┤┌─────────┐  │  └┬───────┬┘ │  Acecr_pm │  │  »
# «      q_3 -> 2 ┤ Rz(-π/2) ├┤ Rz(π/2) ├──┼───┤ Ry(π) ├──┤0          ├──┼──»
# «               └──────────┘└─────────┘┌─┴─┐┌┴───────┴─┐└───────────┘┌─┴─┐»
# «      q_2 -> 3 ───────────────────────┤ X ├┤ Rz(-π/4) ├─────────────┤ X ├»
# «                                      └───┘└──────────┘             └───┘»
# «      q_0 -> 4 ──────────────────────────────────────────────────────────»
# «                                                                         »
# «      q_1 -> 5 ──────────────────────────────────────────────────────────»
# «                                                                         »
# «ancilla_0 -> 6 ──────────────────────────────────────────────────────────»
# «                                                                         »
# «                                                                          »
# «      q_5 -> 0 ───────────────────────────────────────────────────────────»
# «               ┌─────────┐┌───────────┐┌──────────┐                       »
# «      q_4 -> 1 ┤ Rz(π/4) ├┤1          ├┤ Rx(-π/2) ├───────────────────────»
# «               └─────────┘│  Acecr_pm │└┬───────┬─┘┌──────────┐┌─────────┐»
# «      q_3 -> 2 ───────────┤0          ├─┤ Ry(π) ├──┤ Rz(-π/2) ├┤ Rz(π/2) ├»
# «               ┌─────────┐└───┬────┬──┘┌┴───────┴┐ ├─────────┬┘└┬───────┬┘»
# «      q_2 -> 3 ┤ Rz(π/2) ├────┤ √X ├───┤ Rz(π/2) ├─┤ Rz(π/2) ├──┤ Ry(π) ├─»
# «               └─────────┘    └────┘   └─────────┘ └─────────┘  └───────┘ »
# «      q_0 -> 4 ───────────────────────────────────────────────────────────»
# «                                                                          »
# «      q_1 -> 5 ───────────────────────────────────────────────────────────»
# «                                                                          »
# «ancilla_0 -> 6 ───────────────────────────────────────────────────────────»
# «                                                                          »
# «                                                                           »
# «      q_5 -> 0 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «      q_4 -> 1 ────────────────────────────────────────────────────────────»
# «                 ┌───────┐                                                 »
# «      q_3 -> 2 ──┤ Ry(π) ├─────────────────────────────────────────────────»
# «               ┌─┴───────┴─┐┌─────────┐┌─────────┐┌───────────┐┌──────────┐»
# «      q_2 -> 3 ┤0          ├┤ Rz(π/2) ├┤ Rx(π/2) ├┤0          ├┤ Ry(-π/2) ├»
# «               │           │└─────────┘└─────────┘│           │└──────────┘»
# «      q_0 -> 4 ┤  Acecr_pm ├──────────────────────┤  Acecr_pm ├────────────»
# «               │           │ ┌───────┐ ┌─────────┐│           │┌─────────┐ »
# «      q_1 -> 5 ┤1          ├─┤ Rz(π) ├─┤ Ry(π/2) ├┤1          ├┤ Rz(π/2) ├─»
# «               └───────────┘ └───────┘ └─────────┘└───────────┘└─────────┘ »
# «ancilla_0 -> 6 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «                                                                           »
# «      q_5 -> 0 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «      q_4 -> 1 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «      q_3 -> 2 ────────────────────────────────────────────────────────────»
# «               ┌─────────┐ ┌───────┐ ┌───────────┐ ┌─────────┐ ┌─────────┐ »
# «      q_2 -> 3 ┤ Rz(π/2) ├─┤ Ry(π) ├─┤0          ├─┤ Rz(π/2) ├─┤ Rx(π/2) ├─»
# «               └─────────┘ └───────┘ │           │┌┴─────────┴┐├─────────┴┐»
# «      q_0 -> 4 ──────────────────────┤  Acecr_pm ├┤1          ├┤ Rx(-π/2) ├»
# «               ┌─────────┐┌─────────┐│           ││  Acecr_pm │└┬───────┬─┘»
# «      q_1 -> 5 ┤ Rx(π/2) ├┤ Rx(π/2) ├┤1          ├┤0          ├─┤ Ry(π) ├──»
# «               └─────────┘└─────────┘└───────────┘└───────────┘ └───────┘  »
# «ancilla_0 -> 6 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «                                                                        »
# «      q_5 -> 0 ─────────────────────────────────────────────────────────»
# «                                                                        »
# «      q_4 -> 1 ─────────────────────────────────────────────────────────»
# «                                                                        »
# «      q_3 -> 2 ─────────────────────────────────────────────────────────»
# «                                               ┌───────────┐┌──────────┐»
# «      q_2 -> 3 ────────────────────────────────┤0          ├┤ Ry(-π/2) ├»
# «               ┌─────────┐                     │           │└──────────┘»
# «      q_0 -> 4 ┤ Rx(π/2) ├─────────────────────┤  Acecr_pm ├────────────»
# «               ├─────────┴┐┌───────┐┌─────────┐│           │┌─────────┐ »
# «      q_1 -> 5 ┤ Rz(-π/2) ├┤ Rz(π) ├┤ Ry(π/2) ├┤1          ├┤ Rz(π/2) ├─»
# «               └──────────┘└───────┘└─────────┘└───────────┘└─────────┘ »
# «ancilla_0 -> 6 ─────────────────────────────────────────────────────────»
# «                                                                        »
# «                                                                            »
# «      q_5 -> 0 ─────────────────────────────────────────────────────────────»
# «                                                                            »
# «      q_4 -> 1 ─────────────────────────────────────────────────────────────»
# «                                                                            »
# «      q_3 -> 2 ─────────────────────────────────────────────────────────────»
# «               ┌─────────┐ ┌───────┐ ┌───────────┐┌───┐┌─────────┐   ┌────┐ »
# «      q_2 -> 3 ┤ Rz(π/2) ├─┤ Ry(π) ├─┤0          ├┤ X ├┤ Rz(π/2) ├───┤ √X ├─»
# «               └─────────┘ └───────┘ │           │└─┬─┘└─────────┘   └────┘ »
# «      q_0 -> 4 ──────────────────────┤  Acecr_pm ├──┼───────────────────────»
# «               ┌─────────┐┌─────────┐│           │  │  ┌──────────┐┌───────┐»
# «      q_1 -> 5 ┤ Rx(π/2) ├┤ Rx(π/2) ├┤1          ├──■──┤ Rz(3π/4) ├┤ Rz(π) ├»
# «               └─────────┘└─────────┘└───────────┘     └──────────┘└───────┘»
# «ancilla_0 -> 6 ─────────────────────────────────────────────────────────────»
# «                                                                            »
# «                                                                          »
# «      q_5 -> 0 ───────────────────────────────────────────────────────────»
# «                                ┌─────────┐┌───────────┐     ┌───────────┐»
# «      q_4 -> 1 ──────────────■──┤ Rx(π/2) ├┤1          ├──■──┤1          ├»
# «                             │  └─────────┘│  Acecr_pm │  │  │  Acecr_pm │»
# «      q_3 -> 2 ──────────────┼─────────────┤0          ├──┼──┤0          ├»
# «               ┌──────────┐┌─┴─┐┌─────────┐└───────────┘┌─┴─┐└┬──────────┤»
# «      q_2 -> 3 ┤ Rz(3π/4) ├┤ X ├┤ Rz(π/4) ├─────────────┤ X ├─┤ Rz(-π/4) ├»
# «               └──────────┘└───┘└─────────┘             └───┘ └──────────┘»
# «      q_0 -> 4 ───────────────────────────────────────────────────────────»
# «               ┌─────────┐                                                »
# «      q_1 -> 5 ┤ Ry(π/2) ├────────────────────────────────────────────────»
# «               └─────────┘                                                »
# «ancilla_0 -> 6 ───────────────────────────────────────────────────────────»
# «                                                                          »
# «                                                                   »
# «      q_5 -> 0 ────────────────────────────────────────────────────»
# «               ┌──────────┐┌──────────┐                ┌─────────┐ »
# «      q_4 -> 1 ┤ Rx(-π/2) ├┤ Rz(-π/4) ├─────────────■──┤ Rx(π/2) ├─»
# «               └┬───────┬─┘├──────────┤┌─────────┐  │  └┬───────┬┘ »
# «      q_3 -> 2 ─┤ Ry(π) ├──┤ Rz(-π/2) ├┤ Rz(π/2) ├──┼───┤ Ry(π) ├──»
# «                └───────┘  └──────────┘└─────────┘┌─┴─┐┌┴───────┴─┐»
# «      q_2 -> 3 ───────────────────────────────────┤ X ├┤ Rz(-π/4) ├»
# «                                                  └───┘└──────────┘»
# «      q_0 -> 4 ────────────────────────────────────────────────────»
# «                                                                   »
# «      q_1 -> 5 ────────────────────────────────────────────────────»
# «                                                                   »
# «ancilla_0 -> 6 ────────────────────────────────────────────────────»
# «                                                                   »
# «                                                                         »
# «      q_5 -> 0 ──────────────────────────────────────────────────────────»
# «               ┌───────────┐     ┌─────────┐┌────┐┌──────────┐┌─────────┐»
# «      q_4 -> 1 ┤1          ├──■──┤ Rz(π/2) ├┤ √X ├┤ Rz(3π/4) ├┤ Rz(π/2) ├»
# «               │  Acecr_pm │  │  └─────────┘└────┘└──────────┘└─────────┘»
# «      q_3 -> 2 ┤0          ├──┼──────────────────────────────────────────»
# «               └───────────┘┌─┴─┐┌─────────┐┌────┐┌──────────┐ ┌───────┐ »
# «      q_2 -> 3 ─────────────┤ X ├┤ Rz(π/2) ├┤ √X ├┤ Rz(3π/4) ├─┤ Rz(π) ├─»
# «                            └───┘└─────────┘└────┘└──────────┘ └───────┘ »
# «      q_0 -> 4 ──────────────────────────────────────────────────────────»
# «                                                                         »
# «      q_1 -> 5 ──────────────────────────────────────────────────────────»
# «                                                                         »
# «ancilla_0 -> 6 ──────────────────────────────────────────────────────────»
# «                                                                         »
# «                                                                          »
# «      q_5 -> 0 ───────────────────────────────────────────────────────────»
# «               ┌─────────┐┌───────────┐┌──────────┐           ┌─────────┐ »
# «      q_4 -> 1 ┤ Rx(π/2) ├┤0          ├┤ Ry(-π/2) ├─────■─────┤ Ry(π/2) ├─»
# «               └─────────┘│           │└──────────┘   ┌─┴─┐   ├─────────┤ »
# «      q_3 -> 2 ───────────┤  Acecr_pm ├───────────────┤ X ├───┤ Rz(π/4) ├─»
# «               ┌─────────┐│           │┌─────────┐ ┌──┴───┴──┐├─────────┴┐»
# «      q_2 -> 3 ┤ Ry(π/2) ├┤1          ├┤ Rz(π/2) ├─┤ Rx(π/2) ├┤ Rx(-π/2) ├»
# «               └─────────┘└───────────┘└─────────┘ └─────────┘└──────────┘»
# «      q_0 -> 4 ───────────────────────────────────────────────────────────»
# «                                                                          »
# «      q_1 -> 5 ───────────────────────────────────────────────────────────»
# «                                                                          »
# «ancilla_0 -> 6 ───────────────────────────────────────────────────────────»
# «                                                                          »
# «                                                                         »
# «      q_5 -> 0 ──────────────────────────────────────────────────────────»
# «                           ┌───────────┐┌──────────┐┌──────────┐         »
# «      q_4 -> 1 ────────────┤0          ├┤ Rx(-π/2) ├┤ Rz(-π/2) ├────■────»
# «                           │           │└──────────┘└──────────┘  ┌─┴─┐  »
# «      q_3 -> 2 ────────────┤  Acecr_pm ├──────────────────────────┤ X ├──»
# «               ┌──────────┐│           │┌──────────┐ ┌────────┐ ┌─┴───┴─┐»
# «      q_2 -> 3 ┤ Rz(-π/2) ├┤1          ├┤ Ry(-π/2) ├─┤ Rz(-π) ├─┤ Rz(π) ├»
# «               └──────────┘└───────────┘└──────────┘ └────────┘ └───────┘»
# «      q_0 -> 4 ──────────────────────────────────────────────────────────»
# «                                                                         »
# «      q_1 -> 5 ──────────────────────────────────────────────────────────»
# «                                                                         »
# «ancilla_0 -> 6 ──────────────────────────────────────────────────────────»
# «                                                                         »
# «                                                                           »
# «      q_5 -> 0 ────────────────────────────────────────────────────────────»
# «               ┌─────────┐ ┌─────────┐┌───────────┐┌──────────┐┌──────────┐»
# «      q_4 -> 1 ┤ Rz(π/2) ├─┤ Rx(π/2) ├┤0          ├┤ Ry(-π/2) ├┤ Rz(-π/4) ├»
# «               ├─────────┴┐└─────────┘│           │└──────────┘└──────────┘»
# «      q_3 -> 2 ┤ Rz(-π/4) ├───────────┤  Acecr_pm ├────────────────────────»
# «               ├─────────┬┘           │           │┌─────────┐ ┌─────────┐ »
# «      q_2 -> 3 ┤ Ry(π/2) ├────────────┤1          ├┤ Rz(π/2) ├─┤ Rx(π/2) ├─»
# «               └─────────┘            └───────────┘└─────────┘ └─────────┘ »
# «      q_0 -> 4 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «      q_1 -> 5 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_0 -> 6 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «                                                                           »
# «      q_5 -> 0 ────────────────────────────────────────────────────────────»
# «                           ┌─────────┐            ┌───────────┐┌──────────┐»
# «      q_4 -> 1 ─────■──────┤ Ry(π/2) ├────────────┤0          ├┤ Rx(-π/2) ├»
# «                  ┌─┴─┐    ├─────────┴┐┌─────────┐│           │├─────────┬┘»
# «      q_3 -> 2 ───┤ X ├────┤ Rz(-π/4) ├┤ Rz(π/2) ├┤  Acecr_pm ├┤ Rx(π/2) ├─»
# «               ┌──┴───┴───┐├──────────┤└─────────┘│           │├─────────┴┐»
# «      q_2 -> 3 ┤ Rx(-π/2) ├┤ Rz(-π/2) ├───────────┤1          ├┤ Ry(-π/2) ├»
# «               └──────────┘└──────────┘           └───────────┘└──────────┘»
# «      q_0 -> 4 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «      q_1 -> 5 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_0 -> 6 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «                                                                        »
# «      q_5 -> 0 ─────────────────────────────────────────────────────────»
# «               ┌──────────┐┌───────┐┌─────────┐┌───────────┐┌─────────┐ »
# «      q_4 -> 1 ┤ Rz(-π/2) ├┤ Rz(π) ├┤ Ry(π/2) ├┤1          ├┤ Rz(π/2) ├─»
# «               └──────────┘└───────┘└─────────┘│  Acecr_pm │├─────────┴┐»
# «      q_3 -> 2 ────────────────────────────────┤0          ├┤ Ry(-π/2) ├»
# «                ┌────────┐ ┌───────┐┌─────────┐└───────────┘└──────────┘»
# «      q_2 -> 3 ─┤ Rz(-π) ├─┤ Rz(π) ├┤ Ry(π/2) ├─────────────────────────»
# «                └────────┘ └───────┘└─────────┘                         »
# «      q_0 -> 4 ─────────────────────────────────────────────────────────»
# «                                                                        »
# «      q_1 -> 5 ─────────────────────────────────────────────────────────»
# «                                                                        »
# «ancilla_0 -> 6 ─────────────────────────────────────────────────────────»
# «                                                                        »
# «                                                                            »
# «      q_5 -> 0 ─────────────────────────────────────────────────────────────»
# «               ┌─────────┐┌─────────┐┌────┐┌─────────┐┌─────────┐┌─────────┐»
# «      q_4 -> 1 ┤ Rx(π/2) ├┤ Rz(π/2) ├┤ √X ├┤ Rz(π/2) ├┤ Rz(π/2) ├┤ Rx(π/2) ├»
# «               ├─────────┤└─────────┘└────┘└─────────┘└─────────┘└─────────┘»
# «      q_3 -> 2 ┤ Ry(π/2) ├──────────────────────────────────────────────────»
# «               └─────────┘                                                  »
# «      q_2 -> 3 ─────────────────────────────────────────────────────────────»
# «                                                                            »
# «      q_0 -> 4 ─────────────────────────────────────────────────────────────»
# «                                                                            »
# «      q_1 -> 5 ─────────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_0 -> 6 ─────────────────────────────────────────────────────────────»
# «                                                                            »
# «                                                                           »
# «      q_5 -> 0 ────────────────────────────────────────────────────────────»
# «               ┌───────────┐┌──────────┐┌─────────┐ ┌───────┐ ┌───────────┐»
# «      q_4 -> 1 ┤0          ├┤ Ry(-π/2) ├┤ Rz(π/2) ├─┤ Ry(π) ├─┤0          ├»
# «               │           │└──────────┘└─────────┘ └───────┘ │           │»
# «      q_3 -> 2 ┤  Acecr_pm ├──────────────────────────────────┤  Acecr_pm ├»
# «               │           │┌─────────┐ ┌─────────┐┌─────────┐│           │»
# «      q_2 -> 3 ┤1          ├┤ Rz(π/2) ├─┤ Rx(π/2) ├┤ Rx(π/2) ├┤1          ├»
# «               └───────────┘└─────────┘ └─────────┘└─────────┘└───────────┘»
# «      q_0 -> 4 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «      q_1 -> 5 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_0 -> 6 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «                                                                     »
# «      q_5 -> 0 ──────────────────────────────────────────────────────»
# «               ┌───┐┌──────────┐┌──────────┐┌───────────┐┌──────────┐»
# «      q_4 -> 1 ┤ X ├┤ Rx(-π/2) ├┤ Rz(-π/2) ├┤1          ├┤ Ry(-π/2) ├»
# «               └─┬─┘└──────────┘└──────────┘│  Acecr_pm │├──────────┤»
# «      q_3 -> 2 ──┼──────────────────────────┤0          ├┤ Rx(-π/2) ├»
# «                 │  ┌─────────┐    ┌────┐   └┬──────────┤├─────────┬┘»
# «      q_2 -> 3 ──■──┤ Rz(π/2) ├────┤ √X ├────┤ Rz(3π/4) ├┤ Rz(π/2) ├─»
# «                    └─────────┘    └────┘    └──────────┘└─────────┘ »
# ...
# «      q_1 -> 5 ──────────────────────────────────────────────────────────────»
# «                                                                             »
# «ancilla_0 -> 6 ──────────────────────────────────────────────────────────────»
# «                                                                             »
# «                                                                            »
# «      q_5 -> 0 ─────────────────────────────────────────────────────────────»
# «               ┌──────────┐┌─────────┐ ┌───────────┐┌──────────┐┌──────────┐»
# «      q_4 -> 1 ┤ Rz(-π/2) ├┤ Ry(π/2) ├─┤0          ├┤ Rx(-π/2) ├┤ Rz(-π/2) ├»
# «               └──────────┘└─────────┘ │           │└──────────┘└──────────┘»
# «      q_3 -> 2 ────────────────────────┤  Acecr_pm ├────────────────────────»
# «               ┌──────────┐┌──────────┐│           │┌──────────┐ ┌────────┐ »
# «      q_2 -> 3 ┤ Rx(-π/2) ├┤ Rz(-π/2) ├┤1          ├┤ Ry(-π/2) ├─┤ Rz(-π) ├─»
# «               └──────────┘└──────────┘└───────────┘└──────────┘ └────────┘ »
# «      q_0 -> 4 ─────────────────────────────────────────────────────────────»
# «                                                                            »
# «      q_1 -> 5 ─────────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_0 -> 6 ─────────────────────────────────────────────────────────────»
# «                                                                            »
# «                                                      ┌────┐  ┌──────────┐»
# «      q_5 -> 0 ─────────────────────────────────■─────┤ √X ├──┤ Rz(-π/2) ├»
# «               ┌─────────────┐┌────┐┌────────┐┌─┴─┐┌──┴────┴─┐└──────────┘»
# «      q_4 -> 1 ┤ Rz(0.02245) ├┤ √X ├┤ Rz(-π) ├┤ X ├┤ Rz(π/2) ├────────────»
# «               └─────────────┘└────┘└────────┘└───┘└─────────┘            »
# «      q_3 -> 2 ───────────────────────────────────────────────────────────»
# «                                                                          »
# «      q_2 -> 3 ───────────────────────────────────────────────────────────»
# «                                                                          »
# «      q_0 -> 4 ───────────────────────────────────────────────────────────»
# «                                                                          »
# «      q_1 -> 5 ───────────────────────────────────────────────────────────»
# «                                                                          »
# «ancilla_0 -> 6 ───────────────────────────────────────────────────────────»
# «                                                                          »
# «               ┌────┐     ┌─────────┐   ┌────┐   ┌────────────┐┌───────────┐»
# «      q_5 -> 0 ┤ √X ├──■──┤ Rz(π/2) ├───┤ √X ├───┤ Rz(3.9045) ├┤0          ├»
# «               └────┘┌─┴─┐└──┬───┬──┘┌──┴────┴──┐└────────────┘│  Acecr_pm │»
# «      q_4 -> 1 ──────┤ X ├───┤ X ├───┤ Rz(-π/2) ├──────■───────┤1          ├»
# «                     └───┘   └───┘   └──────────┘    ┌─┴─┐     └┬─────────┬┘»
# «      q_3 -> 2 ──────────────────────────────────────┤ X ├──────┤ Rz(π/4) ├─»
# «                                                     └───┘      └─────────┘ »
# «      q_2 -> 3 ─────────────────────────────────────────────────────────────»
# «                                                                            »
# «      q_0 -> 4 ─────────────────────────────────────────────────────────────»
# «                                                                            »
# «      q_1 -> 5 ─────────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_0 -> 6 ─────────────────────────────────────────────────────────────»
# «                                                                            »
# «                ┌───────┐  ┌──────────┐┌─────────┐ ┌───────┐┌───────────┐»
# «      q_5 -> 0 ─┤ Ry(π) ├──┤ Rz(-π/2) ├┤ Rz(π/2) ├─┤ Ry(π) ├┤0          ├»
# «               ┌┴───────┴─┐└──────────┘├─────────┤ └───────┘│  Acecr_pm │»
# «      q_4 -> 1 ┤ Rx(-π/2) ├─────■──────┤ Rx(π/2) ├──────────┤1          ├»
# «               └──────────┘   ┌─┴─┐    ├─────────┴┐         └───────────┘»
# «      q_3 -> 2 ───────────────┤ X ├────┤ Rz(-π/4) ├──────────────────────»
# «                              └───┘    └──────────┘                      »
# «      q_2 -> 3 ──────────────────────────────────────────────────────────»
# «                                                                         »
# «      q_0 -> 4 ──────────────────────────────────────────────────────────»
# «                                                                         »
# «      q_1 -> 5 ──────────────────────────────────────────────────────────»
# «                                                                         »
# «ancilla_0 -> 6 ──────────────────────────────────────────────────────────»
# «                                                                         »
# «                                            ┌────┐┌──────────┐      »
# «      q_5 -> 0 ──────────────────────■──────┤ √X ├┤ Rz(3π/4) ├──────»
# «               ┌──────────┐        ┌─┴─┐    └────┘├─────────┬┘┌────┐»
# «      q_4 -> 1 ┤ Rz(-π/4) ├──■─────┤ X ├──────■───┤ Rz(π/2) ├─┤ √X ├»
# «               └──────────┘┌─┴─┐┌──┴───┴───┐┌─┴─┐ ├─────────┤ └────┘»
# «      q_3 -> 2 ────────────┤ X ├┤ Rz(-π/4) ├┤ X ├─┤ Rz(π/4) ├───────»
# «                           └───┘└──────────┘└───┘ └─────────┘       »
# «      q_2 -> 3 ─────────────────────────────────────────────────────»
# «                                                                    »
# «      q_0 -> 4 ─────────────────────────────────────────────────────»
# «                                                                    »
# «      q_1 -> 5 ─────────────────────────────────────────────────────»
# «                                                                    »
# «ancilla_0 -> 6 ─────────────────────────────────────────────────────»
# «                                                                    »
# «                                                       ┌───┐    ┌─────────┐»
# «      q_5 -> 0 ────────────────────────────────────────┤ X ├────┤ Rz(π/4) ├»
# «               ┌──────────┐┌───────────┐┌──────────┐   └─┬─┘    ├─────────┤»
# «      q_4 -> 1 ┤ Rz(3π/4) ├┤1          ├┤ Rx(-π/2) ├─────■──────┤ Rx(π/2) ├»
# «               └──────────┘│  Acecr_pm │└┬───────┬─┘┌──────────┐├─────────┤»
# «      q_3 -> 2 ────────────┤0          ├─┤ Ry(π) ├──┤ Rz(-π/2) ├┤ Rz(π/2) ├»
# «                           └───────────┘ └───────┘  └──────────┘└─────────┘»
# «      q_2 -> 3 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «      q_0 -> 4 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «      q_1 -> 5 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_0 -> 6 ────────────────────────────────────────────────────────────»
# «                                                                           »
# «                                     ┌───┐ ┌──────────┐            »
# «      q_5 -> 0 ──────────────────────┤ X ├─┤ Rz(-π/4) ├────────────»
# «                        ┌───────────┐└─┬─┘┌┴──────────┤┌──────────┐»
# «      q_4 -> 1 ─────────┤1          ├──■──┤1          ├┤ Rx(-π/2) ├»
# «               ┌───────┐│  Acecr_pm │     │  Acecr_pm │└┬───────┬─┘»
# «      q_3 -> 2 ┤ Ry(π) ├┤0          ├─────┤0          ├─┤ Ry(π) ├──»
# «               └───────┘└───────────┘     └───────────┘ └───────┘  »
# «      q_2 -> 3 ────────────────────────────────────────────────────»
# «                                                                   »
# «      q_0 -> 4 ────────────────────────────────────────────────────»
# «                                                                   »
# «      q_1 -> 5 ────────────────────────────────────────────────────»
# «                                                                   »
# «ancilla_0 -> 6 ────────────────────────────────────────────────────»
# «                                                                   »
# «                              ┌───┐   ┌──────────┐                ┌───┐   »
# «      q_5 -> 0 ───────────────┤ X ├───┤ Rz(-π/4) ├────────────────┤ X ├───»
# «               ┌──────────┐   └─┬─┘   ├─────────┬┘┌───────────┐   └─┬─┘   »
# «      q_4 -> 1 ┤ Rz(-π/4) ├─────■─────┤ Rx(π/2) ├─┤1          ├─────■─────»
# «               ├──────────┤┌─────────┐└┬───────┬┘ │  Acecr_pm │┌─────────┐»
# «      q_3 -> 2 ┤ Rz(-π/2) ├┤ Rz(π/2) ├─┤ Ry(π) ├──┤0          ├┤ Rz(π/2) ├»
# «               └──────────┘└─────────┘ └───────┘  └───────────┘└─────────┘»
# «      q_2 -> 3 ───────────────────────────────────────────────────────────»
# «                                                                          »
# «      q_0 -> 4 ───────────────────────────────────────────────────────────»
# «                                                                          »
# «      q_1 -> 5 ───────────────────────────────────────────────────────────»
# «                                                                          »
# «ancilla_0 -> 6 ───────────────────────────────────────────────────────────»
# «                                                                          »
# «               ┌─────────┐   ┌────┐   ┌─────────┐                        »
# «      q_5 -> 0 ┤ Rz(π/2) ├───┤ √X ├───┤ Rz(π/2) ├────────────────────────»
# «               └┬───────┬┘┌──┴────┴─┐┌┴─────────┴┐┌─────────┐ ┌─────────┐»
# «      q_4 -> 1 ─┤ Rz(π) ├─┤ Ry(π/2) ├┤1          ├┤ Rz(π/2) ├─┤ Rx(π/2) ├»
# «               ┌┴───────┴┐└─────────┘│  Acecr_pm │├─────────┴┐├─────────┤»
# «      q_3 -> 2 ┤ Rx(π/2) ├───────────┤0          ├┤ Ry(-π/2) ├┤ Ry(π/2) ├»
# «               └─────────┘           └───────────┘└──────────┘└─────────┘»
# «      q_2 -> 3 ──────────────────────────────────────────────────────────»
# «                                                                         »
# «      q_0 -> 4 ──────────────────────────────────────────────────────────»
# «                                                                         »
# «      q_1 -> 5 ──────────────────────────────────────────────────────────»
# «                                                                         »
# «ancilla_0 -> 6 ──────────────────────────────────────────────────────────»
# «                                                                         »
# «               ┌───────────┐ ┌───────┐  ┌──────────┐┌─────────┐ ┌───────────┐»
# «      q_5 -> 0 ┤0          ├─┤ Ry(π) ├──┤ Rz(-π/2) ├┤ Ry(π/2) ├─┤0          ├»
# «               │  Acecr_pm │┌┴───────┴─┐├──────────┤├─────────┴┐│  Acecr_pm │»
# «      q_4 -> 1 ┤1          ├┤ Rx(-π/2) ├┤ Rx(-π/2) ├┤ Rz(-π/2) ├┤1          ├»
# «               └───────────┘└──────────┘└──────────┘└──────────┘└───────────┘»
# «      q_3 -> 2 ──────────────────────────────────────────────────────────────»
# «                                                                             »
# «      q_2 -> 3 ──────────────────────────────────────────────────────────────»
# «                                                                             »
# «      q_0 -> 4 ──────────────────────────────────────────────────────────────»
# «                                                                             »
# «      q_1 -> 5 ──────────────────────────────────────────────────────────────»
# «                                                                             »
# «ancilla_0 -> 6 ──────────────────────────────────────────────────────────────»
# «                                                                             »
# «               ┌──────────┐┌──────────┐                             »
# «      q_5 -> 0 ┤ Rx(-π/2) ├┤ Rz(-π/2) ├──■──────────────────────────»
# «               ├──────────┤└┬────────┬┘┌─┴─┐┌──────────┐┌──────────┐»
# «      q_4 -> 1 ┤ Ry(-π/2) ├─┤ Rz(-π) ├─┤ X ├┤ Rx(-π/2) ├┤ Rz(-π/2) ├»
# «               └──────────┘ └────────┘ └───┘└──────────┘└──────────┘»
# «      q_3 -> 2 ─────────────────────────────────────────────────────»
# «                                                                    »
# «      q_2 -> 3 ─────────────────────────────────────────────────────»
# «                                                                    »
# «      q_0 -> 4 ─────────────────────────────────────────────────────»
# «                                                                    »
# «      q_1 -> 5 ─────────────────────────────────────────────────────»
# «                                                                    »
# «ancilla_0 -> 6 ─────────────────────────────────────────────────────»
# «                                                                    »
# «                                                                             »
# «      q_5 -> 0 ──────────────────────────────────────────────────────────────»
# «               ┌───────────┐┌──────────┐ ┌────────┐ ┌───────────┐ ┌───────┐  »
# «      q_4 -> 1 ┤1          ├┤ Ry(-π/2) ├─┤ Rz(-π) ├─┤0          ├─┤ Ry(π) ├──»
# «               │  Acecr_pm │├──────────┤┌┴────────┴┐│           │ └───────┘  »
# «      q_3 -> 2 ┤0          ├┤ Rx(-π/2) ├┤ Rz(-π/2) ├┤  Acecr_pm ├────────────»
# «               └───────────┘└──────────┘└──────────┘│           │┌──────────┐»
# «      q_2 -> 3 ─────────────────────────────────────┤1          ├┤ Rx(-π/2) ├»
# «                                                    └───────────┘└──────────┘»
# «      q_0 -> 4 ──────────────────────────────────────────────────────────────»
# «                                                                             »
# «      q_1 -> 5 ──────────────────────────────────────────────────────────────»
# «                                                                             »
# «ancilla_0 -> 6 ──────────────────────────────────────────────────────────────»
# «                                                                             »
# «                                                                            »
# «      q_5 -> 0 ─────────────────────────────────────────────────────────────»
# «               ┌──────────┐┌─────────┐ ┌───────────┐┌──────────┐┌──────────┐»
# «      q_4 -> 1 ┤ Rz(-π/2) ├┤ Ry(π/2) ├─┤0          ├┤ Rx(-π/2) ├┤ Rz(-π/2) ├»
# «               └──────────┘└─────────┘ │           │└──────────┘└──────────┘»
# «      q_3 -> 2 ────────────────────────┤  Acecr_pm ├────────────────────────»
# «               ┌──────────┐┌──────────┐│           │┌──────────┐ ┌────────┐ »
# «      q_2 -> 3 ┤ Rx(-π/2) ├┤ Rz(-π/2) ├┤1          ├┤ Ry(-π/2) ├─┤ Rz(-π) ├─»
# «               └──────────┘└──────────┘└───────────┘└──────────┘ └────────┘ »
# «      q_0 -> 4 ─────────────────────────────────────────────────────────────»
# «                                                                            »
# «      q_1 -> 5 ─────────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_0 -> 6 ─────────────────────────────────────────────────────────────»
# «                                                                            »
# «
# «      q_5 -> 0 ──────────────────────────────────────
# «
# «      q_4 -> 1 ──■───────────────────────────────────
# «                 │
# «      q_3 -> 2 ──┼───────────────────────────────────
# «               ┌─┴─┐┌─────────┐┌───────┐┌───────────┐
# «      q_2 -> 3 ┤ X ├┤ Rz(π/2) ├┤ Ry(π) ├┤0          ├
# «               └───┘└─────────┘└───────┘│           │
# «      q_0 -> 4 ─────────────────────────┤  Acecr_pm ├
# «                                        │           │
# «      q_1 -> 5 ─────────────────────────┤1          ├
# «                                        └───────────┘
# «ancilla_0 -> 6 ──────────────────────────────────────
# «

# %%
t_trans = transpile(t5, backend, optimization_level = 3)

# %%
out = superstaq_provider.ibmq_compile(t_trans, target="ibmq_jakarta_qpu")

# %%
out.circuit.draw(output='mpl')

# %%
out.pulse_sequence.draw()

# %%
out.circuit.count_ops()

# %%
out2 = superstaq_provider.ibmq_compile(t_orign, target="ibmq_jakarta_qpu")

# %%
out2.circuit.count_ops()

# %%
out2.circuit.draw(output='mpl')

# %%
out2.pulse_sequence.draw()

# %%
t_orign = transpile(t5, backend, optimization_level = 3)

# %%
t_orign_schedule = schedule(
            circuits=t_orign,
            backend=backend,
            inst_map=None,
            meas_map=None,
            method=None,
        )

# %%
t_orign_schedule.draw()

# %%
#19

# %%
t_orign_schedule.children[5]
# Out:
# (6080,
#  Schedule((0, ShiftPhase(1.5707963267948966, DriveChannel(3))), (0, ShiftPhase(1.5707963267948966, ControlChannel(3))), (0, ShiftPhase(1.5707963267948966, ControlChannel(8))), (0, Play(Drag(duration=160, amp=(-3.554362359433285e-17-0.19349047479964404j), sigma=40, beta=0.557336464289407, name='Ym_d3'), DriveChannel(3), name='Ym_d3')), (0, Play(Drag(duration=160, amp=(0.09343255413184134+0.0013155736420234682j), sigma=40, beta=-0.8260101223075255, name='X90p_d5'), DriveChannel(5), name='X90p_d5')), (160, Play(GaussianSquare(duration=496, amp=(0.06823970936107211+0.0029056778790278004j), sigma=64, width=240, name='CR90p_d5_u6'), DriveChannel(5), name='CR90p_d5_u6')), (160, Play(GaussianSquare(duration=496, amp=(0.4793427847550843-0.08228725735534022j), sigma=64, width=240, name='CR90p_u6'), ControlChannel(6), name='CR90p_u6')), (656, Play(Drag(duration=160, amp=(0.19349047479964404+0j), sigma=40, beta=0.557336464289407, name='Xp_d3'), DriveChannel(3), name='Xp_d3')), (816, Play(GaussianSquare(duration=496, amp=(-0.06823970936107211-0.002905677879027792j), sigma=64, width=240, name='CR90m_d5_u6'), DriveChannel(5), name='CR90m_d5_u6')), (816, Play(GaussianSquare(duration=496, amp=(-0.4793427847550843+0.08228725735534027j), sigma=64, width=240, name='CR90m_u6'), ControlChannel(6), name='CR90m_u6')), name="cx"))

# %%
help(t_orign_schedule)
# Out:
# Help on Schedule in module qiskit.pulse.schedule object:
#
# class Schedule(builtins.object)
#  |  Schedule(*schedules: Union[ForwardRef('Schedule'), qiskit.pulse.instructions.instruction.Instruction, Tuple[int, Union[ForwardRef('Schedule'), qiskit.pulse.instructions.instruction.Instruction]]], name: Union[str, NoneType] = None, metadata: Union[dict, NoneType] = None)
#  |
#  |  A quantum program *schedule* with exact time constraints for its instructions, operating
#  |  over all input signal *channels* and supporting special syntaxes for building.
#  |
#  |  Pulse program representation for the original Qiskit Pulse model [1].
#  |  Instructions are not allowed to overlap in time
#  |  on the same channel. This overlap constraint is immediately
#  |  evaluated when a new instruction is added to the ``Schedule`` object.
#  |
#  |  It is necessary to specify the absolute start time and duration
#  |  for each instruction so as to deterministically fix its execution time.
#  |
#  |  The ``Schedule`` program supports some syntax sugar for easier programming.
#  |
#  |  - Appending an instruction to the end of a channel
#  |
#  |  .. code-block:: python
#  |
#  |      sched = Schedule()
#  |      sched += Play(Gaussian(160, 0.1, 40), DriveChannel(0))
#  |
#  |  - Appending an instruction shifted in time by a given amount
#  |
#  |  .. code-block:: python
#  |
#  |      sched = Schedule()
#  |      sched += Play(Gaussian(160, 0.1, 40), DriveChannel(0)) << 30
#  |
#  |  - Merge two schedules
#  |
#  |  .. code-block:: python
#  |
#  |      sched1 = Schedule()
#  |      sched1 += Play(Gaussian(160, 0.1, 40), DriveChannel(0))
#  |
#  |      sched2 = Schedule()
#  |      sched2 += Play(Gaussian(160, 0.1, 40), DriveChannel(1))
#  |      sched2 = sched1 | sched2
#  |
#  |  A ``PulseError`` is immediately raised when the overlap constraint is violated.
#  |
#  |  In the schedule representation, we cannot parametrize the duration of instructions.
#  |  Thus we need to create a new schedule object for each duration.
#  |  To parametrize an instruction's duration, the :class:`~qiskit.pulse.ScheduleBlock`
#  |  representation may be used instead.
#  |
#  |  References:
#  |      [1]: https://arxiv.org/abs/2004.06755
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, other: Union[ForwardRef('Schedule'), qiskit.pulse.instructions.instruction.Instruction]) -> 'Schedule'
#  |      Return a new schedule with ``other`` inserted within ``self`` at ``start_time``.
#  |
#  |  __eq__(self, other: Union[ForwardRef('Schedule'), qiskit.pulse.instructions.instruction.Instruction]) -> bool
#  |      Test if two Schedule are equal.
#  |
#  |      Equality is checked by verifying there is an equal instruction at every time
#  |      in ``other`` for every instruction in this ``Schedule``.
#  |
#  |      .. warning::
#  |
#  |          This does not check for logical equivalency. Ie.,
#  |
#  |          ```python
#  |          >>> Delay(10, DriveChannel(0)) + Delay(10, DriveChannel(0))
#  |              == Delay(20, DriveChannel(0))
#  |          False
#  |          ```
#  |
#  |  __init__(self, *schedules: Union[ForwardRef('Schedule'), qiskit.pulse.instructions.instruction.Instruction, Tuple[int, Union[ForwardRef('Schedule'), qiskit.pulse.instructions.instruction.Instruction]]], name: Union[str, NoneType] = None, metadata: Union[dict, NoneType] = None)
#  |      Create an empty schedule.
#  |
#  |      Args:
#  |          *schedules: Child Schedules of this parent Schedule. May either be passed as
#  |                      the list of schedules, or a list of ``(start_time, schedule)`` pairs.
#  |          name: Name of this schedule. Defaults to an autogenerated string if not provided.
#  |          metadata: Arbitrary key value metadata to associate with the schedule. This gets
#  |              stored as free-form data in a dict in the
#  |              :attr:`~qiskit.pulse.Schedule.metadata` attribute. It will not be directly
#  |              used in the schedule.
#  |      Raises:
#  |          TypeError: if metadata is not a dict.
#  |
#  |  __len__(self) -> int
#  |      Return number of instructions in the schedule.
#  |
#  |  __lshift__(self, time: int) -> 'Schedule'
#  |      Return a new schedule which is shifted forward by ``time``.
#  |
#  |  __or__(self, other: Union[ForwardRef('Schedule'), qiskit.pulse.instructions.instruction.Instruction]) -> 'Schedule'
#  |      Return a new schedule which is the union of `self` and `other`.
#  |
#  |  __repr__(self) -> str
#  |      Return repr(self).
#  |
#  |  append(self, schedule: Union[ForwardRef('Schedule'), qiskit.pulse.instructions.instruction.Instruction], name: Union[str, NoneType] = None, inplace: bool = False) -> 'Schedule'
#  |      Return a new schedule with ``schedule`` inserted at the maximum time over
#  |      all channels shared between ``self`` and ``schedule``.
#  |
#  |      .. math::
#  |
#  |          t = \textrm{max}(\texttt{x.stop_time} |\texttt{x} \in
#  |              \texttt{self.channels} \cap \texttt{schedule.channels})
#  |
#  |      Args:
#  |          schedule: Schedule to be appended.
#  |          name: Name of the new ``Schedule``. Defaults to name of ``self``.
#  |          inplace: Perform operation inplace on this schedule. Otherwise
#  |              return a new ``Schedule``.
#  |
#  |  assign_parameters(self, value_dict: Dict[qiskit.circuit.parameterexpression.ParameterExpression, Union[ForwardRef('ParameterExpression'), float]], inplace: bool = True) -> 'Schedule'
#  |      Assign the parameters in this schedule according to the input.
#  |
#  |      Args:
#  |          value_dict: A mapping from Parameters to either numeric values or another
#  |              Parameter expression.
#  |          inplace: Set ``True`` to override this instance with new parameter.
#  |
#  |      Returns:
#  |          Schedule with updated parameters.
#  |
#  |  ch_duration(self, *channels: qiskit.pulse.channels.Channel) -> int
#  |      Return the time of the end of the last instruction over the supplied channels.
#  |
#  |      Args:
#  |          *channels: Channels within ``self`` to include.
#  |
#  |  ch_start_time(self, *channels: qiskit.pulse.channels.Channel) -> int
#  |      Return the time of the start of the first instruction over the supplied channels.
#  |
#  |      Args:
#  |          *channels: Channels within ``self`` to include.
#  |
#  |  ch_stop_time(self, *channels: qiskit.pulse.channels.Channel) -> int
#  |      Return maximum start time over supplied channels.
#  |
#  |      Args:
#  |          *channels: Channels within ``self`` to include.
#  |
#  |  draw(self, dt: Any = None, style: Union[Dict[str, Any], NoneType] = None, filename: Any = None, interp_method: Any = None, scale: Any = None, channel_scales: Any = None, plot_all: Any = None, plot_range: Any = None, interactive: Any = None, table: Any = None, label: Any = None, framechange: Any = None, channels: Any = None, show_framechange_channels: Any = None, draw_title: Any = None, backend=None, time_range: Union[Tuple[int, int], NoneType] = None, time_unit: str = 'dt', disable_channels: Union[List[qiskit.pulse.channels.Channel], NoneType] = None, show_snapshot: bool = True, show_framechange: bool = True, show_waveform_info: bool = True, show_barrier: bool = True, plotter: str = 'mpl2d', axis: Union[Any, NoneType] = None)
#  |      Plot the schedule.
#  |
#  |      Args:
#  |          style: Stylesheet options. This can be dictionary or preset stylesheet classes. See
#  |              :py:class:`~qiskit.visualization.pulse_v2.stylesheets.IQXStandard`,
#  |              :py:class:`~qiskit.visualization.pulse_v2.stylesheets.IQXSimple`, and
#  |              :py:class:`~qiskit.visualization.pulse_v2.stylesheets.IQXDebugging` for details of
#  |              preset stylesheets.
#  |          backend (Optional[BaseBackend]): Backend object to play the input pulse program.
#  |              If provided, the plotter may use to make the visualization hardware aware.
#  |          time_range: Set horizontal axis limit. Tuple `(tmin, tmax)`.
#  |          time_unit: The unit of specified time range either `dt` or `ns`.
#  |              The unit of `ns` is available only when `backend` object is provided.
#  |          disable_channels: A control property to show specific pulse channel.
#  |              Pulse channel instances provided as a list are not shown in the output image.
#  |          show_snapshot: Show snapshot instructions.
#  |          show_framechange: Show frame change instructions. The frame change represents
#  |              instructions that modulate phase or frequency of pulse channels.
#  |          show_waveform_info: Show additional information about waveforms such as their name.
#  |          show_barrier: Show barrier lines.
#  |          plotter: Name of plotter API to generate an output image.
#  |              One of following APIs should be specified::
#  |
#  |                  mpl2d: Matplotlib API for 2D image generation.
#  |                      Matplotlib API to generate 2D image. Charts are placed along y axis with
#  |                      vertical offset. This API takes matplotlib.axes.Axes as ``axis`` input.
#  |
#  |              ``axis`` and ``style`` kwargs may depend on the plotter.
#  |          axis: Arbitrary object passed to the plotter. If this object is provided,
#  |              the plotters use a given ``axis`` instead of internally initializing
#  |              a figure object. This object format depends on the plotter.
#  |              See plotter argument for details.
#  |          dt: Deprecated. This argument is used by the legacy pulse drawer.
#  |          filename: Deprecated. This argument is used by the legacy pulse drawer.
#  |              To save output image, you can call ``.savefig`` method with
#  |              returned Matplotlib Figure object.
#  |          interp_method: Deprecated. This argument is used by the legacy pulse drawer.
#  |          scale: Deprecated. This argument is used by the legacy pulse drawer.
#  |          channel_scales: Deprecated. This argument is used by the legacy pulse drawer.
#  |          plot_all: Deprecated. This argument is used by the legacy pulse drawer.
#  |          plot_range: Deprecated. This argument is used by the legacy pulse drawer.
#  |          interactive: Deprecated. This argument is used by the legacy pulse drawer.
#  |          table: Deprecated. This argument is used by the legacy pulse drawer.
#  |          label: Deprecated. This argument is used by the legacy pulse drawer.
#  |          framechange: Deprecated. This argument is used by the legacy pulse drawer.
#  |          channels: Deprecated. This argument is used by the legacy pulse drawer.
#  |          show_framechange_channels: Deprecated. This argument is used by the legacy pulse drawer.
#  |          draw_title: Deprecated. This argument is used by the legacy pulse drawer.
#  |
#  |      Returns:
#  |          Visualization output data.
#  |          The returned data type depends on the ``plotter``.
#  |          If matplotlib family is specified, this will be a ``matplotlib.pyplot.Figure`` data.
#  |
#  |  exclude(self, *filter_funcs: Callable, channels: Union[Iterable[qiskit.pulse.channels.Channel], NoneType] = None, instruction_types: Union[Iterable[abc.ABCMeta], abc.ABCMeta] = None, time_ranges: Union[Iterable[Tuple[int, int]], NoneType] = None, intervals: Union[Iterable[Tuple[int, int]], NoneType] = None, check_subroutine: bool = True) -> 'Schedule'
#  |      Return a ``Schedule`` with only the instructions from this Schedule *failing*
#  |      at least one of the provided filters.
#  |      This method is the complement of py:meth:`~self.filter`, so that::
#  |
#  |          self.filter(args) | self.exclude(args) == self
#  |
#  |      Args:
#  |          filter_funcs: A list of Callables which take a (int, Union['Schedule', Instruction])
#  |              tuple and return a bool.
#  |          channels: For example, ``[DriveChannel(0), AcquireChannel(0)]``.
#  |          instruction_types: For example, ``[PulseInstruction, AcquireInstruction]``.
#  |          time_ranges: For example, ``[(0, 5), (6, 10)]``.
#  |          intervals: For example, ``[(0, 5), (6, 10)]``.
#  |          check_subroutine: Set `True` to individually filter instructions inside of a subroutine
#  |              defined by the :py:class:`~qiskit.pulse.instructions.Call` instruction.
#  |
#  |  filter(self, *filter_funcs: Callable, channels: Union[Iterable[qiskit.pulse.channels.Channel], NoneType] = None, instruction_types: Union[Iterable[abc.ABCMeta], abc.ABCMeta] = None, time_ranges: Union[Iterable[Tuple[int, int]], NoneType] = None, intervals: Union[Iterable[Tuple[int, int]], NoneType] = None, check_subroutine: bool = True) -> 'Schedule'
#  |      Return a new ``Schedule`` with only the instructions from this ``Schedule`` which pass
#  |      though the provided filters; i.e. an instruction will be retained iff every function in
#  |      ``filter_funcs`` returns ``True``, the instruction occurs on a channel type contained in
#  |      ``channels``, the instruction type is contained in ``instruction_types``, and the period
#  |      over which the instruction operates is *fully* contained in one specified in
#  |      ``time_ranges`` or ``intervals``.
#  |
#  |      If no arguments are provided, ``self`` is returned.
#  |
#  |      Args:
#  |          filter_funcs: A list of Callables which take a (int, Union['Schedule', Instruction])
#  |              tuple and return a bool.
#  |          channels: For example, ``[DriveChannel(0), AcquireChannel(0)]``.
#  |          instruction_types: For example, ``[PulseInstruction, AcquireInstruction]``.
#  |          time_ranges: For example, ``[(0, 5), (6, 10)]``.
#  |          intervals: For example, ``[(0, 5), (6, 10)]``.
#  |          check_subroutine: Set `True` to individually filter instructions inside of a subroutine
#  |              defined by the :py:class:`~qiskit.pulse.instructions.Call` instruction.
#  |
#  |  flatten(self) -> 'Schedule'
#  |      Deprecated.
#  |
#  |  get_parameters(self, parameter_name: str) -> List[qiskit.circuit.parameter.Parameter]
#  |      Get parameter object bound to this schedule by string name.
#  |
#  |      Because different ``Parameter`` objects can have the same name,
#  |      this method returns a list of ``Parameter`` s for the provided name.
#  |
#  |      Args:
#  |          parameter_name: Name of parameter.
#  |
#  |      Returns:
#  |          Parameter objects that have corresponding name.
#  |
#  |  insert(self, start_time: int, schedule: Union[ForwardRef('Schedule'), qiskit.pulse.instructions.instruction.Instruction], name: Union[str, NoneType] = None, inplace: bool = False) -> 'Schedule'
#  |      Return a new schedule with ``schedule`` inserted into ``self`` at ``start_time``.
#  |
#  |      Args:
#  |          start_time: Time to insert the schedule.
#  |          schedule: Schedule to insert.
#  |          name: Name of the new schedule. Defaults to the name of self.
#  |          inplace: Perform operation inplace on this schedule. Otherwise
#  |              return a new ``Schedule``.
#  |
#  |  is_parameterized(self) -> bool
#  |      Return True iff the instruction is parameterized.
#  |
#  |  replace(self, old: Union[ForwardRef('Schedule'), qiskit.pulse.instructions.instruction.Instruction], new: Union[ForwardRef('Schedule'), qiskit.pulse.instructions.instruction.Instruction], inplace: bool = False) -> 'Schedule'
#  |      Return a ``Schedule`` with the ``old`` instruction replaced with a ``new``
#  |      instruction.
#  |
#  |      The replacement matching is based on an instruction equality check.
#  |
#  |      .. jupyter-kernel:: python3
#  |          :id: replace
#  |
#  |      .. jupyter-execute::
#  |
#  |          from qiskit import pulse
#  |
#  |          d0 = pulse.DriveChannel(0)
#  |
#  |          sched = pulse.Schedule()
#  |
#  |          old = pulse.Play(pulse.Constant(100, 1.0), d0)
#  |          new = pulse.Play(pulse.Constant(100, 0.1), d0)
#  |
#  |          sched += old
#  |
#  |          sched = sched.replace(old, new)
#  |
#  |          assert sched == pulse.Schedule(new)
#  |
#  |      Only matches at the top-level of the schedule tree. If you wish to
#  |      perform this replacement over all instructions in the schedule tree.
#  |      Flatten the schedule prior to running::
#  |
#  |      .. jupyter-execute::
#  |
#  |          sched = pulse.Schedule()
#  |
#  |          sched += pulse.Schedule(old)
#  |
#  |          sched = sched.flatten()
#  |
#  |          sched = sched.replace(old, new)
#  |
#  |          assert sched == pulse.Schedule(new)
#  |
#  |      Args:
#  |          old: Instruction to replace.
#  |          new: Instruction to replace with.
#  |          inplace: Replace instruction by mutably modifying this ``Schedule``.
#  |
#  |      Returns:
#  |          The modified schedule with ``old`` replaced by ``new``.
#  |
#  |      Raises:
#  |          PulseError: If the ``Schedule`` after replacements will has a timing overlap.
#  |
#  |  shift(self, time: int, name: Union[str, NoneType] = None, inplace: bool = False) -> 'Schedule'
#  |      Return a schedule shifted forward by ``time``.
#  |
#  |      Args:
#  |          time: Time to shift by.
#  |          name: Name of the new schedule. Defaults to the name of self.
#  |          inplace: Perform operation inplace on this schedule. Otherwise
#  |              return a new ``Schedule``.
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  initialize_from(other_program: Any, name: Union[str, NoneType] = None) -> 'Schedule' from builtins.type
#  |      Create new schedule object with metadata of another schedule object.
#  |
#  |      Args:
#  |          other_program: Qiskit program that provides metadata to new object.
#  |          name: Name of new schedule. Name of ``schedule`` is used by default.
#  |
#  |      Returns:
#  |          New schedule object with name and metadata.
#  |
#  |      Raises:
#  |          PulseError: When `other_program` does not provide necessary information.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  channels
#  |      Returns channels that this schedule uses.
#  |
#  |  children
#  |      Return the child schedule components of this ``Schedule`` in the
#  |      order they were added to the schedule.
#  |
#  |      Notes:
#  |          Nested schedules are returned as-is. If you want to collect only instructions,
#  |          use py:meth:`~Schedule.instructions` instead.
#  |
#  |      Returns:
#  |          A tuple, where each element is a two-tuple containing the initial
#  |          scheduled time of each ``NamedValue`` and the component
#  |          itself.
#  |
#  |  duration
#  |      Duration of this schedule.
#  |
#  |  instructions
#  |      Get the time-ordered instructions from self.
#  |
#  |  metadata
#  |      The user provided metadata associated with the schedule.
#  |
#  |      User provided ``dict`` of metadata for the schedule.
#  |      The metadata contents do not affect the semantics of the program
#  |      but are used to influence the execution of the schedule. It is expected
#  |      to be passed between all transforms of the schedule and that providers
#  |      will associate any schedule metadata with the results it returns from the
#  |      execution of that schedule.
#  |
#  |  name
#  |      Name of this Schedule
#  |
#  |  parameters
#  |      Parameters which determine the schedule behavior.
#  |
#  |  start_time
#  |      Starting time of this schedule.
#  |
#  |  stop_time
#  |      Stopping time of this schedule.
#  |
#  |  timeslots
#  |      Time keeping attribute.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __hash__ = None
#  |
#  |  __slotnames__ = []
#  |
#  |  instances_counter = count(287)
#  |
#  |  prefix = 'sched'

# %%
t_orign_schedule.instructions
# Out:
# ((0, ShiftPhase(1.5707963267948966, DriveChannel(1))),
#  (0, ShiftPhase(1.5707963267948966, ControlChannel(0))),
#  (0, ShiftPhase(1.5707963267948966, ControlChannel(4))),
#  (0, ShiftPhase(1.5707963267948966, ControlChannel(5))),
#  (0,
#   Play(Drag(duration=160, amp=(-3.5177580880852906e-17-0.19149783107719934j), sigma=40, beta=-1.0249306744293878, name='Ym_d1'), DriveChannel(1), name='Ym_d1')),
#  (0,
#   Play(Drag(duration=160, amp=(0.09672086584553752-0.0002442998264774194j), sigma=40, beta=0.5292268605797695, name='X90p_d3'), DriveChannel(3), name='X90p_d3')),
#  (160,
#   Play(GaussianSquare(duration=704, amp=(0.06553461814337508-0.0017965272209132079j), sigma=64, width=448, name='CR90p_d3_u3'), DriveChannel(3), name='CR90p_d3_u3')),
#  (160,
#   Play(GaussianSquare(duration=704, amp=(-0.7591395560293808-0.2461181293735626j), sigma=64, width=448, name='CR90p_u3'), ControlChannel(3), name='CR90p_u3')),
#  (864,
#   Play(Drag(duration=160, amp=(0.19149783107719934+0j), sigma=40, beta=-1.0249306744293878, name='Xp_d1'), DriveChannel(1), name='Xp_d1')),
#  (1024,
#   Play(GaussianSquare(duration=704, amp=(-0.06553461814337508+0.001796527220913216j), sigma=64, width=448, name='CR90m_d3_u3'), DriveChannel(3), name='CR90m_d3_u3')),
#  (1024,
#   Play(GaussianSquare(duration=704, amp=(0.7591395560293808+0.2461181293735625j), sigma=64, width=448, name='CR90m_u3'), ControlChannel(3), name='CR90m_u3')),
#  (1728, ShiftPhase(1.5707963267948966, DriveChannel(3))),
#  (1728, ShiftPhase(1.5707963267948966, ControlChannel(3))),
#  (1728, ShiftPhase(1.5707963267948966, ControlChannel(8))),
#  (1728,
#   Play(Drag(duration=160, amp=(-3.554362359433285e-17-0.19349047479964404j), sigma=40, beta=0.557336464289407, name='Ym_d3'), DriveChannel(3), name='Ym_d3')),
#  (1728,
#   Play(Drag(duration=160, amp=(0.09343255413184134+0.0013155736420234682j), sigma=40, beta=-0.8260101223075255, name='X90p_d5'), DriveChannel(5), name='X90p_d5')),
#  (1888,
#   Play(GaussianSquare(duration=496, amp=(0.06823970936107211+0.0029056778790278004j), sigma=64, width=240, name='CR90p_d5_u6'), DriveChannel(5), name='CR90p_d5_u6')),
#  (1888,
#   Play(GaussianSquare(duration=496, amp=(0.4793427847550843-0.08228725735534022j), sigma=64, width=240, name='CR90p_u6'), ControlChannel(6), name='CR90p_u6')),
#  (2384,
#   Play(Drag(duration=160, amp=(0.19349047479964404+0j), sigma=40, beta=0.557336464289407, name='Xp_d3'), DriveChannel(3), name='Xp_d3')),
#  (2544,
#   Play(GaussianSquare(duration=496, amp=(-0.06823970936107211-0.002905677879027792j), sigma=64, width=240, name='CR90m_d5_u6'), DriveChannel(5), name='CR90m_d5_u6')),
#  (2544,
#   Play(GaussianSquare(duration=496, amp=(-0.4793427847550843+0.08228725735534027j), sigma=64, width=240, name='CR90m_u6'), ControlChannel(6), name='CR90m_u6')),
#  (3040, ShiftPhase(1.5707963267948966, DriveChannel(3))),
#  (3040, ShiftPhase(-1.0471975511966, DriveChannel(5))),
#  (3040, ShiftPhase(-1.0471975511966, ControlChannel(11))),
#  (3040, ShiftPhase(1.5707963267948966, ControlChannel(3))),
#  (3040, ShiftPhase(-1.0471975511966, ControlChannel(6))),
#  (3040, ShiftPhase(-1.0471975511966, ControlChannel(7))),
#  (3040, ShiftPhase(1.5707963267948966, ControlChannel(8))),
#  (3040,
#   Play(Drag(duration=160, amp=(-3.554362359433285e-17-0.19349047479964404j), sigma=40, beta=0.557336464289407, name='Ym_d3'), DriveChannel(3), name='Ym_d3')),
#  (3040,
#   Play(Drag(duration=160, amp=(0.09343255413184134+0.0013155736420234682j), sigma=40, beta=-0.8260101223075255, name='X90p_d5'), DriveChannel(5), name='X90p_d5')),
#  (3200,
#   Play(GaussianSquare(duration=496, amp=(0.06823970936107211+0.0029056778790278004j), sigma=64, width=240, name='CR90p_d5_u6'), DriveChannel(5), name='CR90p_d5_u6')),
#  (3200,
#   Play(GaussianSquare(duration=496, amp=(0.4793427847550843-0.08228725735534022j), sigma=64, width=240, name='CR90p_u6'), ControlChannel(6), name='CR90p_u6')),
#  (3696,
#   Play(Drag(duration=160, amp=(0.19349047479964404+0j), sigma=40, beta=0.557336464289407, name='Xp_d3'), DriveChannel(3), name='Xp_d3')),
#  (3856,
#   Play(GaussianSquare(duration=496, amp=(-0.06823970936107211-0.002905677879027792j), sigma=64, width=240, name='CR90m_d5_u6'), DriveChannel(5), name='CR90m_d5_u6')),
#  (3856,
#   Play(GaussianSquare(duration=496, amp=(-0.4793427847550843+0.08228725735534027j), sigma=64, width=240, name='CR90m_u6'), ControlChannel(6), name='CR90m_u6')),
#  (4352, ShiftPhase(1.5707963267948966, DriveChannel(1))),
#  (4352, ShiftPhase(1.5707963267948966, ControlChannel(0))),
#  (4352, ShiftPhase(1.5707963267948966, ControlChannel(4))),
#  (4352, ShiftPhase(1.5707963267948966, ControlChannel(5))),
#  (4352,
#   Play(Drag(duration=160, amp=(-3.5177580880852906e-17-0.19149783107719934j), sigma=40, beta=-1.0249306744293878, name='Ym_d1'), DriveChannel(1), name='Ym_d1')),
#  (4352,
#   Play(Drag(duration=160, amp=(0.09672086584553752-0.0002442998264774194j), sigma=40, beta=0.5292268605797695, name='X90p_d3'), DriveChannel(3), name='X90p_d3')),
#  (4512,
#   Play(GaussianSquare(duration=704, amp=(0.06553461814337508-0.0017965272209132079j), sigma=64, width=448, name='CR90p_d3_u3'), DriveChannel(3), name='CR90p_d3_u3')),
#  (4512,
#   Play(GaussianSquare(duration=704, amp=(-0.7591395560293808-0.2461181293735626j), sigma=64, width=448, name='CR90p_u3'), ControlChannel(3), name='CR90p_u3')),
#  (5216,
#   Play(Drag(duration=160, amp=(0.19149783107719934+0j), sigma=40, beta=-1.0249306744293878, name='Xp_d1'), DriveChannel(1), name='Xp_d1')),
#  (5376,
#   Play(GaussianSquare(duration=704, amp=(-0.06553461814337508+0.001796527220913216j), sigma=64, width=448, name='CR90m_d3_u3'), DriveChannel(3), name='CR90m_d3_u3')),
#  (5376,
#   Play(GaussianSquare(duration=704, amp=(0.7591395560293808+0.2461181293735625j), sigma=64, width=448, name='CR90m_u3'), ControlChannel(3), name='CR90m_u3')),
#  (6080, ShiftPhase(1.5707963267948966, DriveChannel(3))),
#  (6080, ShiftPhase(1.5707963267948966, ControlChannel(3))),
#  (6080, ShiftPhase(1.5707963267948966, ControlChannel(8))),
#  (6080,
#   Play(Drag(duration=160, amp=(-3.554362359433285e-17-0.19349047479964404j), sigma=40, beta=0.557336464289407, name='Ym_d3'), DriveChannel(3), name='Ym_d3')),
#  (6080,
#   Play(Drag(duration=160, amp=(0.09343255413184134+0.0013155736420234682j), sigma=40, beta=-0.8260101223075255, name='X90p_d5'), DriveChannel(5), name='X90p_d5')),
#  (6240,
#   Play(GaussianSquare(duration=496, amp=(0.06823970936107211+0.0029056778790278004j), sigma=64, width=240, name='CR90p_d5_u6'), DriveChannel(5), name='CR90p_d5_u6')),
#  (6240,
#   Play(GaussianSquare(duration=496, amp=(0.4793427847550843-0.08228725735534022j), sigma=64, width=240, name='CR90p_u6'), ControlChannel(6), name='CR90p_u6')),
#  (6736,
#   Play(Drag(duration=160, amp=(0.19349047479964404+0j), sigma=40, beta=0.557336464289407, name='Xp_d3'), DriveChannel(3), name='Xp_d3')),
#  (6896,
#   Play(GaussianSquare(duration=496, amp=(-0.06823970936107211-0.002905677879027792j), sigma=64, width=240, name='CR90m_d5_u6'), DriveChannel(5), name='CR90m_d5_u6')),
#  (6896,
#   Play(GaussianSquare(duration=496, amp=(-0.4793427847550843+0.08228725735534027j), sigma=64, width=240, name='CR90m_u6'), ControlChannel(6), name='CR90m_u6')),
#  (7392, ShiftPhase(-1.5707963267948966, DriveChannel(3))),
#  (7392, ShiftPhase(-3.141592653589793, DriveChannel(5))),
#  (7392, ShiftPhase(-3.141592653589793, ControlChannel(11))),
#  (7392, ShiftPhase(-1.5707963267948966, ControlChannel(3))),
#  (7392, ShiftPhase(-3.141592653589793, ControlChannel(6))),
#  (7392, ShiftPhase(-3.141592653589793, ControlChannel(7))),
#  (7392, ShiftPhase(-1.5707963267948966, ControlChannel(8))),
#  (7392,
#   Play(Drag(duration=160, amp=(0.09672086584553752-0.0002442998264774194j), sigma=40, beta=0.5292268605797695, name='X90p_d3'), DriveChannel(3), name='X90p_d3')),
#  (7392,
#   Play(Drag(duration=160, amp=(-0.0013155736420234713+0.09343255413184134j), sigma=40, beta=-0.8260101223075255, name='Y90p_d5'), DriveChannel(5), name='Y90p_d5')),
#  (7552,
#   Play(GaussianSquare(duration=496, amp=(0.06823970936107211+0.0029056778790278004j), sigma=64, width=240, name='CR90p_d5_u6'), DriveChannel(5), name='CR90p_d5_u6')),
#  (7552,
#   Play(GaussianSquare(duration=496, amp=(0.4793427847550843-0.08228725735534022j), sigma=64, width=240, name='CR90p_u6'), ControlChannel(6), name='CR90p_u6')),
#  (8048,
#   Play(Drag(duration=160, amp=(0.19349047479964404+0j), sigma=40, beta=0.557336464289407, name='Xp_d3'), DriveChannel(3), name='Xp_d3')),
#  (8208,
#   Play(GaussianSquare(duration=496, amp=(-0.06823970936107211-0.002905677879027792j), sigma=64, width=240, name='CR90m_d5_u6'), DriveChannel(5), name='CR90m_d5_u6')),
#  (8208,
#   Play(GaussianSquare(duration=496, amp=(-0.4793427847550843+0.08228725735534027j), sigma=64, width=240, name='CR90m_u6'), ControlChannel(6), name='CR90m_u6')),
#  (8704, ShiftPhase(-1.5707963267948966, DriveChannel(5))),
#  (8704, ShiftPhase(-1.5707963267948966, ControlChannel(11))),
#  (8704, ShiftPhase(-1.5707963267948966, ControlChannel(6))),
#  (8704, ShiftPhase(-1.5707963267948966, ControlChannel(7))),
#  (8704,
#   Play(Drag(duration=160, amp=(-0.0002442998264774043-0.09672086584553752j), sigma=40, beta=0.5292268605797695, name='Y90m_d3'), DriveChannel(3), name='Y90m_d3')),
#  (8704,
#   Play(Drag(duration=160, amp=(0.09343255413184134+0.0013155736420234682j), sigma=40, beta=-0.8260101223075255, name='X90p_d5'), DriveChannel(5), name='X90p_d5')))

# %%
t_orign_schedule.instructions[4][-1].name
# Out:
# 'Ym_d1'
